# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from glob import glob
from Charts.ploTools import *
from Charts.resumeTools import *

# %%
FOLDER_EXP = 'OptimizeIterationsResults/OptunaDDPGExpBase_T*'
METRICS_EXP = '/00000*/*/metrics_resume_testing.pkl'
PATH_DATA_LIST_METRICS_RESUME_TESTING = glob(FOLDER_EXP + METRICS_EXP)

FOLDER_EXP_CP5 = 'OptimizeIterationsResults/OptunaDDPGExpBase_CorrelationPunishment05'
PATH_DATA_LIST_METRICS_RESUME_TESTING_CP5 = glob(FOLDER_EXP_CP5 + METRICS_EXP)


FOLDER_EXP_CP7 = 'OptimizeIterationsResults/OptunaDDPGExpBase_CorrelationPunishment07'
PATH_DATA_LIST_METRICS_RESUME_TESTING_CP7 = glob(FOLDER_EXP_CP7 + METRICS_EXP)

# %%
plotTableFullLastWorthMultiAgents(PATH_DATA_LIST_METRICS_RESUME_TESTING)
# Out:
# net_worths

# %%
plotTableFullLastWorthMultiAgents(PATH_DATA_LIST_METRICS_RESUME_TESTING_CP5)
# Out:
# net_worths

# %%
plotTableFullLastWorthMultiAgents(PATH_DATA_LIST_METRICS_RESUME_TESTING_CP7)
# Out:
# net_worths

# %%
metrics_resume_testing_avg = mean_resume_data(PATH_DATA_LIST_METRICS_RESUME_TESTING)
metrics_resume_testing_avg_cp5 = mean_resume_data(PATH_DATA_LIST_METRICS_RESUME_TESTING_CP5)
metrics_resume_testing_avg_cp7 = mean_resume_data(PATH_DATA_LIST_METRICS_RESUME_TESTING_CP7)

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg, 'sharpe_ratios')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_cp5, 'sharpe_ratios')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_cp7, 'sharpe_ratios')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg, 'pearson_correlations')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_cp7, 'pearson_correlations')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_cp5, 'pearson_correlations')
