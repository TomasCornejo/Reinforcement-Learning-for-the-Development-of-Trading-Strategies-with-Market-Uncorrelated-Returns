# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from glob import glob
from Charts.ploTools import *
from Charts.resumeTools import *

# %%
FOLDER_EXP = 'OptimizeIterationsResults/OptunaDDPGExpBase_T*'
METRICS_EXP = '/00000*/*/metrics_resume_testing.pkl'
PATH_DATA_LIST_METRICS_RESUME_TESTING = glob(FOLDER_EXP + METRICS_EXP)

FOLDER_EXP_CP5 = 'OptimizeIterationsResults/OptunaDDPGExpBase_RMemorySize3'
PATH_DATA_LIST_METRICS_RESUME_TESTING_R3 = glob(FOLDER_EXP_CP5 + METRICS_EXP)


FOLDER_EXP_CP7 = 'OptimizeIterationsResults/OptunaDDPGExpBase_RMemorySize10'
PATH_DATA_LIST_METRICS_RESUME_TESTING_R10 = glob(FOLDER_EXP_CP7 + METRICS_EXP)

# %%
plotTableFullLastWorthMultiAgents(PATH_DATA_LIST_METRICS_RESUME_TESTING)
# Out:
# net_worths

# %%
plotTableFullLastWorthMultiAgents(PATH_DATA_LIST_METRICS_RESUME_TESTING_R3)
# Out:
# net_worths

# %%
plotTableFullLastWorthMultiAgents(PATH_DATA_LIST_METRICS_RESUME_TESTING_R10)
# Out:
# net_worths

# %%
metrics_resume_testing_avg = mean_resume_data(PATH_DATA_LIST_METRICS_RESUME_TESTING)
metrics_resume_testing_avg_R3 = mean_resume_data(PATH_DATA_LIST_METRICS_RESUME_TESTING_R3)
metrics_resume_testing_avg_R10 = mean_resume_data(PATH_DATA_LIST_METRICS_RESUME_TESTING_R10)

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg, 'sharpe_ratios')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_R3, 'sharpe_ratios')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_R10, 'sharpe_ratios')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg, 'pearson_correlations')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_R3, 'pearson_correlations')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg_R10, 'pearson_correlations')
