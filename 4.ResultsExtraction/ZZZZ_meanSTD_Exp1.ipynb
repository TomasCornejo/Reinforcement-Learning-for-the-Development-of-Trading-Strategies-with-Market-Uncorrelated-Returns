# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from glob import glob
from Charts.ploTools import *
from Charts.resumeTools import *

# %%
FOLDER_EXP = 'OptimizeIterationsResults/OptunaDDPGExpBase_T*'
METRICS_EXP = '/00000*/*/metrics_resume_testing.pkl'
PATH_DATA_LIST_METRICS_RESUME_TESTING = glob(FOLDER_EXP + METRICS_EXP)

# %%
PATH_DATA_LIST_METRICS_RESUME_TESTING
# Out:
# ['OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\000000\\2024-10-26_00-46-07_218\\metrics_resume_testing.pkl',
#  'OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\000001\\2024-10-26_01-05-40_860\\metrics_resume_testing.pkl',
#  'OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\0000010\\2024-10-26_04-03-20_755\\metrics_resume_testing.pkl',
#  'OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\0000011\\2024-10-26_04-22-53_488\\metrics_resume_testing.pkl',
#  'OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\0000012\\2024-10-26_04-42-49_415\\metrics_resume_testing.pkl',
#  'OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\0000013\\2024-10-26_05-02-31_898\\metrics_resume_testing.pkl',
#  'OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\0000014\\2024-10-26_05-22-15_291\\metrics_resume_testing.pkl',
#  'OptimizeIterationsResults\\OptunaDDPGExpBase_Total\\0000015\\2024-10-26_05-41-59_769\\metrics_resume_testing.pkl',
# ...

# %%
plotTableFullLastWorthMultiAgents(PATH_DATA_LIST_METRICS_RESUME_TESTING)
# Out:
# net_worths

# %%
metrics_resume_testing_avg = mean_resume_data(PATH_DATA_LIST_METRICS_RESUME_TESTING)

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg, 'sharpe_ratios')

# %%
plotTableFullMetricMultiAgents(metrics_resume_testing_avg, 'pearson_correlations')

# %%
metrics_resume_testing_avg
# Out:
# {'DDPG Agent': {'net_worths_delta': [1475.9795036995033,
#    -1051.0349013879,
#    -1279.7719375059833,
#    2191.981680932903,
#    -284.1384734103993,
#    -681.881862296288,
#    -506.9923729434944,
#    -872.3106271438976,
#    -186.69960614439114,
#    -743.0841999919919,
#    749.8969828640144,
#    1225.9140513236116,
#    393.97648880220294,
#    5772.208712061072,
#    -36.37694778559642,
#    -586.0441958051964,
#    -1091.2121818833848,
#    222.22832019510753,
#    1277.0205744338173,
#    -170.7186627388971,
#    555.6877417930012,
#    -3789.7239621937993,
#    -62.43421624249793,
#    -403.4563731458264,
#    -544.567151355378,
#    -903.120800396615,
#    652.3938575892264,
#    9.53203406020766,
#    1268.2057859602762,
#    -8590.548791057572,
#    5069.375647694321,
#    -1176.6821755767546,
#    3017.0040212219055,
#    1136.7494165596945,
#    -1574.9071403096889,
#    441.06489062971264,
#    -353.9416285445006,
#    -279.3478729675933,
# ...
