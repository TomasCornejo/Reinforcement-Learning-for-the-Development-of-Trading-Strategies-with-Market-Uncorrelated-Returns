# %%
from Charts.ploTools import *
import pickle

# %%
# import metrics data (.pkl)
PATH_DATA = 'ResultsData/0004'

with open(f'{PATH_DATA}/metrics_resume.pkl', 'rb') as f:
    metrics_resume = pickle.load(f)

with open(f'{PATH_DATA}/metrics_resume_testing.pkl', 'rb') as f:
    metrics_resume_testing = pickle.load(f)

with open(f'{PATH_DATA}/training_rewards_resume.pkl', 'rb') as f:
    training_rewards_resume = pickle.load(f)

# %%
# Output 1 - Training Rewards
plotCumulativeRewardMultiAgents(metrics_resume, "./" + PATH_DATA + '/' + 'training_')

# %%
# Output 2 - Training Rewards - last Agent
plotCumulativeRewardMultiAgents(metrics_resume_testing , "./" + PATH_DATA + '/' + 'testing_')

# %%
# Output 3 - Cumulative Networth 
plotCumulativeNetWorthMultiAgents(metrics_resume,  "./" + PATH_DATA + '/' + 'training_')

# %%
# Output 4 - Cumulative Networth - last Agent
plotCumulativeNetWorthMultiAgents(metrics_resume_testing,  "./" + PATH_DATA + '/' + 'testing_')

# %%
# Output 5 - Ratio Sharpe
plotSharpeRatioMultiAgents(metrics_resume,  "./" + PATH_DATA + '/' + 'training_')

# %%
# Output 6 - Training Rewards
plotTrainingRewardsMultiAgents(training_rewards_resume , "./" + PATH_DATA + '/' + 'training_')

# %%
# Output 7 - TBD

# %%
# Output 8 - Pearson Correlation
plotPearsonCorrelationMultiAgents(metrics_resume,  "./" + PATH_DATA + '/' + 'training_')

# %%
# Output 9 - Output Files OK
