# %%
# Fill missing data in csv files with 0
# # some of the csv are missing data for some datetimes
# # i want to fill the missing data with 0 all data for the same datetime
# import pandas as pd
# import datetime
# from glob import glob
# import numpy

# # got a filename that has all the datetimes with prices
# filename = 'data/SP500.csv'
# #get the list of datetimes in the field timestamp with pandas

# df = pd.read_csv(filename)
# datetimes = df['timestamp'].to_list()

# # get the list of csv files
# files = glob('Data/*.csv')

# # This is a sample of the format of the csv files
# #timestamp,symbol,open,high,low,close,volume,trade_count,vwap
# #2016-06-01 09:30:00-04:00,QSII,12.69,12.74,12.65,12.67,48037.0,208.0,12.706119

# # for each file in the list: 
# # create a new file with the same name +"_filled" , put all the datetimes in the first column with the same format
# # timestamp,symbol,open,high,low,close,volume,trade_count,vwap
# # keep the same order of the columns 
# # if exists data for a datetime, keep the data
# # if there is no data for a datetime, fill the data with 0
# # process the files with pandas

# for file in files:
#     print('Processing file', file)
#     df = pd.read_csv(file)
#     #df['timestamp'] = pd.to_datetime(df['timestamp'])
#     df = df.set_index('timestamp')
#     df.drop_duplicates(keep='first', inplace=True)
#     df = df.reindex(datetimes, fill_value=0)
#     df = df.reset_index()
#     df.to_csv(file.replace('Data/', 'Data/filled_'), index=False)
#     print('File', file, 'processed')

# %%
# Fill the 0 data in the .csv files with the last available data
# import pandas as pd
# import datetime
# from glob import glob
# import numpy

# fileList = glob('DataExample/*.csv')
# for file in fileList:
#     print('Processing file', file)
#     df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
#     df.replace(0, pd.NA, inplace=True)
#     df.fillna(method='ffill', inplace=True)
#     df.fillna(0, inplace=True)
#     new_file_name = file.replace('.csv', '_filled.csv')
#     df.reset_index(inplace=True)
#     df.to_csv(new_file_name, index=False)
#     print('File', file, 'processed')

# # Fill the 0 data in the .pk (parquet) files with the last available data
# import pandas as pd
# import datetime
# from glob import glob
# import numpy

# fileList = glob('Data/*.pk')
# for file in fileList:
#     print('Processing file', file)
#     df = pd.read_parquet(file)
#     df.replace(0, pd.NA, inplace=True)
#     df.fillna(method='ffill', inplace=True)
#     df.fillna(0, inplace=True)
#     new_file_name = file.replace('.pk', '_filled.pk')
#     df.to_parquet(new_file_name)
#     print('File', new_file_name, 'processed')

# %%
# #Convert to parquet
# from glob import glob
# import pandas as pd


# files = glob('Data/*.csv')

# for file in files:
#     parquet_file_name = file.replace('.csv', '.pk')
#     print(f'Processing file: {file} to {parquet_file_name}')
#     df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
#     # Drop column symbol
#     df.drop(columns='symbol', inplace=True)
#     if parquet_file_name[-3:] == '.pk':
#         df.to_parquet(parquet_file_name, index=True)
#         print("The file was saved as parquet: {parquet_file_name}")

# %%
# # for the _filled.pk files get the first date with data (close price != 0) and the last date with data (close price != 0)
# # put that data in a pandas dataframe with each row the filename and the first and last date 
# import pandas as pd
# from glob import glob

# files = glob('Data/*_filled.pk')

# data = []

# for file in files:
#     df = pd.read_parquet(file)
#     first_date = df[df['close'] != 0].index[0]
#     last_date = df[df['close'] != 0].index[-1]
#     data.append([file, first_date, last_date])

# df = pd.DataFrame(data, columns=['filename', 'first_date', 'last_date'])
# df
# #order the dataframe by the first date
# df.sort_values('first_date', inplace=True)
# df

# %%
# for the .csv files get the first date with data (close price != 0) and the last date with data (close price != 0)
# put that data in a pandas dataframe with each row the filename and the first and last date
# from glob import glob
# import pandas as pd
# files = glob('*.csv')
# data = []
# for file in files:
#     df = pd.read_csv(file)
#     first_date = df[df['close'] != 0].iloc[0]['timestamp']
#     last_date = df[df['close'] != 0].iloc[-1]['timestamp']
#     data.append([file, first_date, last_date]) 

# df = pd.DataFrame(data, columns=['filename', 'first_date', 'last_date'])
# df
# #order the dataframe by the first date
# df.sort_values('last_date', inplace=True)
# df

# %%
# import pandas as pd
# from datetime import datetime

# # Danh sách các cổ phiếu trong Dow Jones 30
# tickers = ['AAPL','ABCB','CSCO','DAL','EAST','ESPR','F',
#            'GOOGL','JPM','META','MSFT','NVDA','PFE','PG','PSX',
#            'SGLY','SP500','TSLA','UNH','USA','WMT','XOM']

# # ticker of benchmark
# benchmark = 'SP500'

# # Get the data from the CSV files
# stock_data = {}
# for ticker in tickers:
#     df = pd.read_parquet(f'Data/{ticker}_filled.pk')
#     #pass the columns to capitalize
#     df.columns = df.columns.str.capitalize()
#     stock_data[ticker] = df


# # Establish the time range for the data
# #trainInit = datetime.fromisoformat('2016-06-01 00:00:01-04:00')
# trainInit = datetime.fromisoformat('2018-01-01 00:00:01-04:00')
# trainEnd = datetime.fromisoformat('2024-01-01 00:00:01-04:00')

# # split the data into training
# training_data_time_range = (trainInit, trainEnd)

# # split the data into training, validation and test sets
# training_data = {}

# for ticker, df in stock_data.items():
#     training_data[ticker] = df.loc[training_data_time_range[0]:training_data_time_range[1]]

# # print shape of training, validation and test data
# ticker = 'AAPL'
# print(f'Training data shape for {ticker}: {training_data[ticker].shape}')

# # Display the first 5 rows of the data
# training_data['AAPL'].head()

# %%
# import pandas as pd
# import numpy as np

# def add_technical_indicators(df):
#     # calculate RSI 14 
#     delta = df['Close'].diff()
#     up = delta.where(delta > 0, 0)
#     down = -delta.where(delta < 0, 0)
#     rs = up.rolling(window=14).mean() / down.rolling(window=14).mean()
#     df['RSI'] = 100 - (100 / (1 + rs))

#     # EMA 12 / 26  en MACD
#     df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
#     df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
#     df['MACD'] = df['EMA12'] - df['EMA26']
#     df['Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
    
#     # RSI 14
#     delta = df['Close'].diff()
#     gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
#     loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
#     rs = gain / loss
#     df['RSI'] = 100 - (100 / (1 + rs))
    
#     # CCI 20
#     tp = (df['High'] + df['Low'] + df['Close']) / 3
#     sma_tp = tp.rolling(window=20).mean()
#     mean_dev = tp.rolling(window=20).apply(lambda x: np.mean(np.abs(x - x.mean())))
#     df['CCI'] = (tp - sma_tp) / (0.015 * mean_dev)
    
#     # ADX 14
#     high_diff = df['High'].diff()
#     low_diff = df['Low'].diff()
#     df['+DM'] = np.where((high_diff > low_diff) & (high_diff > 0), high_diff, 0)
#     df['-DM'] = np.where((low_diff > high_diff) & (low_diff > 0), low_diff, 0)
#     tr = pd.concat([df['High'] - df['Low'], np.abs(df['High'] - df['Close'].shift(1)), np.abs(df['Low'] - df['Close'].shift(1))], axis=1).max(axis=1)
#     atr = tr.ewm(span=14, adjust=False).mean()
#     df['+DI'] = 100 * (df['+DM'].ewm(span=14, adjust=False).mean() / atr)
#     df['-DI'] = 100 * (df['-DM'].ewm(span=14, adjust=False).mean() / atr)
#     dx = 100 * np.abs(df['+DI'] - df['-DI']) / (df['+DI'] + df['-DI'])
#     df['ADX'] = dx.ewm(span=14, adjust=False).mean()

#     # drop NaN values
#     # df.dropna(inplace=True)
#     # Fill NaN values with -1
#     df.fillna(-1, inplace=True)

#     # keep Open, High, Low, Close, Volume, MACD, Signal, RSI, CCI, ADX
#     df = df[['Open', 'High', 'Low', 'Close', 'Volume', 'MACD', 'Signal', 'RSI', 'CCI', 'ADX']]

#     return df

# %%
# # add technical indicators to the training data for each stock
# for ticker, df in training_data.items():
#     training_data[ticker] = add_technical_indicators(df)

# # Create benchmark data
# benchmark_training_data = training_data[benchmark]

# # print the first 5 rows of the data
# print('Shape of training data for AAPL:', training_data['AAPL'].shape)

# # print the first 5 rows of the benchmark data
# print('Shape of training benchmark data:', benchmark_training_data.shape)

# %%
# VARIABLES
INITIAL_BALANCE = 100000
EPISODE_STEP_CONST = 64 
N_TOTAL_EPISODES = 900 # 900
TESTING_POINTS = 50 # 50
SEED = 9

CORRELATION_PUNISHMENT = 1

ID_PATH = '000005'
PATH_TO_SAVE = f'ResultsData/RSreducedTest/{ID_PATH}'
DESCRIPTION = 'Test con Reward= Ratio de Sharpe'

# %%
# Saving variables in metadata
metadata = {}
metadata['INITIAL_BALANCE'] = INITIAL_BALANCE
metadata['EPISODE_STEP_CONST'] = EPISODE_STEP_CONST
metadata['N_TOTAL_EPISODES'] = N_TOTAL_EPISODES
metadata['TESTING_POINTS'] = TESTING_POINTS
metadata['SEED'] = SEED
metadata['ID_PATH'] = ID_PATH
metadata['PATH_TO_SAVE'] = PATH_TO_SAVE
metadata['DESCRIPTION'] = DESCRIPTION

# %%
tickers = ['AAPL','ABCB','CSCO','DAL','EAST','ESPR','F',
           'GOOGL','JPM','META','MSFT','NVDA','PFE','PG','PSX',
           'SGLY','SP500','TSLA','UNH','USA','WMT','XOM']

# ticker of benchmark
benchmark = 'SP500'

# %%
#for tick in tickers:
#    training_data[tick].to_parquet(f'Data/enriched_data/{tick}_training_data.pk',index=True)

# %%
import pandas as pd
import numpy as np

training_data = {}
for tick in tickers:
    training_data[tick] = pd.read_parquet(f'Data/enriched_data/{tick}_training_data.pk')

# %%
def shuffle_dataframe(df, shuffled_days):
    date_to_group = {date: group for date, group in df.groupby(df.index.date)}
    shuffled_groups = [date_to_group[date] for date in shuffled_days]
    return pd.concat(shuffled_groups)

def shuffle_dataset_dictionary(dataset_dict, seed=SEED, benchmark='SP500'):
    outputDatasetDictionary = {}
    np.random.seed(seed)

    #Get unique dates for one
    unique_days = np.unique(dataset_dict[benchmark].index.date)

    #Shuffle the unique days
    shuffled_unique_days = np.random.permutation(unique_days)

    for ticker, dataframe in dataset_dict.items():
        outputDatasetDictionary[ticker] = shuffle_dataframe(dataframe, shuffled_unique_days)
    return outputDatasetDictionary

# %%
shuffleDS = shuffle_dataset_dictionary(training_data)
benchmark_shuffleDS = shuffleDS[benchmark]

# %%
def pearsonccs(samples):
    C = np.cov(samples)
    diag = np.diag(C)
    N = np.sqrt(np.outer(diag, diag))
    N[N == 0] = 1
    return C / N

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd

class StockTradingEnv(gym.Env):
    metadata = {'render_modes': ['human']}
    
    def __init__(self, stock_data , benchmark_data, return_memory_size=5):
        super(StockTradingEnv, self).__init__()

        # Define the benchmark
        self.benchmark_data = benchmark_data
        
        # Initialize of memory
        self.return_memory_size = return_memory_size
        self.last_return_memory_benchmark = []
        self.last_return_memory_portfolio = []
        self.benchmark_portfolio_correlation = 0

        self.portfolio_return = []

        self.benchmark_portfolio_total_correlation = 0

        # Remove any empty DataFrames from the stock data
        self.stock_data = {ticker: df for ticker, df in stock_data.items() if not df.empty}     
        self.tickers = list(self.stock_data.keys())
        print(f"Stock data has been loaded for {len(self.tickers)} stocks.")
        print(f"The tickers are: {self.tickers}")
        
        if not self.tickers:
            raise ValueError("All provided stock data is empty")
        
        # Calculate the size of one stock's data
        sample_df = next(iter(self.stock_data.values()))
        self.n_features = len(sample_df.columns)
        
        # Define action and observation space
        self.action_space = spaces.Box(low=-1, high=1, shape=(len(self.tickers),), dtype=np.float32)
        
        # Observation space: price data for each stock + balance + net worth + shares held + max net worth + current step
        self.obs_shape = self.n_features * len(self.tickers) + 2 + len(self.tickers) + 2
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.obs_shape,), dtype=np.float32)
        
        # Initialize account balance
        self.initial_balance = INITIAL_BALANCE
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        
        # Set the current step and the episode step
        self.current_step = 0
        self.episode_step = 0
        self.current_date = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d')
        
        # Initialize the current date for separate days
        self.is_last_tick_of_day = False

    def hard_reset(self):
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        self.episode_step = 0
        
        self.is_last_tick_of_day = False
        self.last_return_memory_benchmark = []
        self.last_return_memory_portfolio = []

        self.portfolio_return = []

        self.benchmark_portfolio_correlation = 0
        self.benchmark_portfolio_total_correlation = 0
        
        #Especifico del hard reset
        self.current_step = 0
        self.current_date = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d')

        return self._next_observation(), {}

        
    
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        self.episode_step = 0
        self.is_last_tick_of_day = False
        self.last_return_memory_benchmark = []
        self.last_return_memory_portfolio = []

        self.portfolio_return = []

        self.benchmark_portfolio_correlation = 0
        self.benchmark_portfolio_total_correlation = 0

        return self._next_observation(), {}
    
    def _next_observation(self):
        frame = np.zeros(self.obs_shape)
        
        idx = 0
        for ticker in self.tickers:
            df = self.stock_data[ticker]
            if self.current_step < len(df):
                frame[idx:idx+self.n_features] = df.iloc[self.current_step].values
            elif len(df) > 0:
                frame[idx:idx+self.n_features] = df.iloc[-1].values
            idx += self.n_features
        
        frame[-4-len(self.tickers)] = self.balance
        frame[-3-len(self.tickers):-3] = [self.shares_held[ticker] for ticker in self.tickers]
        frame[-3] = self.net_worth
        frame[-2] = self.max_net_worth
        frame[-1] = self.episode_step
        
        return frame

    def step(self, actions):
        self.current_step += 1
        self.episode_step += 1
        self.current_date = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d')

        if self.is_last_tick_of_day:
            return self._next_observation(), 0, True, False, {}
        
        current_prices = {}
        for i, ticker in enumerate(self.tickers):
            current_prices[ticker] = self.stock_data[ticker].iloc[self.current_step]['Close']
            action = actions[i]
            
            # Buy or sell the stocks just if the price is different from 0
            if current_prices[ticker] != 0.0:
                if action > 0:  # Buy
                    shares_to_buy = int(self.balance * action / current_prices[ticker])
                    cost = shares_to_buy * current_prices[ticker]
                    self.balance -= cost
                    self.shares_held[ticker] += shares_to_buy
                elif action < 0:  # Sell
                    shares_to_sell = int(self.shares_held[ticker] * abs(action))
                    sale = shares_to_sell * current_prices[ticker]
                    self.balance += sale
                    self.shares_held[ticker] -= shares_to_sell
                    self.total_shares_sold[ticker] += shares_to_sell
                    self.total_sales_value[ticker] += sale
            else:
                print(f"Price for {ticker} in {self.current_date} is 0.0")
        

        self.last_net_worth = self.net_worth
        self.net_worth = self.balance + sum(self.shares_held[ticker] * current_prices[ticker] for ticker in self.tickers)
        self.max_net_worth = max(self.net_worth, self.max_net_worth)
        

        # reward = self.net_worth - self.last_net_worth # Old Reward
        done = (self.net_worth <= 0 or self.is_last_tick_of_day)

        # Calculate the return of the benchmark (just from second step)
        if self.episode_step > 0:
            benchmark_return = self.benchmark_data.iloc[self.current_step]['Close'] / self.benchmark_data.iloc[self.current_step - 1]['Close'] - 1
            #Add the return to the benchmark to the memory but if the memory is full, remove the oldest return
            if len(self.last_return_memory_benchmark) >= self.return_memory_size:
                self.last_return_memory_benchmark.pop(0)
            self.last_return_memory_benchmark.append(benchmark_return)
            

            # Calculate the return of the portfolio
            portfolio_return = self.net_worth / self.last_net_worth - 1
            self.portfolio_return.append(portfolio_return)
            # Add the return to the portfolio to the memory but if the memory is full, remove the oldest return
            if len(self.last_return_memory_portfolio) >= self.return_memory_size:
                self.last_return_memory_portfolio.pop(0)
            self.last_return_memory_portfolio.append(portfolio_return)

        
        # Calculate the pearson correlation between the benchmark memory and the portfolio memory just if the memory is full
        if len(self.last_return_memory_benchmark) == self.return_memory_size and \
           len(self.last_return_memory_portfolio) == self.return_memory_size:
            self.benchmark_portfolio_correlation = pearsonccs([self.last_return_memory_benchmark, self.last_return_memory_portfolio])[0][1]   
        else:
            self.benchmark_portfolio_correlation = 0
        
        # Update the is_last_tick_of_day variable
        self.is_last_tick_of_day = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d') \
            != self.benchmark_data.index[self.current_step + 1].date().strftime('%Y-%m-%d')
        
        # Define the reward as the ratio sharpe of the portfolio * (1- correlation) 
        if self.benchmark_portfolio_correlation != 0 and np.std(self.last_return_memory_portfolio) != 0:
            reward = (((np.prod(np.array(self.last_return_memory_portfolio)+1)-1)*self.initial_balance)/np.std(self.last_return_memory_portfolio)) #* (1 - self.benchmark_portfolio_correlation*CORRELATION_PUNISHMENT)
        else:
            reward = (np.prod(np.array(self.last_return_memory_portfolio)+1)-1)*self.initial_balance

        obs = self._next_observation()
        return obs, reward, done, False, {}
    
    def render(self, mode='human'):
        profit = self.net_worth - self.initial_balance
        print(f'Step: {self.current_step}')
        print(f'Benchmark-Portfolio Correlation: {self.benchmark_portfolio_correlation:.2f}')
        print(f'Balance: {self.balance:.2f}')
        for ticker in self.tickers:
            print(f'{ticker} Shares held: {self.shares_held[ticker]}')
        print(f'Net worth: {self.net_worth:.2f}')
        print(f'Profit: {profit:.2f}')

    def close(self):
        pass

# %%
from stable_baselines3.common.utils import get_device

# %%
get_device(device='cuda')
# Out:
# device(type='cuda')

# %%
from stable_baselines3 import PPO, A2C, DDPG
from stable_baselines3.common.vec_env import DummyVecEnv

# Define PPO Agent
class PPOAgent:
    def __init__(self, env, n_steps):
        self.model_type = "SB3"
        self.model = PPO("MlpPolicy", env, n_steps=n_steps ,verbose=1, device='cuda')
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define A2C Agent
class A2CAgent:
    def __init__(self, env, n_steps):
        self.model_type = "SB3"
        self.model = A2C("MlpPolicy", env, n_steps=n_steps, verbose=1, device='cuda')
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define DDPG Agent
class DDPGAgent:
    def __init__(self, env):
        self.model_type = "SB3"
        self.model = DDPG("MlpPolicy", env, verbose=1, device='cuda')
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define Random Agent
class RandomAgent:
    def __init__(self, env):
        self.model_type = "Random"
        self.env = env
        self.tickers_len = len(env.get_attr('tickers')[0])
    
    def predict(self, obs):
        return np.random.uniform(-1, 1, self.tickers_len).reshape(1, self.tickers_len)

# Define SP500 Agent
class SP500Agent:
    def __init__(self, env):
        self.model_type = "SP500"
        self.env = env
        self.tickers = env.get_attr('tickers')[0]
        self.tickers_len = len(self.tickers)
        self.SP500idx = self.tickers.index('SP500')

        
        print("Tickers en init SP500Agent")
        print(self.env.get_attr('tickers')[0])
    
    def predict(self, obs):
        current_step = int(self.env.get_attr('episode_step')[0])
        # create a empty array of zeros
        actions = np.zeros(self.tickers_len).reshape(1, self.tickers_len)
        if current_step == 0:
            # Buy SP500
            actions[0, self.SP500idx] = 1
        return actions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Function to create the environment and train the agents
def create_env_and_train_agents(data, benchmark_data, n_steps):
    # Create the environment using DummyVecEnv with training data
    env = DummyVecEnv([lambda: StockTradingEnv(data, benchmark_data, return_memory_size=5)])

    # Train PPO Agent
    ppo_agent = PPOAgent(env, n_steps=n_steps)

    # Train A2C Agent
    a2c_agent = A2CAgent(env, n_steps=n_steps)

    # Train DDPG Agent
    ddpg_agent = DDPGAgent(env)

    # Declaring Random Agent
    random_agent = RandomAgent(env)

    # Declaring SP500 Agent
    sp500_agent = SP500Agent(env)

    # Train the ensemble agent
    #ensemble_agent = EnsembleAgent(ppo_agent.model, a2c_agent.model, ddpg_agent.model)
    
    return env, ppo_agent, a2c_agent, ddpg_agent, random_agent, sp500_agent #, ensemble_agent

# %%
from stable_baselines3.common.callbacks import CallbackList
from CustomCallback import SaveTrainingRewardsCallback

def train_test_agent(env, agent, n_total_episodes=100, testing_points=10, just_test=False):
    """
    Test a single agent and track performance metrics, with an option to visualize the results.
    #TODO Corregir documentacion
    Parameters:
    - env: The trading environment.
    - agent: The agent to be tested.
    - stock_data: Data for the stocks in the environment.
    - n_tests: Number of tests to run (default: 1000).
    - visualize: Boolean flag to enable or disable visualization (default: False).

    Returns:
    - A dictionary containing steps, balances, net worths, and shares held.
    """
    # Initialize metrics tracking
    metrics = {
        'dates': [],
        'net_worths_delta': [],
        'shares_held': [],
        'pearson_correlations': [],
        'rewards': [],
        'portfolio_returns': [],
        'stds': [],
        'sharpe_ratios': [],
        'net_worths': []
    }

    # Reset the environment before starting the tests
    obs = np.array([env.env_method('hard_reset')[0][0].tolist()]) # env.reset()#

    # Get the training partition number of episodes
    partition = int(n_total_episodes / testing_points) - 1
    EPISODE_STEP_CONST = 64

    training_rewards = []
    
    # Set the episode loop
    for i_tpoint in range(testing_points):
        # First Evaluate the agents
        print(f"--------------Testing Point {i_tpoint+1} of {testing_points}-----------------------------------")
        # Set the initial episode values
        done = False
        cum_reward = 0
        local_pearson_correlations = []
        local_portfolio_returns = []
        metrics['dates'].append(env.get_attr('current_date')[0])
        
    
        initial_testing_net_worth = env.get_attr('net_worth')[0]

        #TODO Take off Later
        print("Fecha Inicial: ", env.get_attr('current_date')[0])
        print("Current Step Inicial: ", env.get_attr('current_step')[0])

        net_worth_list = []
        episode_step_final_testing_list = []
        last_testing_shares_held_list = []
        
        # Run the testing episode
        while not done:
            action = agent.predict(obs)
            obs, reward, done, _info = env.step(action)
            local_pearson_correlations.append(env.get_attr('benchmark_portfolio_correlation')[0])
            episode_step_final_testing_list.append(env.get_attr('episode_step')[0])
            net_worth_list.append(env.get_attr('net_worth')[0])
            last_testing_shares_held_list.append(env.get_attr('shares_held')[0])
            local_portfolio_returns.append(env.get_attr('portfolio_return')[0])
            cum_reward += reward
            
            
        print("Fecha Final: ", env.get_attr('current_date')[0])
        print("Current Step Final: ", env.get_attr('current_step')[0])
        print("Episode Step Final: ", episode_step_final_testing_list[-2])
        print("Reward: ", cum_reward)

        net_worth_delta = net_worth_list[-2] - initial_testing_net_worth
        # Append metrics
        metrics['net_worths'].append(net_worth_list[-2])
        metrics['net_worths_delta'].append(net_worth_delta)
        metrics['pearson_correlations'].append(np.mean(local_pearson_correlations))
        metrics['rewards'].append(cum_reward[0])
        metrics['portfolio_returns'].append(np.mean(local_portfolio_returns[0][1:]))
        metrics['stds'].append(np.std(local_portfolio_returns[0][1:]))
        metrics['sharpe_ratios'].append((net_worth_delta / initial_testing_net_worth) / np.std(local_portfolio_returns[0][1:]))

        # Update shares held for each ticker
        # Hacer caso especial para SB3
        if agent.model_type == "SB3":
            metrics['shares_held'].append(last_testing_shares_held_list[-2])
        else:
            metrics['shares_held'].append(last_testing_shares_held_list[-1])

        if not(just_test):
            #After train the agent by partition of episodes
            print("Fecha antes train: ", env.get_attr('current_date')[0])
            print("Current Step antes train: ", env.get_attr('current_step')[0])
            if agent.model_type == "SB3":
                #Define Callbacks to train
                callback_list = CallbackList([SaveTrainingRewardsCallback()])
                #Train the agent
                agent.model.learn(EPISODE_STEP_CONST*partition, callback=callback_list)
                #Add the rewards to the list of training rewards
                training_rewards.append(callback_list.callbacks[0].rewards)
            else:
                # El agente Random y SP500 no se entrenan
                for i in range(EPISODE_STEP_CONST*partition):
                    action = agent.predict(obs)
                    obs, _reward, done, _info = env.step(action)
            print("Fecha despues train: ", env.get_attr('current_date')[0]) 
            print("Current Step despues train: ", env.get_attr('current_step')[0])
        
        episode_done = False
        # Run steps till the end of the day just if if is just_test = False
        if not(just_test):
            while not episode_done:
                action = agent.predict(obs)
                obs, _reward, episode_done, _info = env.step(action)
        obs = env.reset()
        
    return metrics , training_rewards , agent

# %%
def getResumeMetrics(env, agents, n_total_episodes=50, testing_points=5, just_test=False):
    metrics_resume = {}
    training_rewards_resume = {}
    trained_agents = {}         
    for agent_name, agent in agents.items():
        print(f"Testing {agent_name}...")
        metrics_resume[agent_name], training_rewards_resume[agent_name], trained_agents[agent_name] = train_test_agent(env, agent, n_total_episodes, testing_points,just_test)
        print(f"Done testing {agent_name}!")
    
    print('-'*50)
    print('All agents tested!')
    print('-'*50)

    return metrics_resume, training_rewards_resume , trained_agents

# %%
partition = int(N_TOTAL_EPISODES / TESTING_POINTS) - 1
n_steps = EPISODE_STEP_CONST*partition

# 1. Create the environment and train the agents
env, ppo_agent, a2c_agent, ddpg_agent, random_agent , sp500_agent = create_env_and_train_agents(shuffleDS, benchmark_shuffleDS, n_steps=n_steps)

# 2. Test & visualize the agents
agents = {
    'PPO Agent': ppo_agent,
    'A2C Agent': a2c_agent,
    'DDPG Agent': ddpg_agent,
    'Random Agent': random_agent,
    'SP500 Agent': sp500_agent
}
#Enable a metadata dictionary to save the duration time of the training in minutes
import time
start_training_time = time.time()
metrics_resume, training_rewards_resume , trained_agents = getResumeMetrics(env, agents, n_total_episodes=N_TOTAL_EPISODES, testing_points=TESTING_POINTS)
end_training_time = time.time()
metadata['training_time'] = (end_training_time - start_training_time) / 60
# Out:
# Stock data has been loaded for 22 stocks.
# The tickers are: ['AAPL', 'ABCB', 'CSCO', 'DAL', 'EAST', 'ESPR', 'F', 'GOOGL', 'JPM', 'META', 'MSFT', 'NVDA', 'PFE', 'PG', 'PSX', 'SGLY', 'SP500', 'TSLA', 'UNH', 'USA', 'WMT', 'XOM']
# Using cuda device
# Using cuda device
# Using cuda device
# Tickers en init SP500Agent
# ['AAPL', 'ABCB', 'CSCO', 'DAL', 'EAST', 'ESPR', 'F', 'GOOGL', 'JPM', 'META', 'MSFT', 'NVDA', 'PFE', 'PG', 'PSX', 'SGLY', 'SP500', 'TSLA', 'UNH', 'USA', 'WMT', 'XOM']
# Testing PPO Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2019-05-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [5667656.]
# Fecha antes train:  2019-05-20
# Current Step antes train:  64
# -----------------------------
# | time/              |      |
# |    fps             | 134  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-01-21
# Current Step despues train:  1152
# --------------Testing Point 2 of 50-----------------------------------
# Fecha Inicial:  2021-01-20
# Current Step Inicial:  1185
# Fecha Final:  2018-02-28
# Current Step Final:  1249
# Episode Step Final:  63
# Reward:  [8224769.5]
# Fecha antes train:  2018-02-28
# Current Step antes train:  1249
# -----------------------------
# | time/              |      |
# |    fps             | 124  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2021-12-16
# Current Step despues train:  2337
# --------------Testing Point 3 of 50-----------------------------------
# Fecha Inicial:  2023-10-04
# Current Step Inicial:  2381
# Fecha Final:  2022-04-08
# Current Step Final:  2445
# Episode Step Final:  63
# Reward:  [856250.1]
# Fecha antes train:  2022-04-08
# Current Step antes train:  2445
# -----------------------------
# | time/              |      |
# |    fps             | 123  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2022-04-27
# Current Step despues train:  3533
# --------------Testing Point 4 of 50-----------------------------------
# Fecha Inicial:  2019-10-28
# Current Step Inicial:  3560
# Fecha Final:  2018-04-24
# Current Step Final:  3624
# Episode Step Final:  63
# Reward:  [6996008.]
# Fecha antes train:  2018-04-24
# Current Step antes train:  3624
# -----------------------------
# | time/              |      |
# |    fps             | 128  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-06-19
# Current Step despues train:  4712
# --------------Testing Point 5 of 50-----------------------------------
# Fecha Inicial:  2021-08-23
# Current Step Inicial:  4753
# Fecha Final:  2022-06-10
# Current Step Final:  4817
# Episode Step Final:  63
# Reward:  [-1051645.4]
# Fecha antes train:  2022-06-10
# Current Step antes train:  4817
# -----------------------------
# | time/              |      |
# |    fps             | 115  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-09-06
# Current Step despues train:  5905
# --------------Testing Point 6 of 50-----------------------------------
# Fecha Inicial:  2022-03-14
# Current Step Inicial:  5930
# Fecha Final:  2021-10-14
# Current Step Final:  5994
# Episode Step Final:  63
# Reward:  [-5688473.5]
# Fecha antes train:  2021-10-14
# Current Step antes train:  5994
# -----------------------------
# | time/              |      |
# |    fps             | 112  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2021-02-16
# Current Step despues train:  7082
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  7124
# Fecha Final:  2020-04-06
# Current Step Final:  7188
# Episode Step Final:  63
# Reward:  [1159749.5]
# Fecha antes train:  2020-04-06
# Current Step antes train:  7188
# -----------------------------
# | time/              |      |
# |    fps             | 113  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-07-02
# Current Step despues train:  8276
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  8321
# Fecha Final:  2023-02-06
# Current Step Final:  8385
# Episode Step Final:  63
# Reward:  [2315605.5]
# Fecha antes train:  2023-02-06
# Current Step antes train:  8385
# -----------------------------
# | time/              |      |
# |    fps             | 113  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-10-24
# Current Step despues train:  9473
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  9482
# Fecha Final:  2023-04-20
# Current Step Final:  9538
# Episode Step Final:  55
# Reward:  [3166700.5]
# Fecha antes train:  2023-04-20
# Current Step antes train:  9538
# -----------------------------
# | time/              |      |
# |    fps             | 115  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-08-03
# Current Step despues train:  10626
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  10657
# Fecha Final:  2020-04-16
# Current Step Final:  10721
# Episode Step Final:  63
# Reward:  [3113351.5]
# Fecha antes train:  2020-04-16
# Current Step antes train:  10721
# -----------------------------
# | time/              |      |
# |    fps             | 129  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2021-09-08
# Current Step despues train:  11809
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  11847
# Fecha Final:  2021-01-07
# Current Step Final:  11911
# Episode Step Final:  63
# Reward:  [-6288940.5]
# Fecha antes train:  2021-01-07
# Current Step antes train:  11911
# -----------------------------
# | time/              |      |
# |    fps             | 123  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2022-09-23
# Current Step despues train:  12999
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  13039
# Fecha Final:  2018-03-26
# Current Step Final:  13103
# Episode Step Final:  63
# Reward:  [-1041882.94]
# Fecha antes train:  2018-03-26
# Current Step antes train:  13103
# -----------------------------
# | time/              |      |
# |    fps             | 122  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-02-24
# Current Step despues train:  14191
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  14242
# Fecha Final:  2023-01-31
# Current Step Final:  14306
# Episode Step Final:  63
# Reward:  [4848688.]
# Fecha antes train:  2023-01-31
# Current Step antes train:  14306
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-10-06
# Current Step despues train:  15394
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  15442
# Fecha Final:  2019-05-01
# Current Step Final:  15506
# Episode Step Final:  63
# Reward:  [1951448.]
# Fecha antes train:  2019-05-01
# Current Step antes train:  15506
# -----------------------------
# | time/              |      |
# |    fps             | 122  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2023-12-20
# Current Step despues train:  16594
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  16624
# Fecha Final:  2020-08-25
# Current Step Final:  16680
# Episode Step Final:  55
# Reward:  [3403246.8]
# Fecha antes train:  2020-08-25
# Current Step antes train:  16680
# -----------------------------
# | time/              |      |
# |    fps             | 118  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-04-08
# Current Step despues train:  17768
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  17817
# Fecha Final:  2023-05-25
# Current Step Final:  17881
# Episode Step Final:  63
# Reward:  [-7338980.5]
# Fecha antes train:  2023-05-25
# Current Step antes train:  17881
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-09-17
# Current Step despues train:  18969
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  19003
# Fecha Final:  2023-02-02
# Current Step Final:  19067
# Episode Step Final:  63
# Reward:  [-712617.94]
# Fecha antes train:  2023-02-02
# Current Step antes train:  19067
# -----------------------------
# | time/              |      |
# |    fps             | 118  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-09-04
# Current Step despues train:  20155
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  20164
# Fecha Final:  2021-10-12
# Current Step Final:  20228
# Episode Step Final:  63
# Reward:  [13824054.]
# Fecha antes train:  2021-10-12
# Current Step antes train:  20228
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2022-02-18
# Current Step despues train:  21316
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  21340
# Fecha Final:  2018-05-25
# Current Step Final:  21404
# Episode Step Final:  63
# Reward:  [-3464371.2]
# Fecha antes train:  2018-05-25
# Current Step antes train:  21404
# -----------------------------
# | time/              |      |
# |    fps             | 117  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-06-17
# Current Step despues train:  22492
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  22534
# Fecha Final:  2022-10-03
# Current Step Final:  22598
# Episode Step Final:  63
# Reward:  [2223649.]
# Fecha antes train:  2022-10-03
# Current Step antes train:  22598
# -----------------------------
# | time/              |      |
# |    fps             | 114  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-07-10
# Current Step despues train:  23686
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  23728
# Fecha Final:  2019-02-12
# Current Step Final:  23792
# Episode Step Final:  63
# Reward:  [11814952.]
# Fecha antes train:  2019-02-12
# Current Step antes train:  23792
# -----------------------------
# | time/              |      |
# |    fps             | 118  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2023-02-09
# Current Step despues train:  24880
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  24921
# Fecha Final:  2021-01-15
# Current Step Final:  24977
# Episode Step Final:  55
# Reward:  [2611390.2]
# Fecha antes train:  2021-01-15
# Current Step antes train:  24977
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-12-21
# Current Step despues train:  26065
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  26071
# Fecha Final:  2018-06-20
# Current Step Final:  26135
# Episode Step Final:  63
# Reward:  [4445356.5]
# Fecha antes train:  2018-06-20
# Current Step antes train:  26135
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-04-05
# Current Step despues train:  27223
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  27261
# Fecha Final:  2019-12-12
# Current Step Final:  27317
# Episode Step Final:  55
# Reward:  [1320591.5]
# Fecha antes train:  2019-12-12
# Current Step antes train:  27317
# -----------------------------
# | time/              |      |
# |    fps             | 118  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-07-15
# Current Step despues train:  28405
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  28459
# Fecha Final:  2020-02-26
# Current Step Final:  28523
# Episode Step Final:  63
# Reward:  [3027840.8]
# Fecha antes train:  2020-02-26
# Current Step antes train:  28523
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2023-06-30
# Current Step despues train:  29611
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  29651
# Fecha Final:  2018-11-05
# Current Step Final:  29715
# Episode Step Final:  63
# Reward:  [6122669.5]
# Fecha antes train:  2018-11-05
# Current Step antes train:  29715
# -----------------------------
# | time/              |      |
# |    fps             | 116  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-11-22
# Current Step despues train:  30803
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  30836
# Fecha Final:  2023-03-16
# Current Step Final:  30893
# Episode Step Final:  56
# Reward:  [4965979.]
# Fecha antes train:  2023-03-16
# Current Step antes train:  30893
# -----------------------------
# | time/              |      |
# |    fps             | 116  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-06-08
# Current Step despues train:  31981
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  32038
# Fecha Final:  2022-11-28
# Current Step Final:  32102
# Episode Step Final:  63
# Reward:  [11184624.]
# Fecha antes train:  2022-11-28
# Current Step antes train:  32102
# -----------------------------
# | time/              |      |
# |    fps             | 119  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-07-14
# Current Step despues train:  33190
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  33237
# Fecha Final:  2021-03-23
# Current Step Final:  33293
# Episode Step Final:  55
# Reward:  [-2354332.8]
# Fecha antes train:  2021-03-23
# Current Step antes train:  33293
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2023-08-16
# Current Step despues train:  34381
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  34429
# Fecha Final:  2022-09-16
# Current Step Final:  34493
# Episode Step Final:  63
# Reward:  [-8534174.]
# Fecha antes train:  2022-09-16
# Current Step antes train:  34493
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-06-25
# Current Step despues train:  35581
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  35614
# Fecha Final:  2020-02-20
# Current Step Final:  35678
# Episode Step Final:  63
# Reward:  [-384216.25]
# Fecha antes train:  2020-02-20
# Current Step antes train:  35678
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2022-08-30
# Current Step despues train:  36766
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  36805
# Fecha Final:  2020-09-30
# Current Step Final:  36869
# Episode Step Final:  63
# Reward:  [8609024.]
# Fecha antes train:  2020-09-30
# Current Step antes train:  36869
# -----------------------------
# | time/              |      |
# |    fps             | 118  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-05-14
# Current Step despues train:  37957
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  37986
# Fecha Final:  2023-04-17
# Current Step Final:  38050
# Episode Step Final:  63
# Reward:  [11089513.]
# Fecha antes train:  2023-04-17
# Current Step antes train:  38050
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2023-10-19
# Current Step despues train:  39138
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  39177
# Fecha Final:  2023-09-22
# Current Step Final:  39241
# Episode Step Final:  63
# Reward:  [-3242632.2]
# Fecha antes train:  2023-09-22
# Current Step antes train:  39241
# -----------------------------
# | time/              |      |
# |    fps             | 117  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-03-31
# Current Step despues train:  40329
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  40387
# Fecha Final:  2021-08-03
# Current Step Final:  40443
# Episode Step Final:  55
# Reward:  [-3016838.2]
# Fecha antes train:  2021-08-03
# Current Step antes train:  40443
# -----------------------------
# | time/              |      |
# |    fps             | 116  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-06-29
# Current Step despues train:  41531
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  41543
# Fecha Final:  2020-04-03
# Current Step Final:  41607
# Episode Step Final:  63
# Reward:  [6871159.5]
# Fecha antes train:  2020-04-03
# Current Step antes train:  41607
# -----------------------------
# | time/              |      |
# |    fps             | 119  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-08-24
# Current Step despues train:  42695
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  42719
# Fecha Final:  2019-03-11
# Current Step Final:  42783
# Episode Step Final:  63
# Reward:  [-220366.62]
# Fecha antes train:  2019-03-11
# Current Step antes train:  42783
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-01-26
# Current Step despues train:  43871
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  43897
# Fecha Final:  2018-03-07
# Current Step Final:  43961
# Episode Step Final:  63
# Reward:  [-16631281.]
# Fecha antes train:  2018-03-07
# Current Step antes train:  43961
# -----------------------------
# | time/              |      |
# |    fps             | 118  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-04-24
# Current Step despues train:  45049
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  45087
# Fecha Final:  2019-01-02
# Current Step Final:  45151
# Episode Step Final:  63
# Reward:  [-664955.75]
# Fecha antes train:  2019-01-02
# Current Step antes train:  45151
# -----------------------------
# | time/              |      |
# |    fps             | 119  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-03-24
# Current Step despues train:  46239
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  46282
# Fecha Final:  2020-06-01
# Current Step Final:  46344
# Episode Step Final:  61
# Reward:  [-430818.56]
# Fecha antes train:  2020-06-01
# Current Step antes train:  46344
# -----------------------------
# | time/              |      |
# |    fps             | 119  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-06-04
# Current Step despues train:  47432
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  47477
# Fecha Final:  2020-03-11
# Current Step Final:  47541
# Episode Step Final:  63
# Reward:  [-7257403.5]
# Fecha antes train:  2020-03-11
# Current Step antes train:  47541
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-06-21
# Current Step despues train:  48629
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  48663
# Fecha Final:  2022-05-23
# Current Step Final:  48727
# Episode Step Final:  63
# Reward:  [1909229.]
# Fecha antes train:  2022-05-23
# Current Step antes train:  48727
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-02-26
# Current Step despues train:  49815
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  49871
# Fecha Final:  2021-11-09
# Current Step Final:  49926
# Episode Step Final:  54
# Reward:  [199288.58]
# Fecha antes train:  2021-11-09
# Current Step antes train:  49926
# -----------------------------
# | time/              |      |
# |    fps             | 119  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2023-10-06
# Current Step despues train:  51014
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  51075
# Fecha Final:  2020-07-22
# Current Step Final:  51137
# Episode Step Final:  61
# Reward:  [1765582.]
# Fecha antes train:  2020-07-22
# Current Step antes train:  51137
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-08-09
# Current Step despues train:  52225
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  52247
# Fecha Final:  2023-06-21
# Current Step Final:  52303
# Episode Step Final:  55
# Reward:  [-4118249.5]
# Fecha antes train:  2023-06-21
# Current Step antes train:  52303
# -----------------------------
# | time/              |      |
# |    fps             | 115  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2020-07-23
# Current Step despues train:  53391
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  53415
# Fecha Final:  2019-01-07
# Current Step Final:  53479
# Episode Step Final:  63
# Reward:  [6655049.5]
# Fecha antes train:  2019-01-07
# Current Step antes train:  53479
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2023-03-24
# Current Step despues train:  54567
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  54602
# Fecha Final:  2019-04-01
# Current Step Final:  54658
# Episode Step Final:  55
# Reward:  [-1269862.9]
# Fecha antes train:  2019-04-01
# Current Step antes train:  54658
# -----------------------------
# | time/              |      |
# |    fps             | 119  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-02-25
# Current Step despues train:  55746
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  55787
# Fecha Final:  2020-06-09
# Current Step Final:  55843
# Episode Step Final:  55
# Reward:  [551580.25]
# Fecha antes train:  2020-06-09
# Current Step antes train:  55843
# -----------------------------
# | time/              |      |
# |    fps             | 117  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-10-05
# Current Step despues train:  56931
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  56954
# Fecha Final:  2018-09-13
# Current Step Final:  57018
# Episode Step Final:  63
# Reward:  [4085408.]
# Fecha antes train:  2018-09-13
# Current Step antes train:  57018
# -----------------------------
# | time/              |      |
# |    fps             | 120  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2019-07-17
# Current Step despues train:  58106
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  58146
# Fecha Final:  2018-05-07
# Current Step Final:  58202
# Episode Step Final:  55
# Reward:  [3537876.5]
# Fecha antes train:  2018-05-07
# Current Step antes train:  58202
# -----------------------------
# | time/              |      |
# |    fps             | 119  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1088 |
# -----------------------------
# Fecha despues train:  2018-08-08
# Current Step despues train:  59290
# Done testing PPO Agent!
# Testing A2C Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2019-05-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [12889892.]
# Fecha antes train:  2019-05-20
# Current Step antes train:  64
# Fecha despues train:  2020-01-21
# Current Step despues train:  1152
# --------------Testing Point 2 of 50-----------------------------------
# Fecha Inicial:  2021-01-20
# Current Step Inicial:  1185
# Fecha Final:  2018-02-28
# Current Step Final:  1249
# Episode Step Final:  63
# Reward:  [7852900.]
# Fecha antes train:  2018-02-28
# Current Step antes train:  1249
# Fecha despues train:  2021-12-16
# Current Step despues train:  2337
# --------------Testing Point 3 of 50-----------------------------------
# Fecha Inicial:  2023-10-04
# Current Step Inicial:  2381
# Fecha Final:  2022-04-08
# Current Step Final:  2445
# Episode Step Final:  63
# Reward:  [8992092.]
# Fecha antes train:  2022-04-08
# Current Step antes train:  2445
# Fecha despues train:  2022-04-27
# Current Step despues train:  3533
# --------------Testing Point 4 of 50-----------------------------------
# Fecha Inicial:  2019-10-28
# Current Step Inicial:  3560
# Fecha Final:  2018-04-24
# Current Step Final:  3624
# Episode Step Final:  63
# Reward:  [572502.5]
# Fecha antes train:  2018-04-24
# Current Step antes train:  3624
# Fecha despues train:  2019-06-19
# Current Step despues train:  4712
# --------------Testing Point 5 of 50-----------------------------------
# Fecha Inicial:  2021-08-23
# Current Step Inicial:  4753
# Fecha Final:  2022-06-10
# Current Step Final:  4817
# Episode Step Final:  63
# Reward:  [9344623.]
# Fecha antes train:  2022-06-10
# Current Step antes train:  4817
# Fecha despues train:  2019-09-06
# Current Step despues train:  5905
# --------------Testing Point 6 of 50-----------------------------------
# Fecha Inicial:  2022-03-14
# Current Step Inicial:  5930
# Fecha Final:  2021-10-14
# Current Step Final:  5994
# Episode Step Final:  63
# Reward:  [2444610.]
# Fecha antes train:  2021-10-14
# Current Step antes train:  5994
# Fecha despues train:  2021-02-16
# Current Step despues train:  7082
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  7124
# Fecha Final:  2020-04-06
# Current Step Final:  7188
# Episode Step Final:  63
# Reward:  [2390513.2]
# Fecha antes train:  2020-04-06
# Current Step antes train:  7188
# Fecha despues train:  2020-07-02
# Current Step despues train:  8276
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  8321
# Fecha Final:  2023-02-06
# Current Step Final:  8385
# Episode Step Final:  63
# Reward:  [-2674305.5]
# Fecha antes train:  2023-02-06
# Current Step antes train:  8385
# Fecha despues train:  2019-10-24
# Current Step despues train:  9473
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  9482
# Fecha Final:  2023-04-20
# Current Step Final:  9538
# Episode Step Final:  55
# Reward:  [3071420.2]
# Fecha antes train:  2023-04-20
# Current Step antes train:  9538
# Fecha despues train:  2018-08-03
# Current Step despues train:  10626
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  10657
# Fecha Final:  2020-04-16
# Current Step Final:  10721
# Episode Step Final:  63
# Reward:  [2037905.8]
# Fecha antes train:  2020-04-16
# Current Step antes train:  10721
# Fecha despues train:  2021-09-08
# Current Step despues train:  11809
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  11847
# Fecha Final:  2021-01-07
# Current Step Final:  11911
# Episode Step Final:  63
# Reward:  [526111.7]
# Fecha antes train:  2021-01-07
# Current Step antes train:  11911
# Fecha despues train:  2022-09-23
# Current Step despues train:  12999
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  13039
# Fecha Final:  2018-03-26
# Current Step Final:  13103
# Episode Step Final:  63
# Reward:  [514514.5]
# Fecha antes train:  2018-03-26
# Current Step antes train:  13103
# Fecha despues train:  2020-02-24
# Current Step despues train:  14191
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  14242
# Fecha Final:  2023-01-31
# Current Step Final:  14306
# Episode Step Final:  63
# Reward:  [2994830.2]
# Fecha antes train:  2023-01-31
# Current Step antes train:  14306
# Fecha despues train:  2020-10-06
# Current Step despues train:  15394
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  15442
# Fecha Final:  2019-05-01
# Current Step Final:  15506
# Episode Step Final:  63
# Reward:  [2948553.2]
# Fecha antes train:  2019-05-01
# Current Step antes train:  15506
# Fecha despues train:  2023-12-20
# Current Step despues train:  16594
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  16624
# Fecha Final:  2020-08-25
# Current Step Final:  16680
# Episode Step Final:  55
# Reward:  [-6397843.]
# Fecha antes train:  2020-08-25
# Current Step antes train:  16680
# Fecha despues train:  2020-04-08
# Current Step despues train:  17768
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  17817
# Fecha Final:  2023-05-25
# Current Step Final:  17881
# Episode Step Final:  63
# Reward:  [-11739791.]
# Fecha antes train:  2023-05-25
# Current Step antes train:  17881
# Fecha despues train:  2019-09-17
# Current Step despues train:  18969
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  19003
# Fecha Final:  2023-02-02
# Current Step Final:  19067
# Episode Step Final:  63
# Reward:  [1143485.5]
# Fecha antes train:  2023-02-02
# Current Step antes train:  19067
# Fecha despues train:  2020-09-04
# Current Step despues train:  20155
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  20164
# Fecha Final:  2021-10-12
# Current Step Final:  20228
# Episode Step Final:  63
# Reward:  [13685522.]
# Fecha antes train:  2021-10-12
# Current Step antes train:  20228
# Fecha despues train:  2022-02-18
# Current Step despues train:  21316
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  21340
# Fecha Final:  2018-05-25
# Current Step Final:  21404
# Episode Step Final:  63
# Reward:  [-2783556.]
# Fecha antes train:  2018-05-25
# Current Step antes train:  21404
# Fecha despues train:  2020-06-17
# Current Step despues train:  22492
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  22534
# Fecha Final:  2022-10-03
# Current Step Final:  22598
# Episode Step Final:  63
# Reward:  [4410680.5]
# Fecha antes train:  2022-10-03
# Current Step antes train:  22598
# Fecha despues train:  2018-07-10
# Current Step despues train:  23686
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  23728
# Fecha Final:  2019-02-12
# Current Step Final:  23792
# Episode Step Final:  63
# Reward:  [2878552.]
# Fecha antes train:  2019-02-12
# Current Step antes train:  23792
# Fecha despues train:  2023-02-09
# Current Step despues train:  24880
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  24921
# Fecha Final:  2021-01-15
# Current Step Final:  24977
# Episode Step Final:  55
# Reward:  [-1054342.4]
# Fecha antes train:  2021-01-15
# Current Step antes train:  24977
# Fecha despues train:  2020-12-21
# Current Step despues train:  26065
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  26071
# Fecha Final:  2018-06-20
# Current Step Final:  26135
# Episode Step Final:  63
# Reward:  [1658418.]
# Fecha antes train:  2018-06-20
# Current Step antes train:  26135
# Fecha despues train:  2018-04-05
# Current Step despues train:  27223
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  27261
# Fecha Final:  2019-12-12
# Current Step Final:  27317
# Episode Step Final:  55
# Reward:  [4190960.2]
# Fecha antes train:  2019-12-12
# Current Step antes train:  27317
# Fecha despues train:  2020-07-15
# Current Step despues train:  28405
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  28459
# Fecha Final:  2020-02-26
# Current Step Final:  28523
# Episode Step Final:  63
# Reward:  [4225777.]
# Fecha antes train:  2020-02-26
# Current Step antes train:  28523
# Fecha despues train:  2023-06-30
# Current Step despues train:  29611
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  29651
# Fecha Final:  2018-11-05
# Current Step Final:  29715
# Episode Step Final:  63
# Reward:  [2646680.8]
# Fecha antes train:  2018-11-05
# Current Step antes train:  29715
# Fecha despues train:  2019-11-22
# Current Step despues train:  30803
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  30836
# Fecha Final:  2023-03-16
# Current Step Final:  30893
# Episode Step Final:  56
# Reward:  [3733046.2]
# Fecha antes train:  2023-03-16
# Current Step antes train:  30893
# Fecha despues train:  2020-06-08
# Current Step despues train:  31981
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  32038
# Fecha Final:  2022-11-28
# Current Step Final:  32102
# Episode Step Final:  63
# Reward:  [8935162.]
# Fecha antes train:  2022-11-28
# Current Step antes train:  32102
# Fecha despues train:  2020-07-14
# Current Step despues train:  33190
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  33237
# Fecha Final:  2021-03-23
# Current Step Final:  33293
# Episode Step Final:  55
# Reward:  [2782388.5]
# Fecha antes train:  2021-03-23
# Current Step antes train:  33293
# Fecha despues train:  2023-08-16
# Current Step despues train:  34381
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  34429
# Fecha Final:  2022-09-16
# Current Step Final:  34493
# Episode Step Final:  63
# Reward:  [-9534455.]
# Fecha antes train:  2022-09-16
# Current Step antes train:  34493
# Fecha despues train:  2019-06-25
# Current Step despues train:  35581
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  35614
# Fecha Final:  2020-02-20
# Current Step Final:  35678
# Episode Step Final:  63
# Reward:  [-7364744.]
# Fecha antes train:  2020-02-20
# Current Step antes train:  35678
# Fecha despues train:  2022-08-30
# Current Step despues train:  36766
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  36805
# Fecha Final:  2020-09-30
# Current Step Final:  36869
# Episode Step Final:  63
# Reward:  [1344783.4]
# Fecha antes train:  2020-09-30
# Current Step antes train:  36869
# Fecha despues train:  2020-05-14
# Current Step despues train:  37957
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  37986
# Fecha Final:  2023-04-17
# Current Step Final:  38050
# Episode Step Final:  63
# Reward:  [4578361.5]
# Fecha antes train:  2023-04-17
# Current Step antes train:  38050
# Fecha despues train:  2023-10-19
# Current Step despues train:  39138
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  39177
# Fecha Final:  2023-09-22
# Current Step Final:  39241
# Episode Step Final:  63
# Reward:  [-1744287.5]
# Fecha antes train:  2023-09-22
# Current Step antes train:  39241
# Fecha despues train:  2020-03-31
# Current Step despues train:  40329
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  40387
# Fecha Final:  2021-08-03
# Current Step Final:  40443
# Episode Step Final:  55
# Reward:  [-1141449.2]
# Fecha antes train:  2021-08-03
# Current Step antes train:  40443
# Fecha despues train:  2018-06-29
# Current Step despues train:  41531
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  41543
# Fecha Final:  2020-04-03
# Current Step Final:  41607
# Episode Step Final:  63
# Reward:  [6104539.]
# Fecha antes train:  2020-04-03
# Current Step antes train:  41607
# Fecha despues train:  2018-08-24
# Current Step despues train:  42695
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  42719
# Fecha Final:  2019-03-11
# Current Step Final:  42783
# Episode Step Final:  63
# Reward:  [-2969041.8]
# Fecha antes train:  2019-03-11
# Current Step antes train:  42783
# Fecha despues train:  2018-01-26
# Current Step despues train:  43871
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  43897
# Fecha Final:  2018-03-07
# Current Step Final:  43961
# Episode Step Final:  63
# Reward:  [-8904972.]
# Fecha antes train:  2018-03-07
# Current Step antes train:  43961
# Fecha despues train:  2020-04-24
# Current Step despues train:  45049
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  45087
# Fecha Final:  2019-01-02
# Current Step Final:  45151
# Episode Step Final:  63
# Reward:  [-4056245.8]
# Fecha antes train:  2019-01-02
# Current Step antes train:  45151
# Fecha despues train:  2020-03-24
# Current Step despues train:  46239
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  46282
# Fecha Final:  2020-06-01
# Current Step Final:  46344
# Episode Step Final:  61
# Reward:  [-37144.625]
# Fecha antes train:  2020-06-01
# Current Step antes train:  46344
# Fecha despues train:  2020-06-04
# Current Step despues train:  47432
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  47477
# Fecha Final:  2020-03-11
# Current Step Final:  47541
# Episode Step Final:  63
# Reward:  [6589384.5]
# Fecha antes train:  2020-03-11
# Current Step antes train:  47541
# Fecha despues train:  2019-06-21
# Current Step despues train:  48629
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  48663
# Fecha Final:  2022-05-23
# Current Step Final:  48727
# Episode Step Final:  63
# Reward:  [3116913.5]
# Fecha antes train:  2022-05-23
# Current Step antes train:  48727
# Fecha despues train:  2018-02-26
# Current Step despues train:  49815
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  49871
# Fecha Final:  2021-11-09
# Current Step Final:  49926
# Episode Step Final:  54
# Reward:  [2216412.5]
# Fecha antes train:  2021-11-09
# Current Step antes train:  49926
# Fecha despues train:  2023-10-06
# Current Step despues train:  51014
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  51075
# Fecha Final:  2020-07-22
# Current Step Final:  51137
# Episode Step Final:  61
# Reward:  [8004111.]
# Fecha antes train:  2020-07-22
# Current Step antes train:  51137
# Fecha despues train:  2018-08-09
# Current Step despues train:  52225
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  52247
# Fecha Final:  2023-06-21
# Current Step Final:  52303
# Episode Step Final:  55
# Reward:  [-4316439.]
# Fecha antes train:  2023-06-21
# Current Step antes train:  52303
# Fecha despues train:  2020-07-23
# Current Step despues train:  53391
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  53415
# Fecha Final:  2019-01-07
# Current Step Final:  53479
# Episode Step Final:  63
# Reward:  [3250253.5]
# Fecha antes train:  2019-01-07
# Current Step antes train:  53479
# Fecha despues train:  2023-03-24
# Current Step despues train:  54567
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  54602
# Fecha Final:  2019-04-01
# Current Step Final:  54658
# Episode Step Final:  55
# Reward:  [286937.3]
# Fecha antes train:  2019-04-01
# Current Step antes train:  54658
# Fecha despues train:  2019-02-25
# Current Step despues train:  55746
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  55787
# Fecha Final:  2020-06-09
# Current Step Final:  55843
# Episode Step Final:  55
# Reward:  [-4661966.5]
# Fecha antes train:  2020-06-09
# Current Step antes train:  55843
# Fecha despues train:  2018-10-05
# Current Step despues train:  56931
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  56954
# Fecha Final:  2018-09-13
# Current Step Final:  57018
# Episode Step Final:  63
# Reward:  [324206.4]
# Fecha antes train:  2018-09-13
# Current Step antes train:  57018
# Fecha despues train:  2019-07-17
# Current Step despues train:  58106
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  58146
# Fecha Final:  2018-05-07
# Current Step Final:  58202
# Episode Step Final:  55
# Reward:  [4654644.5]
# Fecha antes train:  2018-05-07
# Current Step antes train:  58202
# Fecha despues train:  2018-08-08
# Current Step despues train:  59290
# Done testing A2C Agent!
# Testing DDPG Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2019-05-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [5545893.]
# Fecha antes train:  2019-05-20
# Current Step antes train:  64
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 85       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 248      |
# | train/             |          |
# |    actor_loss      | 6.01e+04 |
# |    critic_loss     | 3.55e+10 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 71       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 496      |
# | train/             |          |
# |    actor_loss      | 8.61e+04 |
# |    critic_loss     | 7.34e+10 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 395      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 67       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 744      |
# ...
# Reward:  [-3192584.]
# Fecha antes train:  2021-10-14
# Current Step antes train:  5994
# Fecha despues train:  2021-02-16
# Current Step despues train:  7082
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  7124
# Fecha Final:  2020-04-06
# Current Step Final:  7188
# Episode Step Final:  63
# Reward:  [-2399554.]
# Fecha antes train:  2020-04-06
# Current Step antes train:  7188
# Fecha despues train:  2020-07-02
# Current Step despues train:  8276
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  8321
# Fecha Final:  2023-02-06
# Current Step Final:  8385
# Episode Step Final:  63
# Reward:  [1164631.4]
# Fecha antes train:  2023-02-06
# Current Step antes train:  8385
# Fecha despues train:  2019-10-24
# Current Step despues train:  9473
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  9482
# Fecha Final:  2023-04-20
# Current Step Final:  9538
# Episode Step Final:  55
# Reward:  [-6856052.]
# Fecha antes train:  2023-04-20
# Current Step antes train:  9538
# Fecha despues train:  2018-08-03
# Current Step despues train:  10626
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  10657
# Fecha Final:  2020-04-16
# Current Step Final:  10721
# Episode Step Final:  63
# Reward:  [7794193.5]
# Fecha antes train:  2020-04-16
# Current Step antes train:  10721
# Fecha despues train:  2021-09-08
# Current Step despues train:  11809
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  11847
# Fecha Final:  2021-01-07
# Current Step Final:  11911
# Episode Step Final:  63
# Reward:  [-2192020.5]
# Fecha antes train:  2021-01-07
# Current Step antes train:  11911
# Fecha despues train:  2022-09-23
# Current Step despues train:  12999
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  13039
# Fecha Final:  2018-03-26
# Current Step Final:  13103
# Episode Step Final:  63
# Reward:  [1816990.8]
# Fecha antes train:  2018-03-26
# Current Step antes train:  13103
# Fecha despues train:  2020-02-24
# Current Step despues train:  14191
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  14242
# Fecha Final:  2023-01-31
# Current Step Final:  14306
# Episode Step Final:  63
# Reward:  [697276.44]
# Fecha antes train:  2023-01-31
# Current Step antes train:  14306
# Fecha despues train:  2020-10-06
# Current Step despues train:  15394
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  15442
# Fecha Final:  2019-05-01
# Current Step Final:  15506
# Episode Step Final:  63
# Reward:  [8140890.5]
# Fecha antes train:  2019-05-01
# Current Step antes train:  15506
# Fecha despues train:  2023-12-20
# Current Step despues train:  16594
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  16624
# Fecha Final:  2020-08-25
# Current Step Final:  16680
# Episode Step Final:  55
# Reward:  [428059.38]
# Fecha antes train:  2020-08-25
# Current Step antes train:  16680
# Fecha despues train:  2020-04-08
# Current Step despues train:  17768
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  17817
# Fecha Final:  2023-05-25
# Current Step Final:  17881
# Episode Step Final:  63
# Reward:  [-3795648.8]
# Fecha antes train:  2023-05-25
# Current Step antes train:  17881
# Fecha despues train:  2019-09-17
# Current Step despues train:  18969
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  19003
# Fecha Final:  2023-02-02
# Current Step Final:  19067
# Episode Step Final:  63
# Reward:  [-1029997.2]
# Fecha antes train:  2023-02-02
# Current Step antes train:  19067
# Fecha despues train:  2020-09-04
# Current Step despues train:  20155
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  20164
# Fecha Final:  2021-10-12
# Current Step Final:  20228
# Episode Step Final:  63
# Reward:  [9608768.]
# Fecha antes train:  2021-10-12
# Current Step antes train:  20228
# Fecha despues train:  2022-02-18
# Current Step despues train:  21316
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  21340
# Fecha Final:  2018-05-25
# Current Step Final:  21404
# Episode Step Final:  63
# Reward:  [-1355889.5]
# Fecha antes train:  2018-05-25
# Current Step antes train:  21404
# Fecha despues train:  2020-06-17
# Current Step despues train:  22492
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  22534
# Fecha Final:  2022-10-03
# Current Step Final:  22598
# Episode Step Final:  63
# Reward:  [-357010.25]
# Fecha antes train:  2022-10-03
# Current Step antes train:  22598
# Fecha despues train:  2018-07-10
# Current Step despues train:  23686
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  23728
# Fecha Final:  2019-02-12
# Current Step Final:  23792
# Episode Step Final:  63
# Reward:  [8072215.]
# Fecha antes train:  2019-02-12
# Current Step antes train:  23792
# Fecha despues train:  2023-02-09
# Current Step despues train:  24880
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  24921
# Fecha Final:  2021-01-15
# Current Step Final:  24977
# Episode Step Final:  55
# Reward:  [3719289.2]
# Fecha antes train:  2021-01-15
# Current Step antes train:  24977
# Fecha despues train:  2020-12-21
# Current Step despues train:  26065
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  26071
# Fecha Final:  2018-06-20
# Current Step Final:  26135
# Episode Step Final:  63
# Reward:  [5747735.5]
# Fecha antes train:  2018-06-20
# Current Step antes train:  26135
# Fecha despues train:  2018-04-05
# Current Step despues train:  27223
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  27261
# Fecha Final:  2019-12-12
# Current Step Final:  27317
# Episode Step Final:  55
# Reward:  [2509542.5]
# Fecha antes train:  2019-12-12
# Current Step antes train:  27317
# Fecha despues train:  2020-07-15
# Current Step despues train:  28405
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  28459
# Fecha Final:  2020-02-26
# Current Step Final:  28523
# Episode Step Final:  63
# Reward:  [4975915.]
# Fecha antes train:  2020-02-26
# Current Step antes train:  28523
# Fecha despues train:  2023-06-30
# Current Step despues train:  29611
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  29651
# Fecha Final:  2018-11-05
# Current Step Final:  29715
# Episode Step Final:  63
# Reward:  [3995688.5]
# Fecha antes train:  2018-11-05
# Current Step antes train:  29715
# Fecha despues train:  2019-11-22
# Current Step despues train:  30803
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  30836
# Fecha Final:  2023-03-16
# Current Step Final:  30893
# Episode Step Final:  56
# Reward:  [-2383743.]
# Fecha antes train:  2023-03-16
# Current Step antes train:  30893
# Fecha despues train:  2020-06-08
# Current Step despues train:  31981
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  32038
# Fecha Final:  2022-11-28
# Current Step Final:  32102
# Episode Step Final:  63
# Reward:  [11429834.]
# Fecha antes train:  2022-11-28
# Current Step antes train:  32102
# Fecha despues train:  2020-07-14
# Current Step despues train:  33190
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  33237
# Fecha Final:  2021-03-23
# Current Step Final:  33293
# Episode Step Final:  55
# Reward:  [-941465.44]
# Fecha antes train:  2021-03-23
# Current Step antes train:  33293
# Fecha despues train:  2023-08-16
# Current Step despues train:  34381
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  34429
# Fecha Final:  2022-09-16
# Current Step Final:  34493
# Episode Step Final:  63
# Reward:  [-18974904.]
# Fecha antes train:  2022-09-16
# Current Step antes train:  34493
# Fecha despues train:  2019-06-25
# Current Step despues train:  35581
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  35614
# Fecha Final:  2020-02-20
# Current Step Final:  35678
# Episode Step Final:  63
# Reward:  [1588916.5]
# Fecha antes train:  2020-02-20
# Current Step antes train:  35678
# Fecha despues train:  2022-08-30
# Current Step despues train:  36766
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  36805
# Fecha Final:  2020-09-30
# Current Step Final:  36869
# Episode Step Final:  63
# Reward:  [496266.25]
# Fecha antes train:  2020-09-30
# Current Step antes train:  36869
# Fecha despues train:  2020-05-14
# Current Step despues train:  37957
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  37986
# Fecha Final:  2023-04-17
# Current Step Final:  38050
# Episode Step Final:  63
# Reward:  [4171823.8]
# Fecha antes train:  2023-04-17
# Current Step antes train:  38050
# Fecha despues train:  2023-10-19
# Current Step despues train:  39138
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  39177
# Fecha Final:  2023-09-22
# Current Step Final:  39241
# Episode Step Final:  63
# Reward:  [2604603.5]
# Fecha antes train:  2023-09-22
# Current Step antes train:  39241
# Fecha despues train:  2020-03-31
# Current Step despues train:  40329
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  40387
# Fecha Final:  2021-08-03
# Current Step Final:  40443
# Episode Step Final:  55
# Reward:  [-2403659.8]
# Fecha antes train:  2021-08-03
# Current Step antes train:  40443
# Fecha despues train:  2018-06-29
# Current Step despues train:  41531
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  41543
# Fecha Final:  2020-04-03
# Current Step Final:  41607
# Episode Step Final:  63
# Reward:  [8263924.]
# Fecha antes train:  2020-04-03
# Current Step antes train:  41607
# Fecha despues train:  2018-08-24
# Current Step despues train:  42695
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  42719
# Fecha Final:  2019-03-11
# Current Step Final:  42783
# Episode Step Final:  63
# Reward:  [2230146.8]
# Fecha antes train:  2019-03-11
# Current Step antes train:  42783
# Fecha despues train:  2018-01-26
# Current Step despues train:  43871
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  43897
# Fecha Final:  2018-03-07
# Current Step Final:  43961
# Episode Step Final:  63
# Reward:  [-9140808.]
# Fecha antes train:  2018-03-07
# Current Step antes train:  43961
# Fecha despues train:  2020-04-24
# Current Step despues train:  45049
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  45087
# Fecha Final:  2019-01-02
# Current Step Final:  45151
# Episode Step Final:  63
# Reward:  [-1317623.]
# Fecha antes train:  2019-01-02
# Current Step antes train:  45151
# Fecha despues train:  2020-03-24
# Current Step despues train:  46239
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  46282
# Fecha Final:  2020-06-01
# Current Step Final:  46344
# Episode Step Final:  61
# Reward:  [152303.19]
# Fecha antes train:  2020-06-01
# Current Step antes train:  46344
# Fecha despues train:  2020-06-04
# Current Step despues train:  47432
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  47477
# Fecha Final:  2020-03-11
# Current Step Final:  47541
# Episode Step Final:  63
# Reward:  [4754847.]
# Fecha antes train:  2020-03-11
# Current Step antes train:  47541
# Fecha despues train:  2019-06-21
# Current Step despues train:  48629
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  48663
# Fecha Final:  2022-05-23
# Current Step Final:  48727
# Episode Step Final:  63
# Reward:  [3494635.2]
# Fecha antes train:  2022-05-23
# Current Step antes train:  48727
# Fecha despues train:  2018-02-26
# Current Step despues train:  49815
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  49871
# Fecha Final:  2021-11-09
# Current Step Final:  49926
# Episode Step Final:  54
# Reward:  [6593130.5]
# Fecha antes train:  2021-11-09
# Current Step antes train:  49926
# Fecha despues train:  2023-10-06
# Current Step despues train:  51014
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  51075
# Fecha Final:  2020-07-22
# Current Step Final:  51137
# Episode Step Final:  61
# Reward:  [-384114.06]
# Fecha antes train:  2020-07-22
# Current Step antes train:  51137
# Fecha despues train:  2018-08-09
# Current Step despues train:  52225
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  52247
# Fecha Final:  2023-06-21
# Current Step Final:  52303
# Episode Step Final:  55
# Reward:  [-1945772.8]
# Fecha antes train:  2023-06-21
# Current Step antes train:  52303
# Fecha despues train:  2020-07-23
# Current Step despues train:  53391
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  53415
# Fecha Final:  2019-01-07
# Current Step Final:  53479
# Episode Step Final:  63
# Reward:  [13680077.]
# Fecha antes train:  2019-01-07
# Current Step antes train:  53479
# Fecha despues train:  2023-03-24
# Current Step despues train:  54567
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  54602
# Fecha Final:  2019-04-01
# Current Step Final:  54658
# Episode Step Final:  55
# Reward:  [-2876887.2]
# Fecha antes train:  2019-04-01
# Current Step antes train:  54658
# Fecha despues train:  2019-02-25
# Current Step despues train:  55746
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  55787
# Fecha Final:  2020-06-09
# Current Step Final:  55843
# Episode Step Final:  55
# Reward:  [-10752803.]
# Fecha antes train:  2020-06-09
# Current Step antes train:  55843
# Fecha despues train:  2018-10-05
# Current Step despues train:  56931
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  56954
# Fecha Final:  2018-09-13
# Current Step Final:  57018
# Episode Step Final:  63
# Reward:  [2436624.]
# Fecha antes train:  2018-09-13
# Current Step antes train:  57018
# Fecha despues train:  2019-07-17
# Current Step despues train:  58106
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  58146
# Fecha Final:  2018-05-07
# Current Step Final:  58202
# Episode Step Final:  55
# Reward:  [5888913.]
# Fecha antes train:  2018-05-07
# Current Step antes train:  58202
# Fecha despues train:  2018-08-08
# Current Step despues train:  59290
# Done testing SP500 Agent!
# --------------------------------------------------
# All agents tested!
# --------------------------------------------------

# %%
from datetime import datetime
# Step0: Lista de fechas de los testing points
date_list = metrics_resume['SP500 Agent']['dates'] 
date_list = [datetime.strptime(date, "%Y-%m-%d").date() for date in date_list]
# Step1: Filter training data by the dates of the testing points
def filter_data_for_testing(data, date_list):
    filtered_data = {}
    for ticker, df in data.items():
        normalized_index = df.index.normalize()
        index_dates = pd.Series(normalized_index.date, index=df.index)
        filtered_df = df.loc[index_dates.isin(date_list)]
        nonsense_timestamp = pd.Timestamp('9999-12-31 23:59:59-04:00')
        placeholder_data = {
            'Open': 1,
            'High': 1,
            'Low': 1,
            'Close': 1,
            'Volume': 1,
            'MACD': 1,
            'Signal': 1,
            'RSI': 1,
            'CCI': 1,
            'ADX': 1
        }
        placeholder_row = pd.DataFrame([placeholder_data], index=[nonsense_timestamp])
        filtered_data[ticker] = pd.concat([filtered_df, placeholder_row])
    return filtered_data

testing_data = filter_data_for_testing(shuffleDS, date_list)
benchmark_testing_data = testing_data['SP500']
# Step2: Create a new environment with the filtered data
env_testing = DummyVecEnv([lambda: StockTradingEnv(testing_data, benchmark_testing_data, return_memory_size=5)])
# Step3: Test the best/last agents with the new environment
start_testing_time = time.time()
metrics_resume_testing, _ , _ = getResumeMetrics(env_testing, trained_agents, n_total_episodes=N_TOTAL_EPISODES, testing_points=TESTING_POINTS, just_test=True)
end_testing_time = time.time()
metadata['testing_time'] = (end_testing_time - start_testing_time) / 60
# Out:
# Stock data has been loaded for 22 stocks.
# The tickers are: ['AAPL', 'ABCB', 'CSCO', 'DAL', 'EAST', 'ESPR', 'F', 'GOOGL', 'JPM', 'META', 'MSFT', 'NVDA', 'PFE', 'PG', 'PSX', 'SGLY', 'SP500', 'TSLA', 'UNH', 'USA', 'WMT', 'XOM']
# Testing PPO Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2021-01-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-577807.25]
# --------------Testing Point 2 of 50-----------------------------------
# Fecha Inicial:  2021-01-20
# Current Step Inicial:  64
# Fecha Final:  2023-10-04
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [3308205.]
# --------------Testing Point 3 of 50-----------------------------------
# Fecha Inicial:  2023-10-04
# Current Step Inicial:  128
# Fecha Final:  2019-10-28
# Current Step Final:  192
# Episode Step Final:  63
# Reward:  [-2688858.]
# --------------Testing Point 4 of 50-----------------------------------
# Fecha Inicial:  2019-10-28
# Current Step Inicial:  192
# Fecha Final:  2021-08-23
# Current Step Final:  256
# Episode Step Final:  63
# Reward:  [3937099.2]
# --------------Testing Point 5 of 50-----------------------------------
# Fecha Inicial:  2021-08-23
# Current Step Inicial:  256
# Fecha Final:  2022-03-14
# Current Step Final:  320
# Episode Step Final:  63
# Reward:  [8149013.]
# --------------Testing Point 6 of 50-----------------------------------
# Fecha Inicial:  2022-03-14
# Current Step Inicial:  320
# Fecha Final:  2021-03-30
# Current Step Final:  384
# Episode Step Final:  63
# Reward:  [-1266351.4]
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  384
# Fecha Final:  2023-03-22
# Current Step Final:  448
# Episode Step Final:  63
# Reward:  [-5607009.5]
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  448
# Fecha Final:  2021-09-17
# Current Step Final:  512
# Episode Step Final:  63
# Reward:  [1073075.5]
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  512
# Fecha Final:  2021-06-30
# Current Step Final:  568
# Episode Step Final:  55
# Reward:  [-7287859.5]
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  568
# Fecha Final:  2023-07-26
# Current Step Final:  632
# Episode Step Final:  63
# Reward:  [2757548.2]
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  632
# Fecha Final:  2023-07-31
# Current Step Final:  696
# Episode Step Final:  63
# Reward:  [-2719269.]
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  696
# Fecha Final:  2023-02-22
# Current Step Final:  760
# Episode Step Final:  63
# Reward:  [-2030064.]
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  760
# Fecha Final:  2020-08-26
# Current Step Final:  824
# Episode Step Final:  63
# Reward:  [-2384434.2]
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  824
# Fecha Final:  2021-02-05
# Current Step Final:  888
# Episode Step Final:  63
# Reward:  [1468554.]
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  888
# Fecha Final:  2020-09-08
# Current Step Final:  944
# Episode Step Final:  55
# Reward:  [-494627.75]
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  944
# Fecha Final:  2019-05-29
# Current Step Final:  1008
# Episode Step Final:  63
# Reward:  [-5107528.]
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  1008
# Fecha Final:  2020-01-13
# Current Step Final:  1072
# Episode Step Final:  63
# Reward:  [-810019.4]
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  1072
# Fecha Final:  2023-05-04
# Current Step Final:  1136
# Episode Step Final:  63
# Reward:  [5136110.5]
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  1136
# Fecha Final:  2023-11-17
# Current Step Final:  1200
# Episode Step Final:  63
# Reward:  [-354476.8]
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  1200
# Fecha Final:  2020-09-28
# Current Step Final:  1264
# Episode Step Final:  63
# Reward:  [5609528.]
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  1264
# Fecha Final:  2020-07-17
# Current Step Final:  1328
# Episode Step Final:  63
# Reward:  [5796924.]
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  1328
# Fecha Final:  2018-05-23
# Current Step Final:  1384
# Episode Step Final:  55
# Reward:  [-4739979.]
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  1384
# Fecha Final:  2020-06-05
# Current Step Final:  1448
# Episode Step Final:  63
# Reward:  [4655780.]
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  1448
# Fecha Final:  2019-07-02
# Current Step Final:  1504
# Episode Step Final:  55
# Reward:  [7986100.]
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  1504
# Fecha Final:  2022-09-01
# Current Step Final:  1568
# Episode Step Final:  63
# Reward:  [2249470.8]
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  1568
# Fecha Final:  2021-05-28
# Current Step Final:  1632
# Episode Step Final:  63
# Reward:  [1010468.75]
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  1632
# Fecha Final:  2022-02-01
# Current Step Final:  1689
# Episode Step Final:  56
# Reward:  [-2274669.5]
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  1689
# Fecha Final:  2020-12-18
# Current Step Final:  1753
# Episode Step Final:  63
# Reward:  [-489845.28]
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  1753
# Fecha Final:  2020-09-03
# Current Step Final:  1809
# Episode Step Final:  55
# Reward:  [-231346.94]
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  1809
# Fecha Final:  2021-11-17
# Current Step Final:  1873
# Episode Step Final:  63
# Reward:  [-9172857.]
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  1873
# Fecha Final:  2018-06-04
# Current Step Final:  1937
# Episode Step Final:  63
# Reward:  [-1416740.8]
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  1937
# Fecha Final:  2019-10-14
# Current Step Final:  2001
# Episode Step Final:  63
# Reward:  [-927804.1]
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  2001
# Fecha Final:  2022-06-22
# Current Step Final:  2065
# Episode Step Final:  63
# Reward:  [5615496.5]
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  2065
# Fecha Final:  2021-02-26
# Current Step Final:  2129
# Episode Step Final:  63
# Reward:  [-1476755.2]
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  2129
# Fecha Final:  2022-11-10
# Current Step Final:  2185
# Episode Step Final:  55
# Reward:  [-6195142.]
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  2185
# Fecha Final:  2020-02-06
# Current Step Final:  2249
# Episode Step Final:  63
# Reward:  [4900209.5]
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  2249
# Fecha Final:  2022-01-20
# Current Step Final:  2313
# Episode Step Final:  63
# Reward:  [-49574.406]
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  2313
# Fecha Final:  2022-07-26
# Current Step Final:  2377
# Episode Step Final:  63
# Reward:  [-7236700.]
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  2377
# Fecha Final:  2022-05-12
# Current Step Final:  2441
# Episode Step Final:  63
# Reward:  [1648906.5]
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  2441
# Fecha Final:  2020-08-24
# Current Step Final:  2503
# Episode Step Final:  61
# Reward:  [-2157630.5]
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  2503
# Fecha Final:  2019-02-19
# Current Step Final:  2567
# Episode Step Final:  63
# Reward:  [1609091.2]
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  2567
# Fecha Final:  2019-04-26
# Current Step Final:  2631
# Episode Step Final:  63
# Reward:  [2097081.]
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  2631
# Fecha Final:  2019-10-17
# Current Step Final:  2686
# Episode Step Final:  54
# Reward:  [6615574.]
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  2686
# Fecha Final:  2022-05-06
# Current Step Final:  2748
# Episode Step Final:  61
# Reward:  [6360842.5]
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  2748
# Fecha Final:  2020-07-30
# Current Step Final:  2804
# Episode Step Final:  55
# Reward:  [-1987985.4]
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  2804
# Fecha Final:  2020-02-14
# Current Step Final:  2868
# Episode Step Final:  63
# Reward:  [-5216456.5]
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  2868
# Fecha Final:  2020-01-24
# Current Step Final:  2924
# Episode Step Final:  55
# Reward:  [-3555243.]
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  2924
# Fecha Final:  2023-06-28
# Current Step Final:  2980
# Episode Step Final:  55
# Reward:  [-10384633.]
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  2980
# Fecha Final:  2021-03-12
# Current Step Final:  3044
# Episode Step Final:  63
# Reward:  [-814284.5]
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  3044
# Fecha Final:  9999-12-31
# Current Step Final:  3100
# Episode Step Final:  55
# Reward:  [6479878.5]
# Done testing PPO Agent!
# Testing A2C Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2021-01-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [3330658.]
# --------------Testing Point 2 of 50-----------------------------------
# Fecha Inicial:  2021-01-20
# Current Step Inicial:  64
# Fecha Final:  2023-10-04
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [14253482.]
# --------------Testing Point 3 of 50-----------------------------------
# Fecha Inicial:  2023-10-04
# Current Step Inicial:  128
# Fecha Final:  2019-10-28
# Current Step Final:  192
# Episode Step Final:  63
# Reward:  [2234505.2]
# --------------Testing Point 4 of 50-----------------------------------
# Fecha Inicial:  2019-10-28
# Current Step Inicial:  192
# Fecha Final:  2021-08-23
# Current Step Final:  256
# Episode Step Final:  63
# Reward:  [4106145.5]
# --------------Testing Point 5 of 50-----------------------------------
# Fecha Inicial:  2021-08-23
# Current Step Inicial:  256
# Fecha Final:  2022-03-14
# Current Step Final:  320
# Episode Step Final:  63
# Reward:  [7862405.]
# --------------Testing Point 6 of 50-----------------------------------
# Fecha Inicial:  2022-03-14
# Current Step Inicial:  320
# Fecha Final:  2021-03-30
# Current Step Final:  384
# Episode Step Final:  63
# Reward:  [820492.4]
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  384
# Fecha Final:  2023-03-22
# Current Step Final:  448
# Episode Step Final:  63
# Reward:  [1917190.8]
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  448
# Fecha Final:  2021-09-17
# Current Step Final:  512
# Episode Step Final:  63
# Reward:  [9452113.]
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  512
# Fecha Final:  2021-06-30
# Current Step Final:  568
# Episode Step Final:  55
# Reward:  [-4138063.5]
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  568
# Fecha Final:  2023-07-26
# Current Step Final:  632
# Episode Step Final:  63
# Reward:  [3753432.2]
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  632
# Fecha Final:  2023-07-31
# Current Step Final:  696
# Episode Step Final:  63
# Reward:  [1952436.5]
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  696
# Fecha Final:  2023-02-22
# Current Step Final:  760
# Episode Step Final:  63
# Reward:  [6609716.]
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  760
# Fecha Final:  2020-08-26
# Current Step Final:  824
# Episode Step Final:  63
# Reward:  [-222185.4]
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  824
# Fecha Final:  2021-02-05
# Current Step Final:  888
# Episode Step Final:  63
# Reward:  [-5140314.5]
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  888
# Fecha Final:  2020-09-08
# Current Step Final:  944
# Episode Step Final:  55
# Reward:  [998611.8]
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  944
# Fecha Final:  2019-05-29
# Current Step Final:  1008
# Episode Step Final:  63
# Reward:  [-10451033.]
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  1008
# Fecha Final:  2020-01-13
# Current Step Final:  1072
# Episode Step Final:  63
# Reward:  [101948.484]
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  1072
# Fecha Final:  2023-05-04
# Current Step Final:  1136
# Episode Step Final:  63
# Reward:  [1173322.4]
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  1136
# Fecha Final:  2023-11-17
# Current Step Final:  1200
# Episode Step Final:  63
# Reward:  [2363412.2]
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  1200
# Fecha Final:  2020-09-28
# Current Step Final:  1264
# Episode Step Final:  63
# Reward:  [-1762508.8]
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  1264
# Fecha Final:  2020-07-17
# Current Step Final:  1328
# Episode Step Final:  63
# Reward:  [7358795.]
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  1328
# Fecha Final:  2018-05-23
# Current Step Final:  1384
# Episode Step Final:  55
# Reward:  [-599887.56]
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  1384
# Fecha Final:  2020-06-05
# Current Step Final:  1448
# Episode Step Final:  63
# Reward:  [5071632.5]
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  1448
# Fecha Final:  2019-07-02
# Current Step Final:  1504
# Episode Step Final:  55
# Reward:  [8244019.5]
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  1504
# Fecha Final:  2022-09-01
# Current Step Final:  1568
# Episode Step Final:  63
# Reward:  [218506.25]
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  1568
# Fecha Final:  2021-05-28
# Current Step Final:  1632
# Episode Step Final:  63
# Reward:  [4630478.]
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  1632
# Fecha Final:  2022-02-01
# Current Step Final:  1689
# Episode Step Final:  56
# Reward:  [-3523057.2]
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  1689
# Fecha Final:  2020-12-18
# Current Step Final:  1753
# Episode Step Final:  63
# Reward:  [10634583.]
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  1753
# Fecha Final:  2020-09-03
# Current Step Final:  1809
# Episode Step Final:  55
# Reward:  [-6549608.]
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  1809
# Fecha Final:  2021-11-17
# Current Step Final:  1873
# Episode Step Final:  63
# Reward:  [-11582711.]
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  1873
# Fecha Final:  2018-06-04
# Current Step Final:  1937
# Episode Step Final:  63
# Reward:  [-5064549.]
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  1937
# Fecha Final:  2019-10-14
# Current Step Final:  2001
# Episode Step Final:  63
# Reward:  [934567.]
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  2001
# Fecha Final:  2022-06-22
# Current Step Final:  2065
# Episode Step Final:  63
# Reward:  [2108079.2]
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  2065
# Fecha Final:  2021-02-26
# Current Step Final:  2129
# Episode Step Final:  63
# Reward:  [-3913985.2]
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  2129
# Fecha Final:  2022-11-10
# Current Step Final:  2185
# Episode Step Final:  55
# Reward:  [885214.3]
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  2185
# Fecha Final:  2020-02-06
# Current Step Final:  2249
# Episode Step Final:  63
# Reward:  [16590715.]
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  2249
# Fecha Final:  2022-01-20
# Current Step Final:  2313
# Episode Step Final:  63
# Reward:  [-3809784.]
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  2313
# Fecha Final:  2022-07-26
# Current Step Final:  2377
# Episode Step Final:  63
# Reward:  [-13567857.]
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  2377
# Fecha Final:  2022-05-12
# Current Step Final:  2441
# Episode Step Final:  63
# Reward:  [462403.66]
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  2441
# Fecha Final:  2020-08-24
# Current Step Final:  2503
# Episode Step Final:  61
# Reward:  [1464522.8]
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  2503
# Fecha Final:  2019-02-19
# Current Step Final:  2567
# Episode Step Final:  63
# Reward:  [361777.66]
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  2567
# Fecha Final:  2019-04-26
# Current Step Final:  2631
# Episode Step Final:  63
# Reward:  [6560242.]
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  2631
# Fecha Final:  2019-10-17
# Current Step Final:  2686
# Episode Step Final:  54
# Reward:  [6888746.]
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  2686
# Fecha Final:  2022-05-06
# Current Step Final:  2748
# Episode Step Final:  61
# Reward:  [5262256.5]
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  2748
# Fecha Final:  2020-07-30
# Current Step Final:  2804
# Episode Step Final:  55
# Reward:  [-10798948.]
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  2804
# Fecha Final:  2020-02-14
# Current Step Final:  2868
# Episode Step Final:  63
# Reward:  [1055029.9]
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  2868
# Fecha Final:  2020-01-24
# Current Step Final:  2924
# Episode Step Final:  55
# Reward:  [-1586767.6]
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  2924
# Fecha Final:  2023-06-28
# Current Step Final:  2980
# Episode Step Final:  55
# Reward:  [-4652578.]
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  2980
# Fecha Final:  2021-03-12
# Current Step Final:  3044
# Episode Step Final:  63
# Reward:  [10249340.]
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  3044
# Fecha Final:  9999-12-31
# Current Step Final:  3100
# Episode Step Final:  55
# Reward:  [9142068.]
# Done testing A2C Agent!
# Testing DDPG Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2021-01-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-1241980.]
# --------------Testing Point 2 of 50-----------------------------------
# Fecha Inicial:  2021-01-20
# Current Step Inicial:  64
# Fecha Final:  2023-10-04
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [2038470.]
# --------------Testing Point 3 of 50-----------------------------------
# Fecha Inicial:  2023-10-04
# Current Step Inicial:  128
# Fecha Final:  2019-10-28
# Current Step Final:  192
# Episode Step Final:  63
# Reward:  [-1564543.8]
# --------------Testing Point 4 of 50-----------------------------------
# Fecha Inicial:  2019-10-28
# Current Step Inicial:  192
# Fecha Final:  2021-08-23
# Current Step Final:  256
# Episode Step Final:  63
# Reward:  [-1531092.2]
# --------------Testing Point 5 of 50-----------------------------------
# Fecha Inicial:  2021-08-23
# Current Step Inicial:  256
# Fecha Final:  2022-03-14
# Current Step Final:  320
# Episode Step Final:  63
# Reward:  [1018579.4]
# --------------Testing Point 6 of 50-----------------------------------
# Fecha Inicial:  2022-03-14
# Current Step Inicial:  320
# Fecha Final:  2021-03-30
# Current Step Final:  384
# Episode Step Final:  63
# Reward:  [-2349815.5]
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  384
# Fecha Final:  2023-03-22
# Current Step Final:  448
# Episode Step Final:  63
# Reward:  [-1611563.4]
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  448
# Fecha Final:  2021-09-17
# Current Step Final:  512
# Episode Step Final:  63
# Reward:  [-3933962.5]
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  512
# Fecha Final:  2021-06-30
# Current Step Final:  568
# Episode Step Final:  55
# Reward:  [-5901600.]
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  568
# Fecha Final:  2023-07-26
# Current Step Final:  632
# Episode Step Final:  63
# Reward:  [2733659.2]
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  632
# Fecha Final:  2023-07-31
# Current Step Final:  696
# Episode Step Final:  63
# Reward:  [-1348070.2]
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  696
# Fecha Final:  2023-02-22
# Current Step Final:  760
# Episode Step Final:  63
# Reward:  [-561130.44]
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  760
# Fecha Final:  2020-08-26
# Current Step Final:  824
# Episode Step Final:  63
# Reward:  [2033871.]
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  824
# Fecha Final:  2021-02-05
# Current Step Final:  888
# Episode Step Final:  63
# Reward:  [2531386.5]
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  888
# Fecha Final:  2020-09-08
# Current Step Final:  944
# Episode Step Final:  55
# Reward:  [4866987.]
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  944
# Fecha Final:  2019-05-29
# Current Step Final:  1008
# Episode Step Final:  63
# Reward:  [-2498903.5]
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  1008
# Fecha Final:  2020-01-13
# Current Step Final:  1072
# Episode Step Final:  63
# Reward:  [-2043148.9]
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  1072
# Fecha Final:  2023-05-04
# Current Step Final:  1136
# Episode Step Final:  63
# Reward:  [8703456.]
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  1136
# Fecha Final:  2023-11-17
# Current Step Final:  1200
# Episode Step Final:  63
# Reward:  [-3810726.]
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  1200
# Fecha Final:  2020-09-28
# Current Step Final:  1264
# Episode Step Final:  63
# Reward:  [-2612002.5]
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  1264
# Fecha Final:  2020-07-17
# Current Step Final:  1328
# Episode Step Final:  63
# Reward:  [6881007.]
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  1328
# Fecha Final:  2018-05-23
# Current Step Final:  1384
# Episode Step Final:  55
# Reward:  [7589962.]
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  1384
# Fecha Final:  2020-06-05
# Current Step Final:  1448
# Episode Step Final:  63
# Reward:  [-342656.]
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  1448
# Fecha Final:  2019-07-02
# Current Step Final:  1504
# Episode Step Final:  55
# Reward:  [1041057.2]
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  1504
# Fecha Final:  2022-09-01
# Current Step Final:  1568
# Episode Step Final:  63
# Reward:  [10100355.]
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  1568
# Fecha Final:  2021-05-28
# Current Step Final:  1632
# Episode Step Final:  63
# Reward:  [5295114.]
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  1632
# Fecha Final:  2022-02-01
# Current Step Final:  1689
# Episode Step Final:  56
# Reward:  [-910468.25]
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  1689
# Fecha Final:  2020-12-18
# Current Step Final:  1753
# Episode Step Final:  63
# Reward:  [-1999546.4]
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  1753
# Fecha Final:  2020-09-03
# Current Step Final:  1809
# Episode Step Final:  55
# Reward:  [5544601.5]
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  1809
# Fecha Final:  2021-11-17
# Current Step Final:  1873
# Episode Step Final:  63
# Reward:  [-5595443.5]
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  1873
# Fecha Final:  2018-06-04
# Current Step Final:  1937
# Episode Step Final:  63
# Reward:  [-2693900.5]
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  1937
# Fecha Final:  2019-10-14
# Current Step Final:  2001
# Episode Step Final:  63
# Reward:  [291203.2]
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  2001
# Fecha Final:  2022-06-22
# Current Step Final:  2065
# Episode Step Final:  63
# Reward:  [-4080112.5]
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  2065
# Fecha Final:  2021-02-26
# Current Step Final:  2129
# Episode Step Final:  63
# Reward:  [-2267066.8]
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  2129
# Fecha Final:  2022-11-10
# Current Step Final:  2185
# Episode Step Final:  55
# Reward:  [-2185318.5]
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  2185
# Fecha Final:  2020-02-06
# Current Step Final:  2249
# Episode Step Final:  63
# Reward:  [6907727.5]
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  2249
# Fecha Final:  2022-01-20
# Current Step Final:  2313
# Episode Step Final:  63
# Reward:  [2435875.8]
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  2313
# Fecha Final:  2022-07-26
# Current Step Final:  2377
# Episode Step Final:  63
# Reward:  [-4074343.8]
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  2377
# Fecha Final:  2022-05-12
# Current Step Final:  2441
# Episode Step Final:  63
# Reward:  [-4413653.5]
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  2441
# Fecha Final:  2020-08-24
# Current Step Final:  2503
# Episode Step Final:  61
# Reward:  [-1249290.6]
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  2503
# Fecha Final:  2019-02-19
# Current Step Final:  2567
# Episode Step Final:  63
# Reward:  [-2859080.8]
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  2567
# Fecha Final:  2019-04-26
# Current Step Final:  2631
# Episode Step Final:  63
# Reward:  [-726623.9]
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  2631
# Fecha Final:  2019-10-17
# Current Step Final:  2686
# Episode Step Final:  54
# Reward:  [-2724539.5]
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  2686
# Fecha Final:  2022-05-06
# Current Step Final:  2748
# Episode Step Final:  61
# Reward:  [4428142.5]
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  2748
# Fecha Final:  2020-07-30
# Current Step Final:  2804
# Episode Step Final:  55
# Reward:  [-2084820.4]
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  2804
# Fecha Final:  2020-02-14
# Current Step Final:  2868
# Episode Step Final:  63
# Reward:  [2974565.2]
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  2868
# Fecha Final:  2020-01-24
# Current Step Final:  2924
# Episode Step Final:  55
# Reward:  [-2088639.5]
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  2924
# Fecha Final:  2023-06-28
# Current Step Final:  2980
# Episode Step Final:  55
# Reward:  [-3533856.2]
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  2980
# Fecha Final:  2021-03-12
# Current Step Final:  3044
# Episode Step Final:  63
# Reward:  [4922830.]
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  3044
# Fecha Final:  9999-12-31
# Current Step Final:  3100
# Episode Step Final:  55
# Reward:  [3747260.]
# Done testing DDPG Agent!
# Testing Random Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2021-01-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [7870186.5]
# --------------Testing Point 2 of 50-----------------------------------
# Fecha Inicial:  2021-01-20
# Current Step Inicial:  64
# Fecha Final:  2023-10-04
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [15605321.]
# --------------Testing Point 3 of 50-----------------------------------
# Fecha Inicial:  2023-10-04
# Current Step Inicial:  128
# Fecha Final:  2019-10-28
# Current Step Final:  192
# Episode Step Final:  63
# Reward:  [2185458.]
# --------------Testing Point 4 of 50-----------------------------------
# Fecha Inicial:  2019-10-28
# Current Step Inicial:  192
# Fecha Final:  2021-08-23
# Current Step Final:  256
# Episode Step Final:  63
# Reward:  [5174748.]
# --------------Testing Point 5 of 50-----------------------------------
# Fecha Inicial:  2021-08-23
# Current Step Inicial:  256
# Fecha Final:  2022-03-14
# Current Step Final:  320
# Episode Step Final:  63
# Reward:  [5086607.]
# --------------Testing Point 6 of 50-----------------------------------
# Fecha Inicial:  2022-03-14
# Current Step Inicial:  320
# Fecha Final:  2021-03-30
# Current Step Final:  384
# Episode Step Final:  63
# Reward:  [-3601770.5]
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  384
# Fecha Final:  2023-03-22
# Current Step Final:  448
# Episode Step Final:  63
# Reward:  [1795575.5]
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  448
# Fecha Final:  2021-09-17
# Current Step Final:  512
# Episode Step Final:  63
# Reward:  [7131851.]
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  512
# Fecha Final:  2021-06-30
# Current Step Final:  568
# Episode Step Final:  55
# Reward:  [-1298823.5]
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  568
# Fecha Final:  2023-07-26
# Current Step Final:  632
# Episode Step Final:  63
# Reward:  [1972416.]
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  632
# Fecha Final:  2023-07-31
# Current Step Final:  696
# Episode Step Final:  63
# Reward:  [1686659.2]
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  696
# Fecha Final:  2023-02-22
# Current Step Final:  760
# Episode Step Final:  63
# Reward:  [-680139.]
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  760
# Fecha Final:  2020-08-26
# Current Step Final:  824
# Episode Step Final:  63
# Reward:  [4497773.5]
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  824
# Fecha Final:  2021-02-05
# Current Step Final:  888
# Episode Step Final:  63
# Reward:  [7650181.]
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  888
# Fecha Final:  2020-09-08
# Current Step Final:  944
# Episode Step Final:  55
# Reward:  [1622352.1]
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  944
# Fecha Final:  2019-05-29
# Current Step Final:  1008
# Episode Step Final:  63
# Reward:  [-8771099.]
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  1008
# Fecha Final:  2020-01-13
# Current Step Final:  1072
# Episode Step Final:  63
# Reward:  [-1354984.8]
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  1072
# Fecha Final:  2023-05-04
# Current Step Final:  1136
# Episode Step Final:  63
# Reward:  [6573844.5]
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  1136
# Fecha Final:  2023-11-17
# Current Step Final:  1200
# Episode Step Final:  63
# Reward:  [-1920849.]
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  1200
# Fecha Final:  2020-09-28
# Current Step Final:  1264
# Episode Step Final:  63
# Reward:  [1392328.]
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  1264
# Fecha Final:  2020-07-17
# Current Step Final:  1328
# Episode Step Final:  63
# Reward:  [3605125.5]
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  1328
# Fecha Final:  2018-05-23
# Current Step Final:  1384
# Episode Step Final:  55
# Reward:  [631712.5]
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  1384
# Fecha Final:  2020-06-05
# Current Step Final:  1448
# Episode Step Final:  63
# Reward:  [4462025.5]
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  1448
# Fecha Final:  2019-07-02
# Current Step Final:  1504
# Episode Step Final:  55
# Reward:  [2216998.2]
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  1504
# Fecha Final:  2022-09-01
# Current Step Final:  1568
# Episode Step Final:  63
# Reward:  [2492899.5]
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  1568
# Fecha Final:  2021-05-28
# Current Step Final:  1632
# Episode Step Final:  63
# Reward:  [1893871.6]
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  1632
# Fecha Final:  2022-02-01
# Current Step Final:  1689
# Episode Step Final:  56
# Reward:  [-1801230.2]
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  1689
# Fecha Final:  2020-12-18
# Current Step Final:  1753
# Episode Step Final:  63
# Reward:  [9675077.]
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  1753
# Fecha Final:  2020-09-03
# Current Step Final:  1809
# Episode Step Final:  55
# Reward:  [716848.56]
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  1809
# Fecha Final:  2021-11-17
# Current Step Final:  1873
# Episode Step Final:  63
# Reward:  [-10217004.]
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  1873
# Fecha Final:  2018-06-04
# Current Step Final:  1937
# Episode Step Final:  63
# Reward:  [-8285619.5]
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  1937
# Fecha Final:  2019-10-14
# Current Step Final:  2001
# Episode Step Final:  63
# Reward:  [-2557078.2]
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  2001
# Fecha Final:  2022-06-22
# Current Step Final:  2065
# Episode Step Final:  63
# Reward:  [814408.25]
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  2065
# Fecha Final:  2021-02-26
# Current Step Final:  2129
# Episode Step Final:  63
# Reward:  [-1536946.9]
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  2129
# Fecha Final:  2022-11-10
# Current Step Final:  2185
# Episode Step Final:  55
# Reward:  [118986.69]
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  2185
# Fecha Final:  2020-02-06
# Current Step Final:  2249
# Episode Step Final:  63
# Reward:  [13836327.]
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  2249
# Fecha Final:  2022-01-20
# Current Step Final:  2313
# Episode Step Final:  63
# Reward:  [-3891059.5]
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  2313
# Fecha Final:  2022-07-26
# Current Step Final:  2377
# Episode Step Final:  63
# Reward:  [-9999116.]
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  2377
# Fecha Final:  2022-05-12
# Current Step Final:  2441
# Episode Step Final:  63
# Reward:  [2809195.8]
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  2441
# Fecha Final:  2020-08-24
# Current Step Final:  2503
# Episode Step Final:  61
# Reward:  [-81291.]
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  2503
# Fecha Final:  2019-02-19
# Current Step Final:  2567
# Episode Step Final:  63
# Reward:  [-4168474.5]
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  2567
# Fecha Final:  2019-04-26
# Current Step Final:  2631
# Episode Step Final:  63
# Reward:  [-1876280.1]
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  2631
# Fecha Final:  2019-10-17
# Current Step Final:  2686
# Episode Step Final:  54
# Reward:  [903429.9]
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  2686
# Fecha Final:  2022-05-06
# Current Step Final:  2748
# Episode Step Final:  61
# Reward:  [9561829.]
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  2748
# Fecha Final:  2020-07-30
# Current Step Final:  2804
# Episode Step Final:  55
# Reward:  [-4990908.]
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  2804
# Fecha Final:  2020-02-14
# Current Step Final:  2868
# Episode Step Final:  63
# Reward:  [6067922.]
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  2868
# Fecha Final:  2020-01-24
# Current Step Final:  2924
# Episode Step Final:  55
# Reward:  [1243382.8]
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  2924
# Fecha Final:  2023-06-28
# Current Step Final:  2980
# Episode Step Final:  55
# Reward:  [-7598232.5]
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  2980
# Fecha Final:  2021-03-12
# Current Step Final:  3044
# Episode Step Final:  63
# Reward:  [5074827.]
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  3044
# Fecha Final:  9999-12-31
# Current Step Final:  3100
# Episode Step Final:  55
# Reward:  [7605413.]
# Done testing Random Agent!
# Testing SP500 Agent...
# --------------Testing Point 1 of 50-----------------------------------
# Fecha Inicial:  2023-11-15
# Current Step Inicial:  0
# Fecha Final:  2021-01-20
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [4184724.5]
# --------------Testing Point 2 of 50-----------------------------------
# Fecha Inicial:  2021-01-20
# Current Step Inicial:  64
# Fecha Final:  2023-10-04
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [16013104.]
# --------------Testing Point 3 of 50-----------------------------------
# Fecha Inicial:  2023-10-04
# Current Step Inicial:  128
# Fecha Final:  2019-10-28
# Current Step Final:  192
# Episode Step Final:  63
# Reward:  [4908568.]
# --------------Testing Point 4 of 50-----------------------------------
# Fecha Inicial:  2019-10-28
# Current Step Inicial:  192
# Fecha Final:  2021-08-23
# Current Step Final:  256
# Episode Step Final:  63
# Reward:  [8613228.]
# --------------Testing Point 5 of 50-----------------------------------
# Fecha Inicial:  2021-08-23
# Current Step Inicial:  256
# Fecha Final:  2022-03-14
# Current Step Final:  320
# Episode Step Final:  63
# Reward:  [13427846.]
# --------------Testing Point 6 of 50-----------------------------------
# Fecha Inicial:  2022-03-14
# Current Step Inicial:  320
# Fecha Final:  2021-03-30
# Current Step Final:  384
# Episode Step Final:  63
# Reward:  [-3192584.]
# --------------Testing Point 7 of 50-----------------------------------
# Fecha Inicial:  2021-03-30
# Current Step Inicial:  384
# Fecha Final:  2023-03-22
# Current Step Final:  448
# Episode Step Final:  63
# Reward:  [-2399554.]
# --------------Testing Point 8 of 50-----------------------------------
# Fecha Inicial:  2023-03-22
# Current Step Inicial:  448
# Fecha Final:  2021-09-17
# Current Step Final:  512
# Episode Step Final:  63
# Reward:  [1164631.4]
# --------------Testing Point 9 of 50-----------------------------------
# Fecha Inicial:  2021-09-17
# Current Step Inicial:  512
# Fecha Final:  2021-06-30
# Current Step Final:  568
# Episode Step Final:  55
# Reward:  [-6856052.]
# --------------Testing Point 10 of 50-----------------------------------
# Fecha Inicial:  2021-06-30
# Current Step Inicial:  568
# Fecha Final:  2023-07-26
# Current Step Final:  632
# Episode Step Final:  63
# Reward:  [7794193.5]
# --------------Testing Point 11 of 50-----------------------------------
# Fecha Inicial:  2023-07-26
# Current Step Inicial:  632
# Fecha Final:  2023-07-31
# Current Step Final:  696
# Episode Step Final:  63
# Reward:  [-2192020.5]
# --------------Testing Point 12 of 50-----------------------------------
# Fecha Inicial:  2023-07-31
# Current Step Inicial:  696
# Fecha Final:  2023-02-22
# Current Step Final:  760
# Episode Step Final:  63
# Reward:  [1816990.8]
# --------------Testing Point 13 of 50-----------------------------------
# Fecha Inicial:  2023-02-22
# Current Step Inicial:  760
# Fecha Final:  2020-08-26
# Current Step Final:  824
# Episode Step Final:  63
# Reward:  [697276.44]
# --------------Testing Point 14 of 50-----------------------------------
# Fecha Inicial:  2020-08-26
# Current Step Inicial:  824
# Fecha Final:  2021-02-05
# Current Step Final:  888
# Episode Step Final:  63
# Reward:  [8140890.5]
# --------------Testing Point 15 of 50-----------------------------------
# Fecha Inicial:  2021-02-05
# Current Step Inicial:  888
# Fecha Final:  2020-09-08
# Current Step Final:  944
# Episode Step Final:  55
# Reward:  [428059.38]
# --------------Testing Point 16 of 50-----------------------------------
# Fecha Inicial:  2020-09-08
# Current Step Inicial:  944
# Fecha Final:  2019-05-29
# Current Step Final:  1008
# Episode Step Final:  63
# Reward:  [-3795648.8]
# --------------Testing Point 17 of 50-----------------------------------
# Fecha Inicial:  2019-05-29
# Current Step Inicial:  1008
# Fecha Final:  2020-01-13
# Current Step Final:  1072
# Episode Step Final:  63
# Reward:  [-1029997.2]
# --------------Testing Point 18 of 50-----------------------------------
# Fecha Inicial:  2020-01-13
# Current Step Inicial:  1072
# Fecha Final:  2023-05-04
# Current Step Final:  1136
# Episode Step Final:  63
# Reward:  [9608768.]
# --------------Testing Point 19 of 50-----------------------------------
# Fecha Inicial:  2023-05-04
# Current Step Inicial:  1136
# Fecha Final:  2023-11-17
# Current Step Final:  1200
# Episode Step Final:  63
# Reward:  [-1355889.5]
# --------------Testing Point 20 of 50-----------------------------------
# Fecha Inicial:  2023-11-17
# Current Step Inicial:  1200
# Fecha Final:  2020-09-28
# Current Step Final:  1264
# Episode Step Final:  63
# Reward:  [-357010.25]
# --------------Testing Point 21 of 50-----------------------------------
# Fecha Inicial:  2020-09-28
# Current Step Inicial:  1264
# Fecha Final:  2020-07-17
# Current Step Final:  1328
# Episode Step Final:  63
# Reward:  [8072215.]
# --------------Testing Point 22 of 50-----------------------------------
# Fecha Inicial:  2020-07-17
# Current Step Inicial:  1328
# Fecha Final:  2018-05-23
# Current Step Final:  1384
# Episode Step Final:  55
# Reward:  [3719289.2]
# --------------Testing Point 23 of 50-----------------------------------
# Fecha Inicial:  2018-05-23
# Current Step Inicial:  1384
# Fecha Final:  2020-06-05
# Current Step Final:  1448
# Episode Step Final:  63
# Reward:  [5747735.5]
# --------------Testing Point 24 of 50-----------------------------------
# Fecha Inicial:  2020-06-05
# Current Step Inicial:  1448
# Fecha Final:  2019-07-02
# Current Step Final:  1504
# Episode Step Final:  55
# Reward:  [2509542.5]
# --------------Testing Point 25 of 50-----------------------------------
# Fecha Inicial:  2019-07-02
# Current Step Inicial:  1504
# Fecha Final:  2022-09-01
# Current Step Final:  1568
# Episode Step Final:  63
# Reward:  [4975915.]
# --------------Testing Point 26 of 50-----------------------------------
# Fecha Inicial:  2022-09-01
# Current Step Inicial:  1568
# Fecha Final:  2021-05-28
# Current Step Final:  1632
# Episode Step Final:  63
# Reward:  [3995688.5]
# --------------Testing Point 27 of 50-----------------------------------
# Fecha Inicial:  2021-05-28
# Current Step Inicial:  1632
# Fecha Final:  2022-02-01
# Current Step Final:  1689
# Episode Step Final:  56
# Reward:  [-2383743.]
# --------------Testing Point 28 of 50-----------------------------------
# Fecha Inicial:  2022-02-01
# Current Step Inicial:  1689
# Fecha Final:  2020-12-18
# Current Step Final:  1753
# Episode Step Final:  63
# Reward:  [11429834.]
# --------------Testing Point 29 of 50-----------------------------------
# Fecha Inicial:  2020-12-18
# Current Step Inicial:  1753
# Fecha Final:  2020-09-03
# Current Step Final:  1809
# Episode Step Final:  55
# Reward:  [-941465.44]
# --------------Testing Point 30 of 50-----------------------------------
# Fecha Inicial:  2020-09-03
# Current Step Inicial:  1809
# Fecha Final:  2021-11-17
# Current Step Final:  1873
# Episode Step Final:  63
# Reward:  [-18974904.]
# --------------Testing Point 31 of 50-----------------------------------
# Fecha Inicial:  2021-11-17
# Current Step Inicial:  1873
# Fecha Final:  2018-06-04
# Current Step Final:  1937
# Episode Step Final:  63
# Reward:  [1588916.5]
# --------------Testing Point 32 of 50-----------------------------------
# Fecha Inicial:  2018-06-04
# Current Step Inicial:  1937
# Fecha Final:  2019-10-14
# Current Step Final:  2001
# Episode Step Final:  63
# Reward:  [496266.25]
# --------------Testing Point 33 of 50-----------------------------------
# Fecha Inicial:  2019-10-14
# Current Step Inicial:  2001
# Fecha Final:  2022-06-22
# Current Step Final:  2065
# Episode Step Final:  63
# Reward:  [4171823.8]
# --------------Testing Point 34 of 50-----------------------------------
# Fecha Inicial:  2022-06-22
# Current Step Inicial:  2065
# Fecha Final:  2021-02-26
# Current Step Final:  2129
# Episode Step Final:  63
# Reward:  [2604603.5]
# --------------Testing Point 35 of 50-----------------------------------
# Fecha Inicial:  2021-02-26
# Current Step Inicial:  2129
# Fecha Final:  2022-11-10
# Current Step Final:  2185
# Episode Step Final:  55
# Reward:  [-2403659.8]
# --------------Testing Point 36 of 50-----------------------------------
# Fecha Inicial:  2022-11-10
# Current Step Inicial:  2185
# Fecha Final:  2020-02-06
# Current Step Final:  2249
# Episode Step Final:  63
# Reward:  [8263924.]
# --------------Testing Point 37 of 50-----------------------------------
# Fecha Inicial:  2020-02-06
# Current Step Inicial:  2249
# Fecha Final:  2022-01-20
# Current Step Final:  2313
# Episode Step Final:  63
# Reward:  [2230146.8]
# --------------Testing Point 38 of 50-----------------------------------
# Fecha Inicial:  2022-01-20
# Current Step Inicial:  2313
# Fecha Final:  2022-07-26
# Current Step Final:  2377
# Episode Step Final:  63
# Reward:  [-9140808.]
# --------------Testing Point 39 of 50-----------------------------------
# Fecha Inicial:  2022-07-26
# Current Step Inicial:  2377
# Fecha Final:  2022-05-12
# Current Step Final:  2441
# Episode Step Final:  63
# Reward:  [-1317623.]
# --------------Testing Point 40 of 50-----------------------------------
# Fecha Inicial:  2022-05-12
# Current Step Inicial:  2441
# Fecha Final:  2020-08-24
# Current Step Final:  2503
# Episode Step Final:  61
# Reward:  [152303.19]
# --------------Testing Point 41 of 50-----------------------------------
# Fecha Inicial:  2020-08-24
# Current Step Inicial:  2503
# Fecha Final:  2019-02-19
# Current Step Final:  2567
# Episode Step Final:  63
# Reward:  [4754847.]
# --------------Testing Point 42 of 50-----------------------------------
# Fecha Inicial:  2019-02-19
# Current Step Inicial:  2567
# Fecha Final:  2019-04-26
# Current Step Final:  2631
# Episode Step Final:  63
# Reward:  [3494635.2]
# --------------Testing Point 43 of 50-----------------------------------
# Fecha Inicial:  2019-04-26
# Current Step Inicial:  2631
# Fecha Final:  2019-10-17
# Current Step Final:  2686
# Episode Step Final:  54
# Reward:  [6593130.5]
# --------------Testing Point 44 of 50-----------------------------------
# Fecha Inicial:  2019-10-17
# Current Step Inicial:  2686
# Fecha Final:  2022-05-06
# Current Step Final:  2748
# Episode Step Final:  61
# Reward:  [-384114.06]
# --------------Testing Point 45 of 50-----------------------------------
# Fecha Inicial:  2022-05-06
# Current Step Inicial:  2748
# Fecha Final:  2020-07-30
# Current Step Final:  2804
# Episode Step Final:  55
# Reward:  [-1944727.2]
# --------------Testing Point 46 of 50-----------------------------------
# Fecha Inicial:  2020-07-30
# Current Step Inicial:  2804
# Fecha Final:  2020-02-14
# Current Step Final:  2868
# Episode Step Final:  63
# Reward:  [13680077.]
# --------------Testing Point 47 of 50-----------------------------------
# Fecha Inicial:  2020-02-14
# Current Step Inicial:  2868
# Fecha Final:  2020-01-24
# Current Step Final:  2924
# Episode Step Final:  55
# Reward:  [-2876887.2]
# --------------Testing Point 48 of 50-----------------------------------
# Fecha Inicial:  2020-01-24
# Current Step Inicial:  2924
# Fecha Final:  2023-06-28
# Current Step Final:  2980
# Episode Step Final:  55
# Reward:  [-10752803.]
# --------------Testing Point 49 of 50-----------------------------------
# Fecha Inicial:  2023-06-28
# Current Step Inicial:  2980
# Fecha Final:  2021-03-12
# Current Step Final:  3044
# Episode Step Final:  63
# Reward:  [2436624.]
# --------------Testing Point 50 of 50-----------------------------------
# Fecha Inicial:  2021-03-12
# Current Step Inicial:  3044
# Fecha Final:  9999-12-31
# Current Step Final:  3100
# Episode Step Final:  55
# Reward:  [5888913.]
# Done testing SP500 Agent!
# --------------------------------------------------
# All agents tested!
# --------------------------------------------------

# %%
#Creación de networths acumulados para cada agente
for agent_name, agent_metrics in metrics_resume.items():
    net_worths_delta_list = agent_metrics['net_worths_delta']
    returns_list_multip = [1] + [(delta/INITIAL_BALANCE)+1 for delta in net_worths_delta_list]
    net_worths_delta_list = []
    for i in range(len(returns_list_multip)):
        net_worths_delta_list.append(np.prod(returns_list_multip[:i+1])*INITIAL_BALANCE)
    metrics_resume[agent_name]['net_worths_delta_acum'] = net_worths_delta_list

#Creación de rewards Acumulada para cada agente
for agent_name, agent_metrics in metrics_resume.items():
    rewards_list = agent_metrics['rewards']
    rewards_list_acum = [0] + [rewards_list[0]]
    for i in range(1,len(rewards_list)):
        rewards_list_acum.append(rewards_list_acum[-1] + rewards_list[i])
    metrics_resume[agent_name]['rewards_acum'] = rewards_list_acum

#Creación de networths acumulados para cada último agente entrenado
for agent_name, agent_metrics in metrics_resume_testing.items():
    net_worths_delta_list = agent_metrics['net_worths_delta']
    returns_list_multip = [1] + [(delta/INITIAL_BALANCE)+1 for delta in net_worths_delta_list]
    net_worths_delta_list = []
    for i in range(len(returns_list_multip)):
        net_worths_delta_list.append(np.prod(returns_list_multip[:i+1])*INITIAL_BALANCE)
    metrics_resume_testing[agent_name]['net_worths_delta_acum'] = net_worths_delta_list

#Creación de rewards Acumulada para cada último agente entrenado
for agent_name, agent_metrics in metrics_resume_testing.items():
    rewards_list = agent_metrics['rewards']
    rewards_list_acum = [0] + [rewards_list[0]]
    for i in range(1,len(rewards_list)):
        rewards_list_acum.append(rewards_list_acum[-1] + rewards_list[i])
    metrics_resume_testing[agent_name]['rewards_acum'] = rewards_list_acum

# %%
# Saving Metrics Resume
# Create folder to save the results
import os
import pickle

if not os.path.exists(PATH_TO_SAVE):
    os.makedirs(PATH_TO_SAVE)

with open(f'{PATH_TO_SAVE}/metrics_resume.pkl', 'wb') as f:
    pickle.dump(metrics_resume, f)

with open(f'{PATH_TO_SAVE}/metrics_resume_testing.pkl', 'wb') as f:
    pickle.dump(metrics_resume_testing, f)

with open(f'{PATH_TO_SAVE}/training_rewards_resume.pkl', 'wb') as f:
    pickle.dump(training_rewards_resume, f)

with open(f'{PATH_TO_SAVE}/metadata.pkl', 'wb') as f:
    pickle.dump(metadata, f)

for agent in trained_agents:
    if trained_agents[agent].model_type == "SB3":
        trained_agents[agent].model.save(f'{PATH_TO_SAVE}/{agent}_model')

# %%
#Variables de data de salida
#Data - Grafico de Recompensa acumulada para cada agente durante entrenamiento(sobre testing points)
#metrics_resume #metrics_resume[agent_name]['rewards_acum']
#Data - Grafico de Recompensa acumulada para cada mejor agente (sobre testing points)
#metrics_resume_testing #metrics_resume_testing[agent_name]['rewards_acum']
#Data - Gráfico de Networth a través del tiempo para cada agente. (sobre testing points)
#metrics_resume #metrics_resume[agent_name]['net_worths_delta_acum']
#Data - Gráfico de Networth a través del tiempo para cada mejor agente . (sobre testing points)
#metrics_resume_testing #metrics_resume_testing[agent_name]['net_worths_delta_acum']
#Data - Gráfico de RatioSharpe a través del tiempo testing point.(sobre testing points)
#metrics_resume # metrics_resume[agent]['sharpe_ratios']
#Data - Gráfico de Recompensa acumulada durante el aprendizaje (sobre la data de entrenamiento)
#training_rewards_resume
#Pendiente - Data - Los hiperpararametros utilizados (Va a ir en el ID_PATH)
#Data - Gráfico de Correlación de Pearson con el SP500 de cada agente.(Sobre los testing point)
#metrics_resume # metrics_resume[agent]['pearson_correlations']
# El archivo del agente entrenado
#trained_agents

# %%
# Extra para avisar finalización
import winsound
freq1 = 300
freq2 = 400
freq3 = 500
freq4 = 600
# duration is set to 100 milliseconds             
dur = 200        
winsound.Beep(freq1, dur)
winsound.Beep(freq2, dur)
winsound.Beep(freq3, dur)
winsound.Beep(freq4, 600)
