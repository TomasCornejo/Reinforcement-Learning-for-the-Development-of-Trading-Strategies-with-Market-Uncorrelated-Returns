# %%
# Fill missing data in csv files with 0
# # some of the csv are missing data for some datetimes
# # i want to fill the missing data with 0 all data for the same datetime
# import pandas as pd
# import datetime
# from glob import glob
# import numpy

# # got a filename that has all the datetimes with prices
# filename = 'data/SP500.csv'
# #get the list of datetimes in the field timestamp with pandas

# df = pd.read_csv(filename)
# datetimes = df['timestamp'].to_list()

# # get the list of csv files
# files = glob('Data/*.csv')

# # This is a sample of the format of the csv files
# #timestamp,symbol,open,high,low,close,volume,trade_count,vwap
# #2016-06-01 09:30:00-04:00,QSII,12.69,12.74,12.65,12.67,48037.0,208.0,12.706119

# # for each file in the list: 
# # create a new file with the same name +"_filled" , put all the datetimes in the first column with the same format
# # timestamp,symbol,open,high,low,close,volume,trade_count,vwap
# # keep the same order of the columns 
# # if exists data for a datetime, keep the data
# # if there is no data for a datetime, fill the data with 0
# # process the files with pandas

# for file in files:
#     print('Processing file', file)
#     df = pd.read_csv(file)
#     #df['timestamp'] = pd.to_datetime(df['timestamp'])
#     df = df.set_index('timestamp')
#     df.drop_duplicates(keep='first', inplace=True)
#     df = df.reindex(datetimes, fill_value=0)
#     df = df.reset_index()
#     df.to_csv(file.replace('Data/', 'Data/filled_'), index=False)
#     print('File', file, 'processed')

# %%
# Fill the 0 data in the .csv files with the last available data
# import pandas as pd
# import datetime
# from glob import glob
# import numpy

# fileList = glob('DataExample/*.csv')
# for file in fileList:
#     print('Processing file', file)
#     df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
#     df.replace(0, pd.NA, inplace=True)
#     df.fillna(method='ffill', inplace=True)
#     df.fillna(0, inplace=True)
#     new_file_name = file.replace('.csv', '_filled.csv')
#     df.reset_index(inplace=True)
#     df.to_csv(new_file_name, index=False)
#     print('File', file, 'processed')

# # Fill the 0 data in the .pk (parquet) files with the last available data
# import pandas as pd
# import datetime
# from glob import glob
# import numpy

# fileList = glob('Data/*.pk')
# for file in fileList:
#     print('Processing file', file)
#     df = pd.read_parquet(file)
#     df.replace(0, pd.NA, inplace=True)
#     df.fillna(method='ffill', inplace=True)
#     df.fillna(0, inplace=True)
#     new_file_name = file.replace('.pk', '_filled.pk')
#     df.to_parquet(new_file_name)
#     print('File', new_file_name, 'processed')

# %%
# #Convert to parquet
# from glob import glob
# import pandas as pd


# files = glob('Data/*.csv')

# for file in files:
#     parquet_file_name = file.replace('.csv', '.pk')
#     print(f'Processing file: {file} to {parquet_file_name}')
#     df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
#     # Drop column symbol
#     df.drop(columns='symbol', inplace=True)
#     if parquet_file_name[-3:] == '.pk':
#         df.to_parquet(parquet_file_name, index=True)
#         print("The file was saved as parquet: {parquet_file_name}")

# %%
# # for the _filled.pk files get the first date with data (close price != 0) and the last date with data (close price != 0)
# # put that data in a pandas dataframe with each row the filename and the first and last date 
# import pandas as pd
# from glob import glob

# files = glob('Data/*_filled.pk')

# data = []

# for file in files:
#     df = pd.read_parquet(file)
#     first_date = df[df['close'] != 0].index[0]
#     last_date = df[df['close'] != 0].index[-1]
#     data.append([file, first_date, last_date])

# df = pd.DataFrame(data, columns=['filename', 'first_date', 'last_date'])
# df
# #order the dataframe by the first date
# df.sort_values('first_date', inplace=True)
# df

# %%
# for the .csv files get the first date with data (close price != 0) and the last date with data (close price != 0)
# put that data in a pandas dataframe with each row the filename and the first and last date
# from glob import glob
# import pandas as pd
# files = glob('*.csv')
# data = []
# for file in files:
#     df = pd.read_csv(file)
#     first_date = df[df['close'] != 0].iloc[0]['timestamp']
#     last_date = df[df['close'] != 0].iloc[-1]['timestamp']
#     data.append([file, first_date, last_date]) 

# df = pd.DataFrame(data, columns=['filename', 'first_date', 'last_date'])
# df
# #order the dataframe by the first date
# df.sort_values('last_date', inplace=True)
# df

# %%
# import pandas as pd
# from datetime import datetime

# # Danh sách các cổ phiếu trong Dow Jones 30
# tickers = ['AAPL','ABCB','CSCO','DAL','EAST','ESPR','F',
#            'GOOGL','JPM','META','MSFT','NVDA','PFE','PG','PSX',
#            'SGLY','SP500','TSLA','UNH','USA','WMT','XOM']

# # ticker of benchmark
# benchmark = 'SP500'

# # Get the data from the CSV files
# stock_data = {}
# for ticker in tickers:
#     df = pd.read_parquet(f'Data/{ticker}_filled.pk')
#     #pass the columns to capitalize
#     df.columns = df.columns.str.capitalize()
#     stock_data[ticker] = df


# # Establish the time range for the data
# #trainInit = datetime.fromisoformat('2016-06-01 00:00:01-04:00')
# trainInit = datetime.fromisoformat('2018-01-01 00:00:01-04:00')
# trainEnd = datetime.fromisoformat('2024-01-01 00:00:01-04:00')

# # split the data into training
# training_data_time_range = (trainInit, trainEnd)

# # split the data into training, validation and test sets
# training_data = {}

# for ticker, df in stock_data.items():
#     training_data[ticker] = df.loc[training_data_time_range[0]:training_data_time_range[1]]

# # print shape of training, validation and test data
# ticker = 'AAPL'
# print(f'Training data shape for {ticker}: {training_data[ticker].shape}')

# # Display the first 5 rows of the data
# training_data['AAPL'].head()

# %%
# import pandas as pd
# import numpy as np

# def add_technical_indicators(df):
#     # calculate RSI 14 
#     delta = df['Close'].diff()
#     up = delta.where(delta > 0, 0)
#     down = -delta.where(delta < 0, 0)
#     rs = up.rolling(window=14).mean() / down.rolling(window=14).mean()
#     df['RSI'] = 100 - (100 / (1 + rs))

#     # EMA 12 / 26  en MACD
#     df['EMA12'] = df['Close'].ewm(span=12, adjust=False).mean()
#     df['EMA26'] = df['Close'].ewm(span=26, adjust=False).mean()
#     df['MACD'] = df['EMA12'] - df['EMA26']
#     df['Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
    
#     # RSI 14
#     delta = df['Close'].diff()
#     gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
#     loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
#     rs = gain / loss
#     df['RSI'] = 100 - (100 / (1 + rs))
    
#     # CCI 20
#     tp = (df['High'] + df['Low'] + df['Close']) / 3
#     sma_tp = tp.rolling(window=20).mean()
#     mean_dev = tp.rolling(window=20).apply(lambda x: np.mean(np.abs(x - x.mean())))
#     df['CCI'] = (tp - sma_tp) / (0.015 * mean_dev)
    
#     # ADX 14
#     high_diff = df['High'].diff()
#     low_diff = df['Low'].diff()
#     df['+DM'] = np.where((high_diff > low_diff) & (high_diff > 0), high_diff, 0)
#     df['-DM'] = np.where((low_diff > high_diff) & (low_diff > 0), low_diff, 0)
#     tr = pd.concat([df['High'] - df['Low'], np.abs(df['High'] - df['Close'].shift(1)), np.abs(df['Low'] - df['Close'].shift(1))], axis=1).max(axis=1)
#     atr = tr.ewm(span=14, adjust=False).mean()
#     df['+DI'] = 100 * (df['+DM'].ewm(span=14, adjust=False).mean() / atr)
#     df['-DI'] = 100 * (df['-DM'].ewm(span=14, adjust=False).mean() / atr)
#     dx = 100 * np.abs(df['+DI'] - df['-DI']) / (df['+DI'] + df['-DI'])
#     df['ADX'] = dx.ewm(span=14, adjust=False).mean()

#     # drop NaN values
#     # df.dropna(inplace=True)
#     # Fill NaN values with -1
#     df.fillna(-1, inplace=True)

#     # keep Open, High, Low, Close, Volume, MACD, Signal, RSI, CCI, ADX
#     df = df[['Open', 'High', 'Low', 'Close', 'Volume', 'MACD', 'Signal', 'RSI', 'CCI', 'ADX']]

#     return df

# %%
# # add technical indicators to the training data for each stock
# for ticker, df in training_data.items():
#     training_data[ticker] = add_technical_indicators(df)

# # Create benchmark data
# benchmark_training_data = training_data[benchmark]

# # print the first 5 rows of the data
# print('Shape of training data for AAPL:', training_data['AAPL'].shape)

# # print the first 5 rows of the benchmark data
# print('Shape of training benchmark data:', benchmark_training_data.shape)

# %%
tickers = ['AAPL','ABCB','CSCO','DAL','EAST','ESPR','F',
           'GOOGL','JPM','META','MSFT','NVDA','PFE','PG','PSX',
           'SGLY','SP500','TSLA','UNH','USA','WMT','XOM']

# ticker of benchmark
benchmark = 'SP500'

# %%
#for tick in tickers:
#    training_data[tick].to_parquet(f'Data/enriched_data/{tick}_training_data.pk',index=True)

# %%
import pandas as pd
import numpy as np

training_data = {}
for tick in tickers:
    training_data[tick] = pd.read_parquet(f'Data/enriched_data/{tick}_training_data.pk')

# %%
def shuffle_dataframe(df, shuffled_days):
    date_to_group = {date: group for date, group in df.groupby(df.index.date)}
    shuffled_groups = [date_to_group[date] for date in shuffled_days]
    return pd.concat(shuffled_groups)

def shuffle_dataset_dictionary(dataset_dict, seed=42, benchmark='SP500'):
    outputDatasetDictionary = {}
    np.random.seed(seed)

    #Get unique dates for one
    unique_days = np.unique(dataset_dict[benchmark].index.date)

    #Shuffle the unique days
    shuffled_unique_days = np.random.permutation(unique_days)

    for ticker, dataframe in dataset_dict.items():
        outputDatasetDictionary[ticker] = shuffle_dataframe(dataframe, shuffled_unique_days)
    return outputDatasetDictionary

# %%
shuffleDS = shuffle_dataset_dictionary(training_data)
benchmark_shuffleDS = shuffleDS[benchmark]

# %%
def pearsonccs(samples):
    C = np.cov(samples)
    diag = np.diag(C)
    N = np.sqrt(np.outer(diag, diag))
    N[N == 0] = 1
    return C / N

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd

class StockTradingEnv(gym.Env):
    metadata = {'render_modes': ['human']}
    
    def __init__(self, stock_data , benchmark_data, return_memory_size=5):
        super(StockTradingEnv, self).__init__()

        # Define the benchmark
        self.benchmark_data = benchmark_data
        
        # Initialize of memory
        self.return_memory_size = return_memory_size
        self.last_return_memory_benchmark = []
        self.last_return_memory_portfolio = []
        self.benchmark_portfolio_correlation = 0

        self.portfolio_return = []

        self.benchmark_portfolio_total_correlation = 0

        # Remove any empty DataFrames from the stock data
        self.stock_data = {ticker: df for ticker, df in stock_data.items() if not df.empty}     
        self.tickers = list(self.stock_data.keys())
        print(f"Stock data has been loaded for {len(self.tickers)} stocks.")
        print(f"The tickers are: {self.tickers}")
        
        if not self.tickers:
            raise ValueError("All provided stock data is empty")
        
        # Calculate the size of one stock's data
        sample_df = next(iter(self.stock_data.values()))
        self.n_features = len(sample_df.columns)
        
        # Define action and observation space
        self.action_space = spaces.Box(low=-1, high=1, shape=(len(self.tickers),), dtype=np.float32)
        
        # Observation space: price data for each stock + balance + net worth + shares held + max net worth + current step
        self.obs_shape = self.n_features * len(self.tickers) + 2 + len(self.tickers) + 2
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.obs_shape,), dtype=np.float32)
        
        # Initialize account balance
        self.initial_balance = 100000
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        
        # Set the current step and the episode step
        self.current_step = 0
        self.episode_step = 0
        self.current_date = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d')
        
        # Initialize the current date for separate days
        self.is_last_tick_of_day = False

    def hard_reset(self):
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        self.episode_step = 0
        
        self.is_last_tick_of_day = False
        self.last_return_memory_benchmark = []
        self.last_return_memory_portfolio = []

        self.portfolio_return = []

        self.benchmark_portfolio_correlation = 0
        self.benchmark_portfolio_total_correlation = 0
        
        #Especifico del hard reset
        self.current_step = 0
        self.current_date = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d')

        return self._next_observation(), {}

        
    
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.balance = self.initial_balance
        self.net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.shares_held = {ticker: 0 for ticker in self.tickers}
        self.total_shares_sold = {ticker: 0 for ticker in self.tickers}
        self.total_sales_value = {ticker: 0 for ticker in self.tickers}
        self.episode_step = 0
        self.is_last_tick_of_day = False
        self.last_return_memory_benchmark = []
        self.last_return_memory_portfolio = []

        self.portfolio_return = []

        self.benchmark_portfolio_correlation = 0
        self.benchmark_portfolio_total_correlation = 0

        return self._next_observation(), {}
    
    def _next_observation(self):
        frame = np.zeros(self.obs_shape)
        
        idx = 0
        for ticker in self.tickers:
            df = self.stock_data[ticker]
            if self.current_step < len(df):
                frame[idx:idx+self.n_features] = df.iloc[self.current_step].values
            elif len(df) > 0:
                frame[idx:idx+self.n_features] = df.iloc[-1].values
            idx += self.n_features
        
        frame[-4-len(self.tickers)] = self.balance
        frame[-3-len(self.tickers):-3] = [self.shares_held[ticker] for ticker in self.tickers]
        frame[-3] = self.net_worth
        frame[-2] = self.max_net_worth
        frame[-1] = self.episode_step
        
        return frame

    def step(self, actions):
        self.current_step += 1
        self.episode_step += 1
        self.current_date = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d')

        if self.is_last_tick_of_day:
            return self._next_observation(), 0, True, False, {}
        
        current_prices = {}
        for i, ticker in enumerate(self.tickers):
            current_prices[ticker] = self.stock_data[ticker].iloc[self.current_step]['Close']
            action = actions[i]
            
            # Buy or sell the stocks just if the price is different from 0
            if current_prices[ticker] != 0.0:
                if action > 0:  # Buy
                    shares_to_buy = int(self.balance * action / current_prices[ticker])
                    cost = shares_to_buy * current_prices[ticker]
                    self.balance -= cost
                    self.shares_held[ticker] += shares_to_buy
                elif action < 0:  # Sell
                    shares_to_sell = int(self.shares_held[ticker] * abs(action))
                    sale = shares_to_sell * current_prices[ticker]
                    self.balance += sale
                    self.shares_held[ticker] -= shares_to_sell
                    self.total_shares_sold[ticker] += shares_to_sell
                    self.total_sales_value[ticker] += sale
            else:
                print(f"Price for {ticker} in {self.current_date} is 0.0")
        

        self.last_net_worth = self.net_worth
        self.net_worth = self.balance + sum(self.shares_held[ticker] * current_prices[ticker] for ticker in self.tickers)
        self.max_net_worth = max(self.net_worth, self.max_net_worth)
        
        reward = self.net_worth - self.initial_balance
        done = (self.net_worth <= 0 or self.is_last_tick_of_day)

        # Calculate the return of the benchmark (just from second step)
        if self.episode_step > 0:
            benchmark_return = self.benchmark_data.iloc[self.current_step]['Close'] / self.benchmark_data.iloc[self.current_step - 1]['Close'] - 1
            #Add the return to the benchmark to the memory but if the memory is full, remove the oldest return
            if len(self.last_return_memory_benchmark) >= self.return_memory_size:
                self.last_return_memory_benchmark.pop(0)
            self.last_return_memory_benchmark.append(benchmark_return)
            

            # Calculate the return of the portfolio
            portfolio_return = self.net_worth / self.last_net_worth - 1
            self.portfolio_return.append(portfolio_return)
            # Add the return to the portfolio to the memory but if the memory is full, remove the oldest return
            if len(self.last_return_memory_portfolio) >= self.return_memory_size:
                self.last_return_memory_portfolio.pop(0)
            self.last_return_memory_portfolio.append(portfolio_return)

        
        # Calculate the pearson correlation between the benchmark memory and the portfolio memory just if the memory is full
        if len(self.last_return_memory_benchmark) == self.return_memory_size and \
           len(self.last_return_memory_portfolio) == self.return_memory_size:
            self.benchmark_portfolio_correlation = pearsonccs([self.last_return_memory_benchmark, self.last_return_memory_portfolio])[0][1]   
        else:
            self.benchmark_portfolio_correlation = 0
        
        # Update the is_last_tick_of_day variable
        self.is_last_tick_of_day = self.benchmark_data.index[self.current_step].date().strftime('%Y-%m-%d') \
            != self.benchmark_data.index[self.current_step + 1].date().strftime('%Y-%m-%d')

        obs = self._next_observation()
        return obs, reward, done, False, {}
    
    def render(self, mode='human'):
        profit = self.net_worth - self.initial_balance
        print(f'Step: {self.current_step}')
        print(f'Benchmark-Portfolio Correlation: {self.benchmark_portfolio_correlation:.2f}')
        print(f'Balance: {self.balance:.2f}')
        for ticker in self.tickers:
            print(f'{ticker} Shares held: {self.shares_held[ticker]}')
        print(f'Net worth: {self.net_worth:.2f}')
        print(f'Profit: {profit:.2f}')

    def close(self):
        pass

# %%
from stable_baselines3.common.utils import get_device

# %%
get_device(device='cuda')
# Out:
# device(type='cuda')

# %%
from stable_baselines3 import PPO, A2C, DDPG
from stable_baselines3.common.vec_env import DummyVecEnv

# # Define Ensemble Agent
# class EnsembleAgent:
#     def __init__(self, ppo_model, a2c_model, ddpg_model):
#         self.ppo_model = ppo_model
#         self.a2c_model = a2c_model
#         self.ddpg_model = ddpg_model
    
#     def predict(self, obs):
#         ppo_action, _ = self.ppo_model.predict(obs)
#         a2c_action, _ = self.a2c_model.predict(obs)
#         ddpg_action, _ = self.ddpg_model.predict(obs)
        
#         # Average the actions
#         ensemble_action = np.mean([ppo_action, a2c_action, ddpg_action], axis=0)
#         return ensemble_action
    
# Define PPO Agent
class PPOAgent:
    def __init__(self, env, n_steps):
        self.model_type = "SB3"
        self.model = PPO("MlpPolicy", env, n_steps=n_steps ,verbose=1, device='cuda')
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define A2C Agent
class A2CAgent:
    def __init__(self, env, n_steps):
        self.model_type = "SB3"
        self.model = A2C("MlpPolicy", env, n_steps=n_steps, verbose=1, device='cuda')
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define DDPG Agent
class DDPGAgent:
    def __init__(self, env):
        self.model_type = "SB3"
        self.model = DDPG("MlpPolicy", env, verbose=1, device='cuda')
    
    def predict(self, obs):
        action, _ = self.model.predict(obs)
        return action
    
# Define Random Agent
class RandomAgent:
    def __init__(self, env):
        self.model_type = "Random"
        self.env = env
        self.tickers_len = len(env.get_attr('tickers')[0])
    
    def predict(self, obs):
        return np.random.uniform(-1, 1, self.tickers_len).reshape(1, self.tickers_len)

# Define SP500 Agent
class SP500Agent:
    def __init__(self, env):
        self.model_type = "SP500"
        self.env = env
        self.tickers = env.get_attr('tickers')[0]
        self.tickers_len = len(self.tickers)
        self.SP500idx = self.tickers.index('SP500')

        
        print("Tickers en init SP500Agent")
        print(self.env.get_attr('tickers')[0])
    
    def predict(self, obs):
        current_step = int(self.env.get_attr('episode_step')[0])
        # create a empty array of zeros
        actions = np.zeros(self.tickers_len).reshape(1, self.tickers_len)
        if current_step == 0:
            # Buy SP500
            actions[0, self.SP500idx] = 1
        return actions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Function to create the environment and train the agents
def create_env_and_train_agents(data, benchmark_data, n_steps):
    # Create the environment using DummyVecEnv with training data
    env = DummyVecEnv([lambda: StockTradingEnv(data, benchmark_data, return_memory_size=5)])

    # Train PPO Agent
    ppo_agent = PPOAgent(env, n_steps=n_steps)

    # Train A2C Agent
    a2c_agent = A2CAgent(env, n_steps=n_steps)

    # Train DDPG Agent
    ddpg_agent = DDPGAgent(env)

    # Declaring Random Agent
    random_agent = RandomAgent(env)

    # Declaring SP500 Agent
    sp500_agent = SP500Agent(env)

    # Train the ensemble agent
    #ensemble_agent = EnsembleAgent(ppo_agent.model, a2c_agent.model, ddpg_agent.model)
    
    return env, ppo_agent, a2c_agent, ddpg_agent, random_agent, sp500_agent #, ensemble_agent

# %%
from stable_baselines3.common.callbacks import CallbackList
from CustomCallback import SaveTrainingRewardsCallback

def train_test_agent(env, agent, n_total_episodes=100, testing_points=10, just_test=False):
    """
    Test a single agent and track performance metrics, with an option to visualize the results.
    #TODO Corregir documentacion
    Parameters:
    - env: The trading environment.
    - agent: The agent to be tested.
    - stock_data: Data for the stocks in the environment.
    - n_tests: Number of tests to run (default: 1000).
    - visualize: Boolean flag to enable or disable visualization (default: False).

    Returns:
    - A dictionary containing steps, balances, net worths, and shares held.
    """
    # Initialize metrics tracking
    metrics = {
        'dates': [],
        'net_worths_delta': [],
        'shares_held': [],
        'pearson_correlations': [],
        'rewards': [],
        'portfolio_returns': [],
        'stds': [],
        'sharpe_ratios': []
    }

    # Reset the environment before starting the tests
    obs = np.array([env.env_method('hard_reset')[0][0].tolist()]) # env.reset()#

    # Get the training partition number of episodes
    partition = int(n_total_episodes / testing_points) - 1
    EPISODE_STEP_CONST = 64

    training_rewards = []
    
    # Set the episode loop
    for i_tpoint in range(testing_points):
        # First Evaluate the agents
        print(f"--------------Testing Point {i_tpoint+1} of {testing_points}-----------------------------------")
        # Set the initial episode values
        done = False
        cum_reward = 0
        local_pearson_correlations = []
        local_portfolio_returns = []
        metrics['dates'].append(env.get_attr('current_date')[0])
        
    
        initial_testing_net_worth = env.get_attr('net_worth')[0]

        #TODO Take off Later
        print("Fecha Inicial: ", env.get_attr('current_date')[0])
        print("Current Step Inicial: ", env.get_attr('current_step')[0])

        net_worth_list = []
        episode_step_final_testing_list = []
        last_testing_shares_held_list = []
        
        # Run the testing episode
        while not done:
            action = agent.predict(obs)
            obs, reward, done, _info = env.step(action)
            local_pearson_correlations.append(env.get_attr('benchmark_portfolio_correlation')[0])
            episode_step_final_testing_list.append(env.get_attr('episode_step')[0])
            net_worth_list.append(env.get_attr('net_worth')[0])
            last_testing_shares_held_list.append(env.get_attr('shares_held')[0])
            local_portfolio_returns.append(env.get_attr('portfolio_return')[0])
            cum_reward += reward
            
            
        print("Fecha Final: ", env.get_attr('current_date')[0])
        print("Current Step Final: ", env.get_attr('current_step')[0])
        print("Episode Step Final: ", episode_step_final_testing_list[-2])
        print("Reward: ", cum_reward)

        net_worth_delta = net_worth_list[-2] - initial_testing_net_worth
        # Append metrics
        metrics['net_worths_delta'].append(net_worth_delta)
        metrics['pearson_correlations'].append(np.mean(local_pearson_correlations))
        metrics['rewards'].append(cum_reward[0])
        metrics['portfolio_returns'].append(np.mean(local_portfolio_returns[0][1:]))
        metrics['stds'].append(np.std(local_portfolio_returns[0][1:]))
        metrics['sharpe_ratios'].append((net_worth_delta / initial_testing_net_worth) / np.std(local_portfolio_returns[0][1:]))

        # Update shares held for each ticker
        # Hacer caso especial para SB3
        if agent.model_type == "SB3":
            metrics['shares_held'].append(last_testing_shares_held_list[-2])
        else:
            metrics['shares_held'].append(last_testing_shares_held_list[-1])

        if not(just_test):
            #After train the agent by partition of episodes
            print("Fecha antes train: ", env.get_attr('current_date')[0])
            print("Current Step antes train: ", env.get_attr('current_step')[0])
            if agent.model_type == "SB3":
                #Define Callbacks to train
                callback_list = CallbackList([SaveTrainingRewardsCallback()])
                #Train the agent
                agent.model.learn(EPISODE_STEP_CONST*partition, callback=callback_list)
                #Add the rewards to the list of training rewards
                training_rewards.append(callback_list.callbacks[0].rewards)
            else:
                # El agente Random y SP500 no se entrenan
                for i in range(EPISODE_STEP_CONST*partition):
                    action = agent.predict(obs)
                    obs, _reward, done, _info = env.step(action)
            print("Fecha despues train: ", env.get_attr('current_date')[0]) 
            print("Current Step despues train: ", env.get_attr('current_step')[0])
        
        episode_done = False
        # Run steps till the end of the day just if if is just_test = False
        if not(just_test):
            while not episode_done:
                action = agent.predict(obs)
                obs, _reward, episode_done, _info = env.step(action)
        obs = env.reset()
        
    return metrics , training_rewards , agent

# %%
def getResumeMetrics(env, agents, n_total_episodes=50, testing_points=5, just_test=False):
    metrics_resume = {}
    training_rewards_resume = {}
    trained_agents = {}         
    for agent_name, agent in agents.items():
        print(f"Testing {agent_name}...")
        metrics_resume[agent_name], training_rewards_resume[agent_name], trained_agents[agent_name] = train_test_agent(env, agent, n_total_episodes, testing_points,just_test)
        print(f"Done testing {agent_name}!")
    
    print('-'*50)
    print('All agents tested!')
    print('-'*50)

    return metrics_resume, training_rewards_resume , trained_agents

# %%
EPISODE_STEP_CONST = 64 
N_TOTAL_EPISODES = 200 #900
TESTING_POINTS = 10 #50

partition = int(N_TOTAL_EPISODES / TESTING_POINTS) - 1
n_steps = EPISODE_STEP_CONST*partition

# 1. Create the environment and train the agents
env, ppo_agent, a2c_agent, ddpg_agent, random_agent , sp500_agent = create_env_and_train_agents(shuffleDS, benchmark_shuffleDS, n_steps=n_steps)

# 2. Test & visualize the agents
agents = {
    'PPO Agent': ppo_agent,
    'A2C Agent': a2c_agent,
    'DDPG Agent': ddpg_agent,
    'Random Agent': random_agent,
    'SP500 Agent': sp500_agent
}
metrics_resume, training_rewards_resume , trained_agents = getResumeMetrics(env, agents, n_total_episodes=N_TOTAL_EPISODES, testing_points=TESTING_POINTS)
# Out:
# Stock data has been loaded for 22 stocks.
# The tickers are: ['AAPL', 'ABCB', 'CSCO', 'DAL', 'EAST', 'ESPR', 'F', 'GOOGL', 'JPM', 'META', 'MSFT', 'NVDA', 'PFE', 'PG', 'PSX', 'SGLY', 'SP500', 'TSLA', 'UNH', 'USA', 'WMT', 'XOM']
# Using cuda device
# Using cuda device
# Using cuda device
# Tickers en init SP500Agent
# ['AAPL', 'ABCB', 'CSCO', 'DAL', 'EAST', 'ESPR', 'F', 'GOOGL', 'JPM', 'META', 'MSFT', 'NVDA', 'PFE', 'PG', 'PSX', 'SGLY', 'SP500', 'TSLA', 'UNH', 'USA', 'WMT', 'XOM']
# Testing PPO Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-07-22
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-58728.27]
# Fecha antes train:  2022-07-22
# Current Step antes train:  64
# -----------------------------
# | time/              |      |
# |    fps             | 159  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2019-12-23
# Current Step despues train:  1280
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  1321
# Fecha Final:  2020-08-17
# Current Step Final:  1385
# Episode Step Final:  63
# Reward:  [9640.87]
# Fecha antes train:  2020-08-17
# Current Step antes train:  1385
# -----------------------------
# | time/              |      |
# |    fps             | 134  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2020-05-18
# Current Step despues train:  2601
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  2628
# Fecha Final:  2018-04-10
# Current Step Final:  2680
# Episode Step Final:  51
# Reward:  [-5283.9062]
# Fecha antes train:  2018-04-10
# Current Step antes train:  2680
# -----------------------------
# | time/              |      |
# |    fps             | 136  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2019-03-19
# Current Step despues train:  3896
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  3902
# Fecha Final:  2023-07-12
# Current Step Final:  3966
# Episode Step Final:  63
# Reward:  [12439.109]
# Fecha antes train:  2023-07-12
# Current Step antes train:  3966
# -----------------------------
# | time/              |      |
# |    fps             | 129  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2018-06-28
# Current Step despues train:  5182
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  5215
# Fecha Final:  2018-12-20
# Current Step Final:  5279
# Episode Step Final:  63
# Reward:  [-10058.129]
# Fecha antes train:  2018-12-20
# Current Step antes train:  5279
# -----------------------------
# | time/              |      |
# |    fps             | 130  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2020-11-11
# Current Step despues train:  6495
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  6535
# Fecha Final:  2023-01-18
# Current Step Final:  6590
# Episode Step Final:  54
# Reward:  [-14986.318]
# Fecha antes train:  2023-01-18
# Current Step antes train:  6590
# -----------------------------
# | time/              |      |
# |    fps             | 132  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2022-12-20
# Current Step despues train:  7806
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  7862
# Fecha Final:  2018-12-11
# Current Step Final:  7926
# Episode Step Final:  63
# Reward:  [4860.892]
# Fecha antes train:  2018-12-11
# Current Step antes train:  7926
# -----------------------------
# | time/              |      |
# |    fps             | 132  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2021-05-11
# Current Step despues train:  9142
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  9185
# Fecha Final:  2021-10-27
# Current Step Final:  9246
# Episode Step Final:  60
# Reward:  [-28485.785]
# Fecha antes train:  2021-10-27
# Current Step antes train:  9246
# -----------------------------
# | time/              |      |
# |    fps             | 130  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2018-05-29
# Current Step despues train:  10462
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  10526
# Fecha Final:  2020-03-17
# Current Step Final:  10590
# Episode Step Final:  63
# Reward:  [22528.148]
# Fecha antes train:  2020-03-17
# Current Step antes train:  10590
# -----------------------------
# | time/              |      |
# |    fps             | 130  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2020-10-14
# Current Step despues train:  11806
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  11830
# Fecha Final:  2019-10-17
# Current Step Final:  11894
# Episode Step Final:  63
# Reward:  [-45081.562]
# Fecha antes train:  2019-10-17
# Current Step antes train:  11894
# -----------------------------
# | time/              |      |
# |    fps             | 143  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 1216 |
# -----------------------------
# Fecha despues train:  2018-10-05
# Current Step despues train:  13110
# Done testing PPO Agent!
# Testing A2C Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-07-22
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-103898.32]
# Fecha antes train:  2022-07-22
# Current Step antes train:  64
# Fecha despues train:  2019-12-23
# Current Step despues train:  1280
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  1321
# Fecha Final:  2020-08-17
# Current Step Final:  1385
# Episode Step Final:  63
# Reward:  [-60354.13]
# Fecha antes train:  2020-08-17
# Current Step antes train:  1385
# Fecha despues train:  2020-05-18
# Current Step despues train:  2601
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  2628
# Fecha Final:  2018-04-10
# Current Step Final:  2680
# Episode Step Final:  51
# Reward:  [31871.76]
# Fecha antes train:  2018-04-10
# Current Step antes train:  2680
# Fecha despues train:  2019-03-19
# Current Step despues train:  3896
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  3902
# Fecha Final:  2023-07-12
# Current Step Final:  3966
# Episode Step Final:  63
# Reward:  [-28379.264]
# Fecha antes train:  2023-07-12
# Current Step antes train:  3966
# Fecha despues train:  2018-06-28
# Current Step despues train:  5182
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  5215
# Fecha Final:  2018-12-20
# Current Step Final:  5279
# Episode Step Final:  63
# Reward:  [5332.535]
# Fecha antes train:  2018-12-20
# Current Step antes train:  5279
# Fecha despues train:  2020-11-11
# Current Step despues train:  6495
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  6535
# Fecha Final:  2023-01-18
# Current Step Final:  6590
# Episode Step Final:  54
# Reward:  [-20619.86]
# Fecha antes train:  2023-01-18
# Current Step antes train:  6590
# Fecha despues train:  2022-12-20
# Current Step despues train:  7806
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  7862
# Fecha Final:  2018-12-11
# Current Step Final:  7926
# Episode Step Final:  63
# Reward:  [-51705.64]
# Fecha antes train:  2018-12-11
# Current Step antes train:  7926
# Fecha despues train:  2021-05-11
# Current Step despues train:  9142
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  9185
# Fecha Final:  2021-10-27
# Current Step Final:  9246
# Episode Step Final:  60
# Reward:  [14602.617]
# Fecha antes train:  2021-10-27
# Current Step antes train:  9246
# Fecha despues train:  2018-05-29
# Current Step despues train:  10462
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  10526
# Fecha Final:  2020-03-17
# Current Step Final:  10590
# Episode Step Final:  63
# Reward:  [49685.65]
# Fecha antes train:  2020-03-17
# Current Step antes train:  10590
# Fecha despues train:  2020-10-14
# Current Step despues train:  11806
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  11830
# Fecha Final:  2019-10-17
# Current Step Final:  11894
# Episode Step Final:  63
# Reward:  [40435.87]
# Fecha antes train:  2019-10-17
# Current Step antes train:  11894
# Fecha despues train:  2018-10-05
# Current Step despues train:  13110
# Done testing A2C Agent!
# Testing DDPG Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-07-22
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [49570.414]
# Fecha antes train:  2022-07-22
# Current Step antes train:  64
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 94        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 247       |
# | train/             |           |
# |    actor_loss      | -1.94e+04 |
# |    critic_loss     | 1.42e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 146       |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 81        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 496       |
# | train/             |           |
# |    actor_loss      | -2.11e+04 |
# |    critic_loss     | 5.75e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 395       |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 77        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 753       |
# | train/             |           |
# |    actor_loss      | -1.87e+04 |
# |    critic_loss     | 6.01e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 652       |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 75        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 1001      |
# | train/             |           |
# |    actor_loss      | -1.58e+04 |
# |    critic_loss     | 1.42e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 900       |
# ----------------------------------
# Fecha despues train:  2019-12-23
# Current Step despues train:  1280
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  1321
# Fecha Final:  2020-08-17
# Current Step Final:  1385
# Episode Step Final:  63
# Reward:  [51683.285]
# Fecha antes train:  2020-08-17
# Current Step antes train:  1385
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 99        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 251       |
# | train/             |           |
# |    actor_loss      | -1.38e+04 |
# |    critic_loss     | 4.72e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1266      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 82        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 507       |
# | train/             |           |
# |    actor_loss      | -1.04e+04 |
# |    critic_loss     | 3.83e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1522      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 78        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 755       |
# | train/             |           |
# |    actor_loss      | -7.57e+03 |
# |    critic_loss     | 2.48e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1770      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 76        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 995       |
# | train/             |           |
# |    actor_loss      | -1.26e+04 |
# |    critic_loss     | 1.68e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2010      |
# ----------------------------------
# Fecha despues train:  2020-05-18
# Current Step despues train:  2601
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  2628
# Fecha Final:  2018-04-10
# Current Step Final:  2680
# Episode Step Final:  51
# Reward:  [69305.33]
# Fecha antes train:  2018-04-10
# Current Step antes train:  2680
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 96        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 256       |
# | train/             |           |
# |    actor_loss      | -9.77e+03 |
# |    critic_loss     | 1.34e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2387      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 82        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 495       |
# | train/             |           |
# |    actor_loss      | -8.61e+03 |
# |    critic_loss     | 1.91e+08  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2626      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 78        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 735       |
# | train/             |           |
# |    actor_loss      | -8.26e+03 |
# |    critic_loss     | 1.87e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2866      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 76        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 982       |
# | train/             |           |
# |    actor_loss      | -8.25e+03 |
# |    critic_loss     | 1.43e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3113      |
# ----------------------------------
# Fecha despues train:  2019-03-19
# Current Step despues train:  3896
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  3902
# Fecha Final:  2023-07-12
# Current Step Final:  3966
# Episode Step Final:  63
# Reward:  [-62137.625]
# Fecha antes train:  2023-07-12
# Current Step antes train:  3966
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 97        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 256       |
# | train/             |           |
# |    actor_loss      | -6.86e+03 |
# |    critic_loss     | 1.15e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3503      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 82        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 496       |
# | train/             |           |
# |    actor_loss      | -8.88e+03 |
# |    critic_loss     | 1.72e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3743      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 78        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 745       |
# | train/             |           |
# |    actor_loss      | -6.51e+03 |
# |    critic_loss     | 1.31e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3992      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 76        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 993       |
# | train/             |           |
# |    actor_loss      | -9.23e+03 |
# |    critic_loss     | 1.19e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4240      |
# ----------------------------------
# Fecha despues train:  2018-06-28
# Current Step despues train:  5182
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  5215
# Fecha Final:  2018-12-20
# Current Step Final:  5279
# Episode Step Final:  63
# Reward:  [-568.0596]
# Fecha antes train:  2018-12-20
# Current Step antes train:  5279
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 100       |
# |    time_elapsed    | 2         |
# |    total_timesteps | 240       |
# | train/             |           |
# |    actor_loss      | -1.16e+04 |
# |    critic_loss     | 1.15e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4603      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 79        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 496       |
# | train/             |           |
# |    actor_loss      | -8.14e+03 |
# |    critic_loss     | 2.93e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4859      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 76        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 744       |
# | train/             |           |
# |    actor_loss      | -9.21e+03 |
# |    critic_loss     | 1.59e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5107      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 74        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 1000      |
# | train/             |           |
# |    actor_loss      | -7.03e+03 |
# |    critic_loss     | 1.98e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5363      |
# ----------------------------------
# Fecha despues train:  2020-11-11
# Current Step despues train:  6495
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  6535
# Fecha Final:  2023-01-18
# Current Step Final:  6590
# Episode Step Final:  54
# Reward:  [-28896.83]
# Fecha antes train:  2023-01-18
# Current Step antes train:  6590
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 96        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 256       |
# | train/             |           |
# |    actor_loss      | -6.86e+03 |
# |    critic_loss     | 1.57e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5735      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 82        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 504       |
# | train/             |           |
# |    actor_loss      | -8.79e+03 |
# |    critic_loss     | 1.09e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5983      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 77        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 760       |
# | train/             |           |
# |    actor_loss      | -8.37e+03 |
# |    critic_loss     | 2.08e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6239      |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 75       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1016     |
# | train/             |          |
# |    actor_loss      | -7e+03   |
# |    critic_loss     | 1.94e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6495     |
# ---------------------------------
# Fecha despues train:  2022-12-20
# Current Step despues train:  7806
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  7862
# Fecha Final:  2018-12-11
# Current Step Final:  7926
# Episode Step Final:  63
# Reward:  [-149047.31]
# Fecha antes train:  2018-12-11
# Current Step antes train:  7926
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 95        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 256       |
# | train/             |           |
# |    actor_loss      | -7.69e+03 |
# |    critic_loss     | 2.22e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6851      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 81        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 512       |
# | train/             |           |
# |    actor_loss      | -7.28e+03 |
# |    critic_loss     | 1.78e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7107      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 77        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 755       |
# | train/             |           |
# |    actor_loss      | -6.14e+03 |
# |    critic_loss     | 6.13e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7350      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 75        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 1011      |
# | train/             |           |
# |    actor_loss      | -5.03e+03 |
# |    critic_loss     | 1.93e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7606      |
# ----------------------------------
# Fecha despues train:  2021-05-11
# Current Step despues train:  9142
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  9185
# Fecha Final:  2021-10-27
# Current Step Final:  9246
# Episode Step Final:  60
# Reward:  [20461.236]
# Fecha antes train:  2021-10-27
# Current Step antes train:  9246
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 97        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 256       |
# | train/             |           |
# |    actor_loss      | -7.87e+03 |
# |    critic_loss     | 2.21e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7967      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 82        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 497       |
# | train/             |           |
# |    actor_loss      | -6.13e+03 |
# |    critic_loss     | 1.59e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8208      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 78        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 737       |
# | train/             |           |
# |    actor_loss      | -8.21e+03 |
# |    critic_loss     | 3.36e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8448      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 76        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 976       |
# | train/             |           |
# |    actor_loss      | -8.07e+03 |
# |    critic_loss     | 3.39e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8687      |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 75       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1216     |
# | train/             |          |
# |    actor_loss      | -1e+04   |
# |    critic_loss     | 2.37e+07 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8927     |
# ---------------------------------
# Fecha despues train:  2018-05-29
# Current Step despues train:  10462
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  10526
# Fecha Final:  2020-03-17
# Current Step Final:  10590
# Episode Step Final:  63
# Reward:  [31111.018]
# Fecha antes train:  2020-03-17
# Current Step antes train:  10590
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 95        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 256       |
# | train/             |           |
# |    actor_loss      | -8.17e+03 |
# |    critic_loss     | 3.09e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9083      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 81        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 512       |
# | train/             |           |
# |    actor_loss      | -8.41e+03 |
# |    critic_loss     | 2.01e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9339      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 78        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 752       |
# | train/             |           |
# |    actor_loss      | -6.58e+03 |
# |    critic_loss     | 2.87e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9579      |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 76        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 1000      |
# | train/             |           |
# |    actor_loss      | -7.68e+03 |
# |    critic_loss     | 2.88e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9827      |
# ----------------------------------
# Fecha despues train:  2020-10-14
# Current Step despues train:  11806
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  11830
# Fecha Final:  2019-10-17
# Current Step Final:  11894
# Episode Step Final:  63
# Reward:  [-559888.56]
# Fecha antes train:  2019-10-17
# Current Step antes train:  11894
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 99        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 246       |
# | train/             |           |
# |    actor_loss      | -7.32e+03 |
# |    critic_loss     | 2.96e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10189     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 83        |
# |    time_elapsed    | 5         |
# |    total_timesteps | 486       |
# | train/             |           |
# |    actor_loss      | -7.75e+03 |
# |    critic_loss     | 2.79e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10429     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 78        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 734       |
# | train/             |           |
# |    actor_loss      | -6.94e+03 |
# |    critic_loss     | 2.85e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10677     |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 76        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 990       |
# | train/             |           |
# |    actor_loss      | -5.57e+03 |
# |    critic_loss     | 2.43e+07  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10933     |
# ----------------------------------
# Fecha despues train:  2018-10-05
# Current Step despues train:  13110
# Done testing DDPG Agent!
# Testing Random Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-07-22
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-60131.277]
# Fecha antes train:  2022-07-22
# Current Step antes train:  64
# Fecha despues train:  2019-12-23
# Current Step despues train:  1280
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  1321
# Fecha Final:  2020-08-17
# Current Step Final:  1385
# Episode Step Final:  63
# Reward:  [-60678.074]
# Fecha antes train:  2020-08-17
# Current Step antes train:  1385
# Fecha despues train:  2020-05-18
# Current Step despues train:  2601
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  2628
# Fecha Final:  2018-04-10
# Current Step Final:  2680
# Episode Step Final:  51
# Reward:  [-15473.619]
# Fecha antes train:  2018-04-10
# Current Step antes train:  2680
# Fecha despues train:  2019-03-19
# Current Step despues train:  3896
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  3902
# Fecha Final:  2023-07-12
# Current Step Final:  3966
# Episode Step Final:  63
# Reward:  [12781.348]
# Fecha antes train:  2023-07-12
# Current Step antes train:  3966
# Fecha despues train:  2018-06-28
# Current Step despues train:  5182
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  5215
# Fecha Final:  2018-12-20
# Current Step Final:  5279
# Episode Step Final:  63
# Reward:  [10596.236]
# Fecha antes train:  2018-12-20
# Current Step antes train:  5279
# Fecha despues train:  2020-11-11
# Current Step despues train:  6495
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  6535
# Fecha Final:  2023-01-18
# Current Step Final:  6590
# Episode Step Final:  54
# Reward:  [-5599.0537]
# Fecha antes train:  2023-01-18
# Current Step antes train:  6590
# Fecha despues train:  2022-12-20
# Current Step despues train:  7806
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  7862
# Fecha Final:  2018-12-11
# Current Step Final:  7926
# Episode Step Final:  63
# Reward:  [22666.197]
# Fecha antes train:  2018-12-11
# Current Step antes train:  7926
# Fecha despues train:  2021-05-11
# Current Step despues train:  9142
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  9185
# Fecha Final:  2021-10-27
# Current Step Final:  9246
# Episode Step Final:  60
# Reward:  [13073.658]
# Fecha antes train:  2021-10-27
# Current Step antes train:  9246
# Fecha despues train:  2018-05-29
# Current Step despues train:  10462
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  10526
# Fecha Final:  2020-03-17
# Current Step Final:  10590
# Episode Step Final:  63
# Reward:  [34578.66]
# Fecha antes train:  2020-03-17
# Current Step antes train:  10590
# Fecha despues train:  2020-10-14
# Current Step despues train:  11806
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  11830
# Fecha Final:  2019-10-17
# Current Step Final:  11894
# Episode Step Final:  63
# Reward:  [-391762.66]
# Fecha antes train:  2019-10-17
# Current Step antes train:  11894
# Fecha despues train:  2018-10-05
# Current Step despues train:  13110
# Done testing Random Agent!
# Testing SP500 Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-07-22
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-95194.05]
# Fecha antes train:  2022-07-22
# Current Step antes train:  64
# Fecha despues train:  2019-12-23
# Current Step despues train:  1280
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  1321
# Fecha Final:  2020-08-17
# Current Step Final:  1385
# Episode Step Final:  63
# Reward:  [-62662.965]
# Fecha antes train:  2020-08-17
# Current Step antes train:  1385
# Fecha despues train:  2020-05-18
# Current Step despues train:  2601
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  2628
# Fecha Final:  2018-04-10
# Current Step Final:  2680
# Episode Step Final:  51
# Reward:  [-518.10754]
# Fecha antes train:  2018-04-10
# Current Step antes train:  2680
# Fecha despues train:  2019-03-19
# Current Step despues train:  3896
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  3902
# Fecha Final:  2023-07-12
# Current Step Final:  3966
# Episode Step Final:  63
# Reward:  [-2010.0663]
# Fecha antes train:  2023-07-12
# Current Step antes train:  3966
# Fecha despues train:  2018-06-28
# Current Step despues train:  5182
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  5215
# Fecha Final:  2018-12-20
# Current Step Final:  5279
# Episode Step Final:  63
# Reward:  [24150.8]
# Fecha antes train:  2018-12-20
# Current Step antes train:  5279
# Fecha despues train:  2020-11-11
# Current Step despues train:  6495
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  6535
# Fecha Final:  2023-01-18
# Current Step Final:  6590
# Episode Step Final:  54
# Reward:  [-4808.936]
# Fecha antes train:  2023-01-18
# Current Step antes train:  6590
# Fecha despues train:  2022-12-20
# Current Step despues train:  7806
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  7862
# Fecha Final:  2018-12-11
# Current Step Final:  7926
# Episode Step Final:  63
# Reward:  [4477.]
# Fecha antes train:  2018-12-11
# Current Step antes train:  7926
# Fecha despues train:  2021-05-11
# Current Step despues train:  9142
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  9185
# Fecha Final:  2021-10-27
# Current Step Final:  9246
# Episode Step Final:  60
# Reward:  [14293.07]
# Fecha antes train:  2021-10-27
# Current Step antes train:  9246
# Fecha despues train:  2018-05-29
# Current Step despues train:  10462
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  10526
# Fecha Final:  2020-03-17
# Current Step Final:  10590
# Episode Step Final:  63
# Reward:  [16088.511]
# Fecha antes train:  2020-03-17
# Current Step antes train:  10590
# Fecha despues train:  2020-10-14
# Current Step despues train:  11806
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  11830
# Fecha Final:  2019-10-17
# Current Step Final:  11894
# Episode Step Final:  63
# Reward:  [-122704.02]
# Fecha antes train:  2019-10-17
# Current Step antes train:  11894
# Fecha despues train:  2018-10-05
# Current Step despues train:  13110
# Done testing SP500 Agent!
# --------------------------------------------------
# All agents tested!
# --------------------------------------------------

# %%
def plotTrainingRewards(agent_training_rewards_resume, agent_name):
    dataToPlot = []
    step_index_adder = 0
    cumulative_reward = 0
    for period_index, rewards in enumerate(agent_training_rewards_resume):
        for step_index, reward in enumerate(rewards):
            cumulative_reward += reward
            dataToPlot.append([step_index+step_index_adder, cumulative_reward, f'Period {period_index + 1}'])
        step_index_adder += len(rewards)

    df = pd.DataFrame(dataToPlot, columns=['Step', 'Reward', 'Training Period'])

    fig, ax = plt.subplots()

    # Plot each training period with a different color
    for period in df['Training Period'].unique():
        period_data = df[df['Training Period'] == period]
        ax.plot(period_data['Step'], period_data['Reward'], label=period)

    # Add title and labels
    ax.set_title('Training Rewards Over Steps - ' + agent_name)
    ax.set_xlabel('Step')
    ax.set_ylabel('Reward')

    # Add a legend
    ax.legend()

    plt.show()

# %%
def plotTrainingRewardsMultiAgents(agents_training_rewards_resume):
    for agent in agents_training_rewards_resume:
        if len(agents_training_rewards_resume[agent]) > 0:
            plotTrainingRewards(agents_training_rewards_resume[agent], agent)

# %%
plotTrainingRewardsMultiAgents(training_rewards_resume)

# %%
# Check Fechas de los episodios para cada agente
PPOAgentDates = metrics_resume['PPO Agent']['dates']
A2CAgentDates = metrics_resume['A2C Agent']['dates']
DDPGAgentDates = metrics_resume['DDPG Agent']['dates']
RandomAgentDates = metrics_resume['Random Agent']['dates']
SP500AgentDates = metrics_resume['SP500 Agent']['dates']
dates_df = pd.DataFrame({
    'PPO Agent': PPOAgentDates,
    'A2C Agent': A2CAgentDates,
    'DDPG Agent': DDPGAgentDates,
    'Random Agent': RandomAgentDates,
    'SP500 Agent': SP500AgentDates
})
dates_df
# Out:
#     PPO Agent   A2C Agent  DDPG Agent Random Agent SP500 Agent
# 0  2020-04-21  2020-04-21  2020-04-21   2020-04-21  2020-04-21
# 1  2022-06-14  2022-06-14  2022-06-14   2022-06-14  2022-06-14
# 2  2023-07-03  2023-07-03  2023-07-03   2023-07-03  2023-07-03
# 3  2022-12-14  2022-12-14  2022-12-14   2022-12-14  2022-12-14
# 4  2018-02-13  2018-02-13  2018-02-13   2018-02-13  2018-02-13
# 5  2019-12-27  2019-12-27  2019-12-27   2019-12-27  2019-12-27
# 6  2021-04-13  2021-04-13  2021-04-13   2021-04-13  2021-04-13
# 7  2020-02-19  2020-02-19  2020-02-19   2020-02-19  2020-02-19
# 8  2018-06-06  2018-06-06  2018-06-06   2018-06-06  2018-06-06
# 9  2020-06-11  2020-06-11  2020-06-11   2020-06-11  2020-06-11

# %%
# Visualizar las métricas de los agentes usando dates como x-axis (con las etiquetas en diagonal) y la metrica como y-axis
def plot_metrics(metrics):
    # Get a list of all the posible dates from the metrics
    #available_dates 
    #for agent_name, agent_metrics in metrics.items():

    ## Plot Rewards
    plt.figure(figsize=(15, 5))
    for agent_name, agent_metrics in metrics.items():
        plt.plot(agent_metrics['dates'], agent_metrics['rewards'], label=agent_name)
    plt.xticks(rotation=45)
    plt.title('Rewards Per Episode')
    plt.xlabel('Date')
    plt.ylabel('Rewards')
    plt.legend()
    plt.show()

    ## Plot Net Worths Delta
    plt.figure(figsize=(15, 5))
    for agent_name, agent_metrics in metrics.items():
        plt.plot(agent_metrics['dates'], agent_metrics['net_worths_delta'], label=agent_name)
    plt.xticks(rotation=45)
    plt.title('Net Worths Delta Per Episode')
    plt.xlabel('Date')
    plt.ylabel('Net Worths Delta')
    plt.legend()
    plt.show()

    ## Plot Pearson Correlations
    plt.figure(figsize=(15, 5))
    for agent_name, agent_metrics in metrics.items():
        plt.plot(agent_metrics['dates'], agent_metrics['pearson_correlations'], label=agent_name)
    plt.xticks(rotation=45)
    plt.title('Pearson Correlations Per Episode')
    plt.xlabel('Date')
    plt.ylabel('Pearson Correlations')
    plt.legend()
    plt.show()

    ## Plot Portfolio Returns
    plt.figure(figsize=(15, 5))
    for agent_name, agent_metrics in metrics.items():
        plt.plot(agent_metrics['dates'], agent_metrics['portfolio_returns'], label=agent_name)
    plt.xticks(rotation=45)
    plt.title('Portfolio Returns Per Episode')
    plt.xlabel('Date')
    plt.ylabel('Portfolio Returns')
    plt.legend()
    plt.show()

    ## Plot Sharpe Ratios
    plt.figure(figsize=(15, 5))
    for agent_name, agent_metrics in metrics.items():
        plt.plot(agent_metrics['dates'], agent_metrics['sharpe_ratios'], label=agent_name)
    plt.xticks(rotation=45)
    plt.title('Sharpe Ratios Per Episode')
    plt.xlabel('Date')
    plt.ylabel('Sharpe Ratios')
    plt.legend()
    plt.show()

# %%
plot_metrics(metrics_resume)

# %%
metrics_resume['PPO Agent'].keys()
# Out:
# dict_keys(['dates', 'net_worths_delta', 'shares_held', 'pearson_correlations', 'rewards', 'portfolio_returns', 'stds', 'sharpe_ratios'])

# %%
metrics_resume['PPO Agent']['portfolio_returns']
# Out:
# [1.2964750486270517e-05,
#  -0.00020289281027608032,
#  -0.0003491883546972874,
#  -1.453391238638087e-05,
#  -4.21567955102591e-05,
#  -0.00011201099356831034,
#  0.00012621432433159826,
#  -0.000129429089248491,
#  5.8300479723875696e-05,
#  -0.00024116671820994547]

# %%
def SharesHeldPlot(agents_metrics):
    agents_to_plot = list(agents_metrics.keys())
    for i in range(len(agents_to_plot)):
        #Create the dataframe for shares_held where each row is a ticker , each column is a step and the value is the shares held
        df = pd.DataFrame.from_dict(metrics_resume[agents_to_plot[i]]['shares_held']).T
        #Filter the rows where the sum of the shares held is greater than 0
        df = df.loc[(df.sum(axis=1) > 0)]
        #Now plot a line char where each line is a ticker and the x axis is the step
        df.T.plot(figsize=(12, 6))
        plt.title(f'Shares Held Over Time for {agents_to_plot[i]}')
        plt.xlabel('Episodes')
        plt.ylabel('Shares Held')
        plt.show()

# %%
SharesHeldPlot(metrics_resume)

# %%
metrics_resume
# Out:
# {'PPO Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [52.45514000003459,
#    -1289.772888000036,
#    -1752.964100000041,
#    -120.38464999997814,
#    -263.80999999996857,
#    -594.4461479999882,
#    775.2030999999697,
#    -764.5871000000188,
#    353.7608000000182,
#    -1584.323000000004],
#   'shares_held': [{'AAPL': 2,
#     'ABCB': 44,
#     'CSCO': 187,
#     'DAL': 17,
#     'EAST': 42,
#     'ESPR': 96,
#     'F': 44,
#     'GOOGL': 1,
#     'JPM': 135,
#     'META': 0,
#     'MSFT': 74,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 87,
#     'PSX': 0,
#     'SGLY': 130,
#     'SP500': 9,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 5199,
#     'WMT': 153,
#     'XOM': 0},
#    {'AAPL': 40,
#     'ABCB': 22,
#     'CSCO': 67,
#     'DAL': 473,
#     'EAST': 31636,
#     'ESPR': 258,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 92,
#     'MSFT': 40,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 18,
#     'PSX': 18,
#     'SGLY': 3114,
#     'SP500': 0,
#     'TSLA': 7,
#     'UNH': 13,
#     'USA': 3,
#     'WMT': 1,
#     'XOM': 47},
#    {'AAPL': 0,
#     'ABCB': 391,
#     'CSCO': 0,
#     'DAL': 240,
#     'EAST': 6892,
#     'ESPR': 7869,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 176,
#     'META': 0,
#     'MSFT': 7,
#     'NVDA': 5,
#     'PFE': 81,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 7,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 4,
#     'USA': 91,
#     'WMT': 1,
#     'XOM': 25},
#    {'AAPL': 1,
#     'ABCB': 29,
#     'CSCO': 0,
#     'DAL': 20,
#     'EAST': 4228,
#     'ESPR': 221,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 64,
#     'META': 0,
#     'MSFT': 19,
#     'NVDA': 95,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 20,
#     'SGLY': 5912,
#     'SP500': 81,
#     'TSLA': 0,
#     'UNH': 8,
#     'USA': 3314,
#     'WMT': 1,
#     'XOM': 6},
#    {'AAPL': 5,
#     'ABCB': 563,
#     'CSCO': 27,
#     'DAL': 31,
#     'EAST': 2861,
#     'ESPR': 224,
#     'F': 138,
#     'GOOGL': 0,
#     'JPM': 1,
#     'META': 15,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 211,
#     'SGLY': 20,
#     'SP500': 2,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1112,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 205,
#     'DAL': 79,
#     'EAST': 0,
#     'ESPR': 354,
#     'F': 0,
#     'GOOGL': 31,
#     'JPM': 24,
#     'META': 22,
#     'MSFT': 14,
#     'NVDA': 0,
#     'PFE': 9,
#     'PG': 0,
#     'PSX': 5,
#     'SGLY': 1350,
#     'SP500': 3,
#     'TSLA': 4,
#     'UNH': 11,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 20,
#     'ABCB': 12,
#     'CSCO': 113,
#     'DAL': 132,
#     'EAST': 0,
#     'ESPR': 551,
#     'F': 0,
#     'GOOGL': 1,
#     'JPM': 181,
#     'META': 0,
#     'MSFT': 35,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 2266,
#     'SP500': 0,
#     'TSLA': 1,
#     'UNH': 0,
#     'USA': 667,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 1063,
#     'DAL': 37,
#     'EAST': 3,
#     'ESPR': 39,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 665,
#     'PG': 1,
#     'PSX': 0,
#     'SGLY': 30979,
#     'SP500': 1,
#     'TSLA': 3,
#     'UNH': 0,
#     'USA': 289,
#     'WMT': 0,
#     'XOM': 27},
#    {'AAPL': 0,
#     'ABCB': 203,
#     'CSCO': 14,
#     'DAL': 0,
#     'EAST': 10,
#     'ESPR': 0,
#     'F': 8,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 171,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 72,
#     'PSX': 73,
#     'SGLY': 2480,
#     'SP500': 0,
#     'TSLA': 39,
#     'UNH': 12,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 107},
#    {'AAPL': 9,
#     'ABCB': 9,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 716,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 26,
#     'MSFT': 7,
#     'NVDA': 12,
#     'PFE': 0,
#     'PG': 108,
#     'PSX': 123,
#     'SGLY': 0,
#     'SP500': 83,
#     'TSLA': 0,
#     'UNH': 10,
#     'USA': 470,
#     'WMT': 0,
#     'XOM': 0}],
#   'pearson_correlations': [0.48072652316718917,
#    0.6277775220610837,
#    0.28620504813446185,
#    0.5432807728288067,
#    0.3653843240710279,
#    0.31837049703927806,
#    0.2510192523370628,
#    0.28208580995645477,
#    0.3417664187244586,
#    0.5411910049562044],
#   'rewards': [-58728.27,
#    9640.87,
#    -5283.9062,
#    12439.109,
#    -10058.129,
#    -14986.318,
#    4860.892,
#    -28485.785,
#    22528.148,
#    -45081.562],
#   'portfolio_returns': [1.2964750486270517e-05,
#    -0.00020289281027608032,
#    -0.0003491883546972874,
#    -1.453391238638087e-05,
#    -4.21567955102591e-05,
#    -0.00011201099356831034,
#    0.00012621432433159826,
#    -0.000129429089248491,
#    5.8300479723875696e-05,
#    -0.00024116671820994547],
#   'stds': [0.003002634983773121,
#    0.00358595423953001,
#    0.002971544409693284,
#    0.0031219174048512646,
#    0.0009468435211147846,
#    0.0009761525362468847,
#    0.0018228149277352335,
#    0.0011407098842735146,
#    0.0016329336577619398,
#    0.0057591654822796035],
#   'sharpe_ratios': [0.17469702539107598,
#    -3.5967354903253836,
#    -5.899168440094011,
#    -0.38561125868643387,
#    -2.786204838676688,
#    -6.089685022850191,
#    4.252780072210211,
#    -6.702730558760455,
#    2.166412568682517,
#    -2.7509593271365667]},
#  'A2C Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [-2421.70229999999,
#    -1259.0278720000497,
#    2221.5903499999986,
#    -1013.1542999999801,
#    390.54899999999907,
#    -593.4178159999865,
#    -1200.0178999999916,
#    881.3143000000273,
#    915.8824000000022,
#    230.56230000003416],
#   'shares_held': [{'AAPL': 1,
#     'ABCB': 341,
#     'CSCO': 34,
#     'DAL': 0,
#     'EAST': 18290,
#     'ESPR': 142,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 35,
#     'MSFT': 11,
#     'NVDA': 25,
#     'PFE': 0,
#     'PG': 16,
#     'PSX': 0,
#     'SGLY': 2101,
#     'SP500': 9,
#     'TSLA': 1,
#     'UNH': 3,
#     'USA': 241,
#     'WMT': 176,
#     'XOM': 123},
#    {'AAPL': 0,
#     'ABCB': 2,
#     'CSCO': 8,
#     'DAL': 358,
#     'EAST': 23718,
#     'ESPR': 0,
#     'F': 1,
#     'GOOGL': 7,
#     'JPM': 0,
#     'META': 13,
#     'MSFT': 52,
#     'NVDA': 0,
#     'PFE': 236,
#     'PG': 31,
#     'PSX': 19,
#     'SGLY': 2726,
#     'SP500': 15,
#     'TSLA': 7,
#     'UNH': 13,
#     'USA': 3,
#     'WMT': 2,
#     'XOM': 5},
#    {'AAPL': 0,
#     'ABCB': 43,
#     'CSCO': 101,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 5211,
#     'F': 0,
#     'GOOGL': 17,
#     'JPM': 0,
#     'META': 28,
#     'MSFT': 0,
#     'NVDA': 76,
#     'PFE': 184,
#     'PG': 0,
#     'PSX': 32,
#     'SGLY': 86,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 213,
#     'XOM': 2},
#    {'AAPL': 30,
#     'ABCB': 115,
#     'CSCO': 0,
#     'DAL': 254,
#     'EAST': 0,
#     'ESPR': 1136,
#     'F': 179,
#     'GOOGL': 13,
#     'JPM': 0,
#     'META': 139,
#     'MSFT': 11,
#     'NVDA': 0,
#     'PFE': 154,
#     'PG': 4,
#     'PSX': 0,
#     'SGLY': 3117,
#     'SP500': 0,
#     'TSLA': 2,
#     'UNH': 8,
#     'USA': 0,
#     'WMT': 49,
#     'XOM': 93},
#    {'AAPL': 0,
#     'ABCB': 96,
#     'CSCO': 0,
#     'DAL': 57,
#     'EAST': 338,
#     'ESPR': 3,
#     'F': 8,
#     'GOOGL': 2,
#     'JPM': 0,
#     'META': 14,
#     'MSFT': 8,
#     'NVDA': 1,
#     'PFE': 94,
#     'PG': 105,
#     'PSX': 48,
#     'SGLY': 4758,
#     'SP500': 77,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 2765,
#     'WMT': 0,
#     'XOM': 127},
#    {'AAPL': 0,
#     'ABCB': 83,
#     'CSCO': 0,
#     'DAL': 21,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 2,
#     'GOOGL': 3,
#     'JPM': 4,
#     'META': 6,
#     'MSFT': 69,
#     'NVDA': 0,
#     'PFE': 406,
#     'PG': 141,
#     'PSX': 97,
#     'SGLY': 86,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 1,
#     'USA': 625,
#     'WMT': 235,
#     'XOM': 2},
#    {'AAPL': 0,
#     'ABCB': 112,
#     'CSCO': 0,
#     'DAL': 4,
#     'EAST': 613,
#     'ESPR': 885,
#     'F': 924,
#     'GOOGL': 6,
#     'JPM': 0,
#     'META': 21,
#     'MSFT': 4,
#     'NVDA': 21,
#     'PFE': 43,
#     'PG': 34,
#     'PSX': 104,
#     'SGLY': 8,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 26,
#     'WMT': 35,
#     'XOM': 57},
#    {'AAPL': 1,
#     'ABCB': 138,
#     'CSCO': 4,
#     'DAL': 0,
#     'EAST': 26,
#     'ESPR': 354,
#     'F': 1579,
#     'GOOGL': 15,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 16,
#     'NVDA': 0,
#     'PFE': 79,
#     'PG': 18,
#     'PSX': 0,
#     'SGLY': 4630,
#     'SP500': 0,
#     'TSLA': 1,
#     'UNH': 0,
#     'USA': 287,
#     'WMT': 46,
#     'XOM': 182},
#    {'AAPL': 16,
#     'ABCB': 25,
#     'CSCO': 15,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 293,
#     'GOOGL': 1,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 210,
#     'NVDA': 32,
#     'PFE': 461,
#     'PG': 3,
#     'PSX': 4,
#     'SGLY': 5953,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 20,
#     'USA': 425,
#     'WMT': 0,
#     'XOM': 334},
#    {'AAPL': 0,
#     'ABCB': 17,
#     'CSCO': 448,
#     'DAL': 1,
#     'EAST': 1,
#     'ESPR': 50,
#     'F': 576,
#     'GOOGL': 1,
#     'JPM': 0,
#     'META': 1,
#     'MSFT': 58,
#     'NVDA': 6,
#     'PFE': 0,
#     'PG': 27,
#     'PSX': 335,
#     'SGLY': 488,
#     'SP500': 1,
#     'TSLA': 0,
#     'UNH': 86,
#     'USA': 190,
#     'WMT': 0,
#     'XOM': 91}],
#   'pearson_correlations': [0.6146873077260239,
#    0.5894053110272683,
#    0.2077363485320039,
#    0.6627130185444019,
#    0.3442365575311952,
#    0.5132684309287353,
#    0.1977714522540755,
#    0.07194371987145391,
#    0.18244191105831878,
#    0.5765770527437589],
#   'rewards': [-103898.32,
#    -60354.13,
#    31871.76,
#    -28379.264,
#    5332.535,
#    -20619.86,
#    -51705.64,
#    14602.617,
#    49685.65,
#    40435.87],
#   'portfolio_returns': [-0.000389463744950965,
#    -0.00019981679658763777,
#    0.00044371782544726956,
#    -0.00016196725507798684,
#    6.337285743885888e-05,
#    -0.0001119784874309918,
#    -0.00019356335638349135,
#    0.00014910262402670585,
#    0.00015356235983658123,
#    5.9532089776066645e-05],
#   'stds': [0.0034205475989500995,
#    0.003005542504465931,
#    0.002896338919119549,
#    0.0021259749431890894,
#    0.0010022159046356876,
#    0.0007923189560979985,
#    0.001508019393938287,
#    0.0008609623284973421,
#    0.0036256255989448255,
#    0.006770815977249276],
#   'sharpe_ratios': [-7.079867272548131,
#    -4.189020351997225,
#    7.6703397359150705,
#    -4.765598499859026,
#    3.896854941071468,
#    -7.48963294936729,
#    -7.957576041950428,
#    10.236386318298107,
#    2.526136179826603,
#    0.3405236544232632]},
#  'DDPG Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [1489.3800000000192,
#    1553.7446049999999,
#    2309.209999999992,
#    -2690.059999999983,
#    -0.05000000000291038,
#    -973.9799999999959,
#    -3861.8399999999965,
#    497.21000000002095,
#    701.0499000000127,
#    -12546.910000000003],
#   'shares_held': [{'AAPL': 0,
#     'ABCB': 4514,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 3,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2426,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 4,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2923,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 2,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2038,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 2,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 1901,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2319,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 1912,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 1,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2486,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 1752,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 1,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 3802,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0}],
#   'pearson_correlations': [0.3406803165507454,
#    0.32033487165364755,
#    0.024952425621105355,
#    0.3369725095303013,
#    0.16576329041183482,
#    0.12711801784966908,
#    0.22947385516436097,
#    0.11163928021956163,
#    0.09702865856696233,
#    0.2541125296819703],
#   'rewards': [49570.414,
#    51683.285,
#    69305.33,
#    -62137.625,
#    -568.0596,
#    -28896.83,
#    -149047.31,
#    20461.236,
#    31111.018,
#    -559888.56],
#   'portfolio_returns': [0.00026202889813642204,
#    0.0002514980254496805,
#    0.00046342902812954943,
#    -0.00043637901216879573,
#    1.3526765130097536e-06,
#    -0.00018394947837160314,
#    -0.0006275756403119453,
#    8.477016499473118e-05,
#    0.00011359556752552337,
#    -0.0014116706385087308],
#   'stds': [0.006856290869108287,
#    0.0023621667175603976,
#    0.0036907977495081404,
#    0.002582866883192858,
#    0.0016500169151601885,
#    0.001185983893951788,
#    0.003832459424779226,
#    0.0011863560165863865,
#    0.0013509620835055827,
#    0.03785843664903082],
#   'sharpe_ratios': [2.1722824022979705,
#    6.577624658960054,
#    6.256669036681113,
#    -10.415016033170925,
#    -0.00030302719653062607,
#    -8.212421812530868,
#    -10.076662456047954,
#    4.191069063995561,
#    5.189264070097906,
#    -3.314164849520062]},
#  'Random Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [-514.5302100000117,
#    -1300.2397280000296,
#    -27.83674999998766,
#    143.88914000001387,
#    301.16289999998116,
#    -306.44755800002895,
#    736.8124999999563,
#    685.925700000007,
#    963.1461999999738,
#    -9265.485749999993],
#   'shares_held': [{'AAPL': 1,
#     'ABCB': 364,
#     'CSCO': 398,
#     'DAL': 23,
#     'EAST': 10284,
#     'ESPR': 448,
#     'F': 57,
#     'GOOGL': 58,
#     'JPM': 1,
#     'META': 4,
#     'MSFT': 1,
#     'NVDA': 49,
#     'PFE': 170,
#     'PG': 2,
#     'PSX': 226,
#     'SGLY': 261,
#     'SP500': 7,
#     'TSLA': 5,
#     'UNH': 6,
#     'USA': 76,
#     'WMT': 2,
#     'XOM': 1},
#    {'AAPL': 8,
#     'ABCB': 309,
#     'CSCO': 1,
#     'DAL': 30,
#     'EAST': 291,
#     'ESPR': 23,
#     'F': 869,
#     'GOOGL': 1,
#     'JPM': 49,
#     'META': 8,
#     'MSFT': 17,
#     'NVDA': 4,
#     'PFE': 89,
#     'PG': 33,
#     'PSX': 149,
#     'SGLY': 5995,
#     'SP500': 4,
#     'TSLA': 1,
#     'UNH': 30,
#     'USA': 2031,
#     'WMT': 18,
#     'XOM': 7},
#    {'AAPL': 4,
#     'ABCB': 16,
#     'CSCO': 1,
#     'DAL': 107,
#     'EAST': 624,
#     'ESPR': 58,
#     'F': 35,
#     'GOOGL': 15,
#     'JPM': 20,
#     'META': 7,
#     'MSFT': 144,
#     'NVDA': 63,
#     'PFE': 20,
#     'PG': 133,
#     'PSX': 5,
#     'SGLY': 8269,
#     'SP500': 11,
#     'TSLA': 1,
#     'UNH': 1,
#     'USA': 682,
#     'WMT': 1,
#     'XOM': 1},
#    {'AAPL': 24,
#     'ABCB': 310,
#     'CSCO': 11,
#     'DAL': 129,
#     'EAST': 299,
#     'ESPR': 3145,
#     'F': 719,
#     'GOOGL': 1,
#     'JPM': 29,
#     'META': 29,
#     'MSFT': 4,
#     'NVDA': 11,
#     'PFE': 1,
#     'PG': 2,
#     'PSX': 23,
#     'SGLY': 2683,
#     'SP500': 7,
#     'TSLA': 4,
#     'UNH': 2,
#     'USA': 1602,
#     'WMT': 3,
#     'XOM': 147},
#    {'AAPL': 13,
#     'ABCB': 46,
#     'CSCO': 1,
#     'DAL': 1,
#     'EAST': 112,
#     'ESPR': 1,
#     'F': 2936,
#     'GOOGL': 3,
#     'JPM': 206,
#     'META': 59,
#     'MSFT': 1,
#     'NVDA': 8,
#     'PFE': 5,
#     'PG': 2,
#     'PSX': 28,
#     'SGLY': 4599,
#     'SP500': 1,
#     'TSLA': 1,
#     'UNH': 2,
#     'USA': 889,
#     'WMT': 1,
#     'XOM': 199},
#    {'AAPL': 9,
#     'ABCB': 41,
#     'CSCO': 18,
#     'DAL': 29,
#     'EAST': 4,
#     'ESPR': 156,
#     'F': 620,
#     'GOOGL': 1,
#     'JPM': 6,
#     'META': 24,
#     'MSFT': 83,
#     'NVDA': 11,
#     'PFE': 24,
#     'PG': 9,
#     'PSX': 46,
#     'SGLY': 16353,
#     'SP500': 7,
#     'TSLA': 17,
#     'UNH': 46,
#     'USA': 689,
#     'WMT': 20,
#     'XOM': 11},
#    {'AAPL': 10,
#     'ABCB': 442,
#     'CSCO': 178,
#     'DAL': 68,
#     'EAST': 108,
#     'ESPR': 1,
#     'F': 191,
#     'GOOGL': 8,
#     'JPM': 1,
#     'META': 49,
#     'MSFT': 3,
#     'NVDA': 17,
#     'PFE': 180,
#     'PG': 7,
#     'PSX': 39,
#     'SGLY': 7014,
#     'SP500': 1,
#     'TSLA': 13,
#     'UNH': 65,
#     'USA': 210,
#     'WMT': 1,
#     'XOM': 78},
#    {'AAPL': 15,
#     'ABCB': 195,
#     'CSCO': 43,
#     'DAL': 20,
#     'EAST': 59,
#     'ESPR': 69,
#     'F': 80,
#     'GOOGL': 1,
#     'JPM': 56,
#     'META': 13,
#     'MSFT': 24,
#     'NVDA': 24,
#     'PFE': 91,
#     'PG': 186,
#     'PSX': 30,
#     'SGLY': 85,
#     'SP500': 5,
#     'TSLA': 1,
#     'UNH': 4,
#     'USA': 60,
#     'WMT': 40,
#     'XOM': 81},
#    {'AAPL': 5,
#     'ABCB': 8,
#     'CSCO': 2,
#     'DAL': 17,
#     'EAST': 169,
#     'ESPR': 1,
#     'F': 1470,
#     'GOOGL': 10,
#     'JPM': 2,
#     'META': 2,
#     'MSFT': 1,
#     'NVDA': 3,
#     'PFE': 3,
#     'PG': 3,
#     'PSX': 221,
#     'SGLY': 17353,
#     'SP500': 3,
#     'TSLA': 42,
#     'UNH': 64,
#     'USA': 5316,
#     'WMT': 6,
#     'XOM': 81},
#    {'AAPL': 4,
#     'ABCB': 44,
#     'CSCO': 176,
#     'DAL': 323,
#     'EAST': 52,
#     'ESPR': 6,
#     'F': 350,
#     'GOOGL': 2,
#     'JPM': 13,
#     'META': 13,
#     'MSFT': 178,
#     'NVDA': 22,
#     'PFE': 65,
#     'PG': 40,
#     'PSX': 8,
#     'SGLY': 6038,
#     'SP500': 9,
#     'TSLA': 21,
#     'UNH': 10,
#     'USA': 679,
#     'WMT': 2,
#     'XOM': 54}],
#   'pearson_correlations': [0.3811660979986973,
#    0.7180307881915637,
#    0.19631527374190544,
#    0.6547215864387446,
#    0.44518564486416495,
#    0.3384962057696544,
#    0.37938817813179937,
#    0.44607166602586523,
#    0.11301701823729059,
#    0.41299185370289404],
#   'rewards': [-60131.277,
#    -60678.074,
#    -15473.619,
#    12781.348,
#    10596.236,
#    -5599.0537,
#    22666.197,
#    13073.658,
#    34578.66,
#    -391762.66],
#   'portfolio_returns': [-8.05533401229596e-05,
#    -0.00020819063774237025,
#    -2.91107950884939e-06,
#    2.6087304801392814e-05,
#    4.917605560265533e-05,
#    -5.77459075421002e-05,
#    0.00011882560422957122,
#    0.00011611538722648484,
#    0.0001551119534013255,
#    -0.0015480921268932566],
#   'stds': [0.0023000352709412,
#    0.002398614424649077,
#    0.002306407662900398,
#    0.002404817649761388,
#    0.001160390379739311,
#    0.0005681310500855314,
#    0.0009096794577815982,
#    0.000703021909709453,
#    0.000997436445479963,
#    0.0061132317990941895],
#   'sharpe_ratios': [-2.2370535639197406,
#    -5.420795083354248,
#    -0.12069310403253626,
#    0.5983370091045819,
#    2.5953584695147103,
#    -5.393958981011401,
#    8.099693729446127,
#    9.756818251702688,
#    9.65621623677999,
#    -15.156444339919974]},
#  'SP500 Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [-1806.4199999999983,
#    -799.9199999999983,
#    63.0,
#    -310.0,
#    880.7400000000052,
#    -321.36000000001513,
#    205.69999999998254,
#    509.1200000000099,
#    626.2600000000093,
#    -3260.1800000000076],
#   'shares_held': [{'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 251,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 296,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 378,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 225,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 399,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 251,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 378,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 218,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 399,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 334,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0}],
#   'pearson_correlations': [0.9209736229529327,
#    0.9217634467721452,
#    0.9029607394914435,
#    0.9212596096098584,
#    0.9216633931548353,
#    0.9089905982583898,
#    0.9208371330689118,
#    0.9161129664234662,
#    0.921751340382896,
#    0.9211206603799786],
#   'rewards': [-95194.05,
#    -62662.965,
#    -518.10754,
#    -2010.0663,
#    24150.8,
#    -4808.936,
#    4477.0,
#    14293.07,
#    16088.511,
#    -122704.02],
#   'portfolio_returns': [-0.00029090956406141634,
#    -0.00012664593552245927,
#    1.2650936418683312e-05,
#    -4.7129615626244124e-05,
#    0.00014191318992684912,
#    -6.056721645661872e-05,
#    3.334340532816101e-05,
#    8.614374884584024e-05,
#    0.00010170612435190222,
#    -0.0005314882600998316],
#   'stds': [0.0024773120220180408,
#    0.002401790920620819,
#    0.00033115702846192954,
#    0.002424888425459699,
#    0.0009698774392102126,
#    0.0005699638227581626,
#    0.0006317171335490141,
#    0.000367282820482897,
#    0.0014189456604089175,
#    0.0024355265557344423],
#   'sharpe_ratios': [-7.291854978076085,
#    -3.330514713550643,
#    1.9024207425886661,
#    -1.278409335230472,
#    9.080941203428821,
#    -5.638252590223944,
#    3.256204226159754,
#    13.861797274662285,
#    4.413558725141956,
#    -13.385934931909983]}}

# %%
from datetime import datetime
# Step0: Lista de fechas de los testing points
date_list = metrics_resume['SP500 Agent']['dates'] 
date_list = [datetime.strptime(date, "%Y-%m-%d").date() for date in date_list]
# Step1: Filter training data by the dates of the testing points
def filter_data_for_testing(data, date_list):
    filtered_data = {}
    for ticker, df in data.items():
        normalized_index = df.index.normalize()
        index_dates = pd.Series(normalized_index.date, index=df.index)
        filtered_df = df.loc[index_dates.isin(date_list)]
        nonsense_timestamp = pd.Timestamp('9999-12-31 23:59:59-04:00')
        placeholder_data = {
            'Open': 1,
            'High': 1,
            'Low': 1,
            'Close': 1,
            'Volume': 1,
            'MACD': 1,
            'Signal': 1,
            'RSI': 1,
            'CCI': 1,
            'ADX': 1
        }
        placeholder_row = pd.DataFrame([placeholder_data], index=[nonsense_timestamp])
        filtered_data[ticker] = pd.concat([filtered_df, placeholder_row])
    return filtered_data

testing_data = filter_data_for_testing(shuffleDS, date_list)
benchmark_testing_data = testing_data['SP500']
# Step2: Create a new environment with the filtered data
env_testing = DummyVecEnv([lambda: StockTradingEnv(testing_data, benchmark_testing_data, return_memory_size=5)])
# Step3: Test the best/last agents with the new environment
metrics_resume_testing, training_rewards_resume, _ = getResumeMetrics(env_testing, trained_agents, n_total_episodes=N_TOTAL_EPISODES, testing_points=TESTING_POINTS, just_test=True)
# Step4: Visualize the results
# Out:
# Stock data has been loaded for 22 stocks.
# The tickers are: ['AAPL', 'ABCB', 'CSCO', 'DAL', 'EAST', 'ESPR', 'F', 'GOOGL', 'JPM', 'META', 'MSFT', 'NVDA', 'PFE', 'PG', 'PSX', 'SGLY', 'SP500', 'TSLA', 'UNH', 'USA', 'WMT', 'XOM']
# Testing PPO Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-06-14
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-101464.33]
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  64
# Fecha Final:  2023-07-03
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [-26536.928]
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  128
# Fecha Final:  2022-12-14
# Current Step Final:  180
# Episode Step Final:  51
# Reward:  [-15776.807]
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  180
# Fecha Final:  2018-02-13
# Current Step Final:  244
# Episode Step Final:  63
# Reward:  [12903.389]
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  244
# Fecha Final:  2019-12-27
# Current Step Final:  308
# Episode Step Final:  63
# Reward:  [-25683.09]
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  308
# Fecha Final:  2021-04-13
# Current Step Final:  363
# Episode Step Final:  54
# Reward:  [-21855.191]
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  363
# Fecha Final:  2020-02-19
# Current Step Final:  427
# Episode Step Final:  63
# Reward:  [-66985.9]
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  427
# Fecha Final:  2018-06-06
# Current Step Final:  488
# Episode Step Final:  60
# Reward:  [1248.2515]
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  488
# Fecha Final:  2020-06-11
# Current Step Final:  552
# Episode Step Final:  63
# Reward:  [-9033.177]
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  552
# Fecha Final:  9999-12-31
# Current Step Final:  616
# Episode Step Final:  63
# Reward:  [-184329.81]
# Done testing PPO Agent!
# Testing A2C Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-06-14
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-138899.58]
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  64
# Fecha Final:  2023-07-03
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [-43568.066]
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  128
# Fecha Final:  2022-12-14
# Current Step Final:  180
# Episode Step Final:  51
# Reward:  [-24302.102]
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  180
# Fecha Final:  2018-02-13
# Current Step Final:  244
# Episode Step Final:  63
# Reward:  [-20371.3]
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  244
# Fecha Final:  2019-12-27
# Current Step Final:  308
# Episode Step Final:  63
# Reward:  [-36145.6]
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  308
# Fecha Final:  2021-04-13
# Current Step Final:  363
# Episode Step Final:  54
# Reward:  [-14404.793]
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  363
# Fecha Final:  2020-02-19
# Current Step Final:  427
# Episode Step Final:  63
# Reward:  [-14071.53]
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  427
# Fecha Final:  2018-06-06
# Current Step Final:  488
# Episode Step Final:  60
# Reward:  [55982.05]
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  488
# Fecha Final:  2020-06-11
# Current Step Final:  552
# Episode Step Final:  63
# Reward:  [39651.53]
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  552
# Fecha Final:  9999-12-31
# Current Step Final:  616
# Episode Step Final:  63
# Reward:  [-175316.08]
# Done testing A2C Agent!
# Testing DDPG Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-06-14
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [49581.414]
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  64
# Fecha Final:  2023-07-03
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [51679.95]
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  128
# Fecha Final:  2022-12-14
# Current Step Final:  180
# Episode Step Final:  51
# Reward:  [69305.33]
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  180
# Fecha Final:  2018-02-13
# Current Step Final:  244
# Episode Step Final:  63
# Reward:  [-62137.625]
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  244
# Fecha Final:  2019-12-27
# Current Step Final:  308
# Episode Step Final:  63
# Reward:  [-568.0596]
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  308
# Fecha Final:  2021-04-13
# Current Step Final:  363
# Episode Step Final:  54
# Reward:  [-28896.83]
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  363
# Fecha Final:  2020-02-19
# Current Step Final:  427
# Episode Step Final:  63
# Reward:  [-149047.31]
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  427
# Fecha Final:  2018-06-06
# Current Step Final:  488
# Episode Step Final:  60
# Reward:  [20461.236]
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  488
# Fecha Final:  2020-06-11
# Current Step Final:  552
# Episode Step Final:  63
# Reward:  [31111.018]
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  552
# Fecha Final:  9999-12-31
# Current Step Final:  616
# Episode Step Final:  63
# Reward:  [-559888.56]
# Done testing DDPG Agent!
# Testing Random Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-06-14
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-18509.459]
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  64
# Fecha Final:  2023-07-03
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [-17190.803]
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  128
# Fecha Final:  2022-12-14
# Current Step Final:  180
# Episode Step Final:  51
# Reward:  [20446.045]
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  180
# Fecha Final:  2018-02-13
# Current Step Final:  244
# Episode Step Final:  63
# Reward:  [15577.587]
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  244
# Fecha Final:  2019-12-27
# Current Step Final:  308
# Episode Step Final:  63
# Reward:  [45889.965]
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  308
# Fecha Final:  2021-04-13
# Current Step Final:  363
# Episode Step Final:  54
# Reward:  [-16637.234]
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  363
# Fecha Final:  2020-02-19
# Current Step Final:  427
# Episode Step Final:  63
# Reward:  [3308.467]
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  427
# Fecha Final:  2018-06-06
# Current Step Final:  488
# Episode Step Final:  60
# Reward:  [-16266.085]
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  488
# Fecha Final:  2020-06-11
# Current Step Final:  552
# Episode Step Final:  63
# Reward:  [44873.473]
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  552
# Fecha Final:  9999-12-31
# Current Step Final:  616
# Episode Step Final:  63
# Reward:  [-154500.48]
# Done testing Random Agent!
# Testing SP500 Agent...
# --------------Testing Point 1 of 10-----------------------------------
# Fecha Inicial:  2020-04-21
# Current Step Inicial:  0
# Fecha Final:  2022-06-14
# Current Step Final:  64
# Episode Step Final:  63
# Reward:  [-95194.05]
# --------------Testing Point 2 of 10-----------------------------------
# Fecha Inicial:  2022-06-14
# Current Step Inicial:  64
# Fecha Final:  2023-07-03
# Current Step Final:  128
# Episode Step Final:  63
# Reward:  [-62662.965]
# --------------Testing Point 3 of 10-----------------------------------
# Fecha Inicial:  2023-07-03
# Current Step Inicial:  128
# Fecha Final:  2022-12-14
# Current Step Final:  180
# Episode Step Final:  51
# Reward:  [-518.10754]
# --------------Testing Point 4 of 10-----------------------------------
# Fecha Inicial:  2022-12-14
# Current Step Inicial:  180
# Fecha Final:  2018-02-13
# Current Step Final:  244
# Episode Step Final:  63
# Reward:  [-2010.0663]
# --------------Testing Point 5 of 10-----------------------------------
# Fecha Inicial:  2018-02-13
# Current Step Inicial:  244
# Fecha Final:  2019-12-27
# Current Step Final:  308
# Episode Step Final:  63
# Reward:  [24150.8]
# --------------Testing Point 6 of 10-----------------------------------
# Fecha Inicial:  2019-12-27
# Current Step Inicial:  308
# Fecha Final:  2021-04-13
# Current Step Final:  363
# Episode Step Final:  54
# Reward:  [-4808.936]
# --------------Testing Point 7 of 10-----------------------------------
# Fecha Inicial:  2021-04-13
# Current Step Inicial:  363
# Fecha Final:  2020-02-19
# Current Step Final:  427
# Episode Step Final:  63
# Reward:  [4477.]
# --------------Testing Point 8 of 10-----------------------------------
# Fecha Inicial:  2020-02-19
# Current Step Inicial:  427
# Fecha Final:  2018-06-06
# Current Step Final:  488
# Episode Step Final:  60
# Reward:  [14293.07]
# --------------Testing Point 9 of 10-----------------------------------
# Fecha Inicial:  2018-06-06
# Current Step Inicial:  488
# Fecha Final:  2020-06-11
# Current Step Final:  552
# Episode Step Final:  63
# Reward:  [16088.511]
# --------------Testing Point 10 of 10-----------------------------------
# Fecha Inicial:  2020-06-11
# Current Step Inicial:  552
# Fecha Final:  9999-12-31
# Current Step Final:  616
# Episode Step Final:  63
# Reward:  [-122704.02]
# Done testing SP500 Agent!
# --------------------------------------------------
# All agents tested!
# --------------------------------------------------

# %%
trained_agents
# Out:
# {'PPO Agent': <__main__.PPOAgent at 0x1933bdb8550>,
#  'A2C Agent': <__main__.A2CAgent at 0x1933bdb8d90>,
#  'DDPG Agent': <__main__.DDPGAgent at 0x193432df160>,
#  'Random Agent': <__main__.RandomAgent at 0x19344ed9d30>,
#  'SP500 Agent': <__main__.SP500Agent at 0x193cc80c580>}

# %%
metrics_resume_testing
# Out:
# {'PPO Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [-1922.4557300000015,
#    -196.16767800001253,
#    -396.01140000000305,
#    117.36556999999448,
#    136.7212999999756,
#    -806.6455099999584,
#    -1605.9888999999966,
#    377.043800000014,
#    -25.638999999995576,
#    -4629.368200000012],
#   'shares_held': [{'AAPL': 17,
#     'ABCB': 0,
#     'CSCO': 207,
#     'DAL': 14,
#     'EAST': 0,
#     'ESPR': 62,
#     'F': 453,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 59547,
#     'SP500': 7,
#     'TSLA': 0,
#     'UNH': 33,
#     'USA': 332,
#     'WMT': 295,
#     'XOM': 37},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 5,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 2498,
#     'GOOGL': 2,
#     'JPM': 126,
#     'META': 1,
#     'MSFT': 4,
#     'NVDA': 0,
#     'PFE': 79,
#     'PG': 1,
#     'PSX': 68,
#     'SGLY': 0,
#     'SP500': 4,
#     'TSLA': 2,
#     'UNH': 0,
#     'USA': 1963,
#     'WMT': 16,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 94,
#     'DAL': 156,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 2263,
#     'GOOGL': 0,
#     'JPM': 4,
#     'META': 1,
#     'MSFT': 0,
#     'NVDA': 15,
#     'PFE': 0,
#     'PG': 20,
#     'PSX': 43,
#     'SGLY': 117,
#     'SP500': 44,
#     'TSLA': 0,
#     'UNH': 20,
#     'USA': 239,
#     'WMT': 0,
#     'XOM': 26},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 138,
#     'DAL': 167,
#     'EAST': 508,
#     'ESPR': 142,
#     'F': 0,
#     'GOOGL': 95,
#     'JPM': 6,
#     'META': 13,
#     'MSFT': 0,
#     'NVDA': 71,
#     'PFE': 22,
#     'PG': 0,
#     'PSX': 1,
#     'SGLY': 0,
#     'SP500': 6,
#     'TSLA': 29,
#     'UNH': 4,
#     'USA': 4,
#     'WMT': 187,
#     'XOM': 230},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 316,
#     'DAL': 0,
#     'EAST': 202,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 3,
#     'MSFT': 523,
#     'NVDA': 0,
#     'PFE': 1,
#     'PG': 36,
#     'PSX': 188,
#     'SGLY': 4084,
#     'SP500': 15,
#     'TSLA': 1,
#     'UNH': 3,
#     'USA': 40,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 24,
#     'ABCB': 0,
#     'CSCO': 25,
#     'DAL': 8,
#     'EAST': 3643,
#     'ESPR': 0,
#     'F': 15,
#     'GOOGL': 1,
#     'JPM': 3,
#     'META': 37,
#     'MSFT': 2,
#     'NVDA': 0,
#     'PFE': 19,
#     'PG': 11,
#     'PSX': 2,
#     'SGLY': 8189,
#     'SP500': 5,
#     'TSLA': 3,
#     'UNH': 82,
#     'USA': 727,
#     'WMT': 44,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 614,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 137,
#     'F': 0,
#     'GOOGL': 1,
#     'JPM': 22,
#     'META': 0,
#     'MSFT': 9,
#     'NVDA': 0,
#     'PFE': 152,
#     'PG': 0,
#     'PSX': 108,
#     'SGLY': 1221,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 115,
#     'XOM': 320},
#    {'AAPL': 1,
#     'ABCB': 70,
#     'CSCO': 738,
#     'DAL': 37,
#     'EAST': 371,
#     'ESPR': 0,
#     'F': 96,
#     'GOOGL': 8,
#     'JPM': 1,
#     'META': 0,
#     'MSFT': 160,
#     'NVDA': 0,
#     'PFE': 63,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 1,
#     'TSLA': 7,
#     'UNH': 0,
#     'USA': 23,
#     'WMT': 0,
#     'XOM': 9},
#    {'AAPL': 0,
#     'ABCB': 386,
#     'CSCO': 11,
#     'DAL': 23,
#     'EAST': 1706,
#     'ESPR': 2,
#     'F': 8,
#     'GOOGL': 0,
#     'JPM': 23,
#     'META': 0,
#     'MSFT': 76,
#     'NVDA': 25,
#     'PFE': 174,
#     'PG': 14,
#     'PSX': 0,
#     'SGLY': 9,
#     'SP500': 11,
#     'TSLA': 0,
#     'UNH': 25,
#     'USA': 2107,
#     'WMT': 0,
#     'XOM': 199},
#    {'AAPL': 10,
#     'ABCB': 523,
#     'CSCO': 0,
#     'DAL': 195,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 3597,
#     'GOOGL': 11,
#     'JPM': 7,
#     'META': 0,
#     'MSFT': 25,
#     'NVDA': 37,
#     'PFE': 154,
#     'PG': 48,
#     'PSX': 0,
#     'SGLY': 1871,
#     'SP500': 1,
#     'TSLA': 1,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 4}],
#   'pearson_correlations': [0.4495931499805019,
#    0.6382272178032937,
#    0.20207259097512403,
#    0.6085922074995603,
#    0.34441163500433286,
#    0.13072694338113003,
#    0.17837493273965987,
#    0.23305293685088974,
#    0.12507357498703223,
#    0.5416231357863259],
#   'rewards': [-101464.33,
#    -26536.928,
#    -15776.807,
#    12903.389,
#    -25683.09,
#    -21855.191,
#    -66985.9,
#    1248.2515,
#    -9033.177,
#    -184329.81],
#   'portfolio_returns': [-0.0003060224611068076,
#    -2.738841958038214e-05,
#    -7.776706861216898e-05,
#    2.1949577390155e-05,
#    2.2831987849340897e-05,
#    -0.0001525253969593614,
#    -0.00026041172083558995,
#    6.432940837018181e-05,
#    -3.8081869145728352e-06,
#    -0.0007581069591485924],
#   'stds': [0.0037470326846205733,
#    0.002925532373390441,
#    0.0017849842645103061,
#    0.0024612871796209075,
#    0.0012613530698340038,
#    0.0007444296228286982,
#    0.001171663287742916,
#    0.0010407570138772128,
#    0.0008096288101337979,
#    0.0034914453228246344],
#   'sharpe_ratios': [-5.130608382175536,
#    -0.6705366851663686,
#    -2.2185708180942707,
#    0.47684630615949236,
#    1.0839256927322367,
#    -10.835752437347283,
#    -13.706914920017358,
#    3.6227841366678235,
#    -0.3166759838469498,
#    -13.259174273005025]},
#  'A2C Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [-2561.692689999967,
#    -669.6974279999849,
#    230.64255000000412,
#    -1227.1675899999973,
#    -235.67680000004475,
#    -653.1482180000021,
#    107.26420000000508,
#    1288.2783000000054,
#    1331.1627000000299,
#    -4818.07365000002],
#   'shares_held': [{'AAPL': 16,
#     'ABCB': 20,
#     'CSCO': 0,
#     'DAL': 278,
#     'EAST': 9051,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 1,
#     'MSFT': 1,
#     'NVDA': 2,
#     'PFE': 669,
#     'PG': 2,
#     'PSX': 552,
#     'SGLY': 0,
#     'SP500': 5,
#     'TSLA': 0,
#     'UNH': 1,
#     'USA': 84,
#     'WMT': 66,
#     'XOM': 81},
#    {'AAPL': 11,
#     'ABCB': 5,
#     'CSCO': 179,
#     'DAL': 843,
#     'EAST': 0,
#     'ESPR': 2170,
#     'F': 1422,
#     'GOOGL': 0,
#     'JPM': 5,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 26,
#     'PG': 10,
#     'PSX': 239,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 7,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 10},
#    {'AAPL': 52,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 7,
#     'EAST': 728,
#     'ESPR': 0,
#     'F': 160,
#     'GOOGL': 35,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 9,
#     'NVDA': 29,
#     'PFE': 494,
#     'PG': 45,
#     'PSX': 272,
#     'SGLY': 34,
#     'SP500': 19,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 695,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 374,
#     'DAL': 0,
#     'EAST': 408,
#     'ESPR': 5048,
#     'F': 21,
#     'GOOGL': 16,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 3,
#     'NVDA': 0,
#     'PFE': 300,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 4651,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 11,
#     'USA': 0,
#     'WMT': 118,
#     'XOM': 0},
#    {'AAPL': 62,
#     'ABCB': 11,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 441,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 213,
#     'META': 10,
#     'MSFT': 218,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 33,
#     'SGLY': 4587,
#     'SP500': 1,
#     'TSLA': 0,
#     'UNH': 85,
#     'USA': 4,
#     'WMT': 1,
#     'XOM': 98},
#    {'AAPL': 45,
#     'ABCB': 126,
#     'CSCO': 0,
#     'DAL': 64,
#     'EAST': 172,
#     'ESPR': 151,
#     'F': 84,
#     'GOOGL': 0,
#     'JPM': 29,
#     'META': 1,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 2,
#     'PG': 0,
#     'PSX': 172,
#     'SGLY': 120,
#     'SP500': 1,
#     'TSLA': 4,
#     'UNH': 101,
#     'USA': 223,
#     'WMT': 21,
#     'XOM': 67},
#    {'AAPL': 4,
#     'ABCB': 195,
#     'CSCO': 73,
#     'DAL': 1,
#     'EAST': 14,
#     'ESPR': 299,
#     'F': 7,
#     'GOOGL': 1,
#     'JPM': 0,
#     'META': 2,
#     'MSFT': 31,
#     'NVDA': 0,
#     'PFE': 516,
#     'PG': 82,
#     'PSX': 11,
#     'SGLY': 1454,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 35,
#     'USA': 1178,
#     'WMT': 11,
#     'XOM': 74},
#    {'AAPL': 1,
#     'ABCB': 0,
#     'CSCO': 17,
#     'DAL': 7,
#     'EAST': 1269,
#     'ESPR': 81,
#     'F': 3,
#     'GOOGL': 3,
#     'JPM': 22,
#     'META': 33,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 689,
#     'PG': 121,
#     'PSX': 50,
#     'SGLY': 37731,
#     'SP500': 2,
#     'TSLA': 0,
#     'UNH': 3,
#     'USA': 246,
#     'WMT': 12,
#     'XOM': 9},
#    {'AAPL': 6,
#     'ABCB': 18,
#     'CSCO': 1,
#     'DAL': 178,
#     'EAST': 0,
#     'ESPR': 407,
#     'F': 0,
#     'GOOGL': 3,
#     'JPM': 10,
#     'META': 0,
#     'MSFT': 44,
#     'NVDA': 12,
#     'PFE': 2,
#     'PG': 8,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 165,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1757,
#     'WMT': 25,
#     'XOM': 19},
#    {'AAPL': 0,
#     'ABCB': 1197,
#     'CSCO': 0,
#     'DAL': 252,
#     'EAST': 0,
#     'ESPR': 162,
#     'F': 1821,
#     'GOOGL': 1,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 147,
#     'NVDA': 1,
#     'PFE': 0,
#     'PG': 8,
#     'PSX': 42,
#     'SGLY': 0,
#     'SP500': 11,
#     'TSLA': 2,
#     'UNH': 9,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 4}],
#   'pearson_correlations': [0.3534863326301434,
#    0.6101293386507933,
#    0.3199077886686085,
#    0.49664900841484266,
#    0.3902512163837757,
#    0.15948873992404608,
#    0.19640056406423229,
#    0.27526440995426643,
#    0.2607460893257718,
#    0.5125274331978621],
#   'rewards': [-138899.58,
#    -43568.066,
#    -24302.102,
#    -20371.3,
#    -36145.6,
#    -14404.793,
#    -14071.53,
#    55982.05,
#    39651.53,
#    -175316.08],
#   'portfolio_returns': [-0.000412398012556003,
#    -0.0001063418375138172,
#    4.891663044400696e-05,
#    -0.00019447735203850702,
#    -3.728358654339177e-05,
#    -0.00012337692283549982,
#    1.811353907311113e-05,
#    0.00021843850787624076,
#    0.0002145392709035802,
#    -0.0007818111166976888],
#   'stds': [0.003477945603998248,
#    0.0020151007726565235,
#    0.002389966827034252,
#    0.0030490335531731918,
#    0.0012438078144828074,
#    0.0007144120140107767,
#    0.0012824108934996249,
#    0.001707460456623661,
#    0.0015706261465379344,
#    0.0053204735610390555],
#   'sharpe_ratios': [-7.3655340872929225,
#    -3.323394229644989,
#    0.9650449846879764,
#    -4.024775616925759,
#    -1.894800766290751,
#    -9.14245848600958,
#    0.8364261450344304,
#    7.544996400955908,
#    8.475363172415385,
#    -9.055723319972818]},
#  'DDPG Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [1489.640000000014,
#    1553.639599999995,
#    2309.209999999992,
#    -2690.059999999983,
#    -0.05000000000291038,
#    -973.9799999999959,
#    -3861.8399999999965,
#    497.21000000002095,
#    701.0499000000127,
#    -12546.910000000003],
#   'shares_held': [{'AAPL': 0,
#     'ABCB': 4514,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 2,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2426,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 4,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2923,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 2,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2038,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 2,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 1901,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2319,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 1912,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 1,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 2486,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 1752,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 1,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 3802,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 1,
#     'WMT': 0,
#     'XOM': 0}],
#   'pearson_correlations': [0.23422813252136038,
#    0.3203343523923182,
#    0.024952425621105355,
#    0.3369725095303013,
#    0.16576329041183482,
#    0.12711801784966908,
#    0.22947385516436097,
#    0.11163928021956163,
#    0.09702865856696233,
#    0.2541125296819703],
#   'rewards': [49581.414,
#    51679.95,
#    69305.33,
#    -62137.625,
#    -568.0596,
#    -28896.83,
#    -149047.31,
#    20461.236,
#    31111.018,
#    -559888.56],
#   'portfolio_returns': [0.0002620686058593221,
#    0.000251481281671075,
#    0.00046342902812954943,
#    -0.00043637901216879573,
#    1.3526765130097536e-06,
#    -0.00018394947837160314,
#    -0.0006275756403119453,
#    8.477016499473118e-05,
#    0.00011359556752552337,
#    -0.0014116706385087308],
#   'stds': [0.0068560519953525636,
#    0.0023621401643295443,
#    0.0036907977495081404,
#    0.002582866883192858,
#    0.0016500169151601885,
#    0.001185983893951788,
#    0.003832459424779226,
#    0.0011863560165863865,
#    0.0013509620835055827,
#    0.03785843664903082],
#   'sharpe_ratios': [2.1727373144337,
#    6.5772540658736505,
#    6.256669036681113,
#    -10.415016033170925,
#    -0.00030302719653062607,
#    -8.212421812530868,
#    -10.076662456047954,
#    4.191069063995561,
#    5.189264070097906,
#    -3.314164849520062]},
#  'Random Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [546.359690000012,
#    14.781409000061103,
#    1200.9669499999873,
#    -24.215859999967506,
#    1168.0353000000032,
#    -710.8347999999824,
#    434.5819999999803,
#    -272.79409999997006,
#    1343.8206999999966,
#    -4124.512299999988],
#   'shares_held': [{'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0}],
#   'pearson_correlations': [0.40648225303612734,
#    0.5190481912600751,
#    0.20594828674820173,
#    0.633886338996096,
#    0.2505679630442836,
#    0.26695658153212276,
#    0.4952370589865633,
#    0.4596492131264602,
#    0.18656583204963467,
#    0.5087699826242058],
#   'rewards': [-18509.459,
#    -17190.803,
#    20446.045,
#    15577.587,
#    45889.965,
#    -16637.234,
#    3308.467,
#    -16266.085,
#    44873.473,
#    -154500.48],
#   'portfolio_returns': [9.181246374742155e-05,
#    5.23170032558586e-06,
#    0.0002409039129842272,
#    -1.2824266793212064e-06,
#    0.00018836056985095708,
#    -0.000134264617470023,
#    7.05354321692526e-05,
#    -4.608059196511453e-05,
#    0.00021553088689152937,
#    -0.0006738177785261642],
#   'stds': [0.0027985835246241756,
#    0.0023859927586825226,
#    0.0020595193517796415,
#    0.0022870886782602315,
#    0.0014437093024320927,
#    0.0008058686627412019,
#    0.0010871601440975852,
#    0.0006601167351033405,
#    0.0006418322694731948,
#    0.003255271082422836],
#   'sharpe_ratios': [1.952272230550572,
#    0.061950770580808376,
#    5.83129723429025,
#    -0.10588072176715203,
#    8.090515854073356,
#    -8.820727655323422,
#    3.997405555744615,
#    -4.132513016160156,
#    20.937256724455164,
#    -12.670257547123208]},
#  'SP500 Agent': {'dates': ['2020-04-21',
#    '2022-06-14',
#    '2023-07-03',
#    '2022-12-14',
#    '2018-02-13',
#    '2019-12-27',
#    '2021-04-13',
#    '2020-02-19',
#    '2018-06-06',
#    '2020-06-11'],
#   'net_worths_delta': [-1806.4199999999983,
#    -799.9199999999983,
#    63.0,
#    -310.0,
#    880.7400000000052,
#    -321.36000000001513,
#    205.69999999998254,
#    509.1200000000099,
#    626.2600000000093,
#    -3260.1800000000076],
#   'shares_held': [{'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0},
#    {'AAPL': 0,
#     'ABCB': 0,
#     'CSCO': 0,
#     'DAL': 0,
#     'EAST': 0,
#     'ESPR': 0,
#     'F': 0,
#     'GOOGL': 0,
#     'JPM': 0,
#     'META': 0,
#     'MSFT': 0,
#     'NVDA': 0,
#     'PFE': 0,
#     'PG': 0,
#     'PSX': 0,
#     'SGLY': 0,
#     'SP500': 0,
#     'TSLA': 0,
#     'UNH': 0,
#     'USA': 0,
#     'WMT': 0,
#     'XOM': 0}],
#   'pearson_correlations': [0.9209736229529327,
#    0.9217634467721452,
#    0.9029607394914435,
#    0.9212596096098584,
#    0.9216633931548353,
#    0.9089905982583898,
#    0.9208371330689118,
#    0.9161129664234662,
#    0.921751340382896,
#    0.9211206603799786],
#   'rewards': [-95194.05,
#    -62662.965,
#    -518.10754,
#    -2010.0663,
#    24150.8,
#    -4808.936,
#    4477.0,
#    14293.07,
#    16088.511,
#    -122704.02],
#   'portfolio_returns': [-0.00029090956406141634,
#    -0.00012664593552245927,
#    1.2650936418683312e-05,
#    -4.7129615626244124e-05,
#    0.00014191318992684912,
#    -6.056721645661872e-05,
#    3.334340532816101e-05,
#    8.614374884584024e-05,
#    0.00010170612435190222,
#    -0.0005314882600998316],
#   'stds': [0.0024773120220180408,
#    0.002401790920620819,
#    0.00033115702846192954,
#    0.002424888425459699,
#    0.0009698774392102126,
#    0.0005699638227581626,
#    0.0006317171335490141,
#    0.000367282820482897,
#    0.0014189456604089175,
#    0.0024355265557344423],
#   'sharpe_ratios': [-7.291854978076085,
#    -3.330514713550643,
#    1.9024207425886661,
#    -1.278409335230472,
#    9.080941203428821,
#    -5.638252590223944,
#    3.256204226159754,
#    13.861797274662285,
#    4.413558725141956,
#    -13.385934931909983]}}

# %%
plot_metrics(metrics_resume_testing)
