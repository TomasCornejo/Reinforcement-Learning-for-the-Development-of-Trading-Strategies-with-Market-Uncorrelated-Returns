# %%
folderPath = 'E:\stockdata'

# %%
from alpaca.data import StockHistoricalDataClient
from hist_data_function import download_data
stock_client = StockHistoricalDataClient(key,  Secret)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from alpaca.data import StockHistoricalDataClient
#       2 from hist_data_function import download_data
#       3 stock_client = StockHistoricalDataClient(key,  Secret)
#
# ModuleNotFoundError: No module named 'alpaca'

# %%
stocks_to_get = 'CSCO'

# %%
download_data(stocks_to_get ,stock_client)
# Out:
#   symbol                 timestamp   open   high    low  close  volume  \
# 0   CSCO 2016-06-01 12:00:00+00:00  28.93  28.93  28.80  28.80  1200.0
# 1   CSCO 2016-06-01 12:15:00+00:00  28.80  28.82  28.80  28.82  1000.0
# 2   CSCO 2016-06-01 12:30:00+00:00  28.87  28.87  28.87  28.87   500.0
# 3   CSCO 2016-06-01 13:00:00+00:00  28.78  28.79  28.78  28.79   674.0
# 4   CSCO 2016-06-01 13:15:00+00:00  28.78  28.84  28.78  28.84  3847.0
#
#    trade_count       vwap
# 0          4.0  28.873333
# 1          4.0  28.810000
# 2          1.0  28.870000
# 3          4.0  28.785237
# 4          7.0  28.833468
# 'Data Downloaded Successfully CSCO between 2016-06-01 and 2024-03-01'

# %%
import pandas as pd

# %%
df = pd.read_csv('assets_data.csv')

# %%
# obtener el symbolo de meta
meta = df[df['symbol'] == 'CSCO']
meta
# Out:
#                                      id asset_class exchange symbol  \
# 25138  9ec078b151674d3d908ca1e49be367f1   us_equity   NASDAQ   CSCO
#
#                                         name  status  tradable  marginable  \
# 25138  Cisco Systems, Inc. Common Stock (DE)  active      True        True
#
#        shortable  easy_to_borrow  fractionable  min_order_size  \
# 25138       True            True          True             NaN
#
#        min_trade_increment  price_increment  maintenance_margin_requirement  \
# 25138                  NaN              NaN                            30.0
#
#       attributes
# 25138         []
